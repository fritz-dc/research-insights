# %% [markdown]
# # Phase 1 — Notebook 2: TF-IDF, Category Analysis & NMF
#
# Builds feature matrices and runs all Phase 1 analytical work on the clean
# corpus from `01_preprocess.ipynb`. `make_vec`, `add_bin`, and `group_key` —
# all imported from `utils.py` — are shared across Steps 1, 3, and 4, which is
# the main reason those three live together.
#
# | Step | What | Key output |
# |------|------|------------|
# | 1 | Build TF-IDF matrices | `features/X_*.npz`, `vocab/vocab_*.csv` |
# | 2 | Quality CP2 | `quality/quality_cp2.json` |
# | 3 | Category TF-IDF | `analysis/category_tfidf.csv` |
# | 4 | NMF topic discovery | `analysis/nmf_topics.csv`, `nmf_weights.csv` |
# | 5 | LLM topic labeling | `analysis/llm_topic_labels.json` |

# %% [markdown]
# ## Setup

# %%
import sys, json, re, unicodedata
from pathlib import Path
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed
from collections import defaultdict
import time as _time
import openai as _openai

import pandas as pd
import numpy as np
import scipy.sparse as sp
from sklearn.decomposition import NMF
from docx import Document
from docx.shared import Pt, RGBColor, Inches
from docx.enum.text import WD_ALIGN_PARAGRAPH

ROOT = Path(".")
sys.path.insert(0, str(ROOT))
from utils import (load_cfg, tokens_to_str, make_vec, add_bin, group_key,
                   quality_report, build_output_path, get_run_date,
                   get_llm_client, build_project_topic_bridge,
                   slugify_group_value)

CFG           = load_cfg()
ct            = CFG["tfidf"]
RUN_DATE      = get_run_date()
GROUPBY_FIELD = CFG["analysis"]["group_by"]
client        = get_llm_client()

def OUT(subdir, fname):
    """Analysis outputs nest under OUTPUTS/{GROUPBY_FIELD}/{RUN_DATE}/"""
    return build_output_path(subdir, fname,
                             groupby_field=GROUPBY_FIELD, run_date=RUN_DATE)

df = pd.read_parquet(ROOT / "OUTPUTS/prepared/05_enriched.parquet")
print(f"Loaded {len(df):,} projects  |  {df.shape[1]} columns")
print(f"Output path: OUTPUTS/{GROUPBY_FIELD}/{RUN_DATE}/")
# Out:
# Loaded 896,277 projects  |  45 columns
# Output path: OUTPUTS/project_category/2026-03-27/

# %% [markdown]
# ---
# ## Parameters
#
# All tunable values live here. Edit this cell; do not edit parameter references in downstream cells.

# %%
# ── All parameters from params.yaml — edit there, not here ──────────────
GROUPBY_FIELD       = CFG["analysis"]["group_by"]
GROUP_DESCRIPTION   = CFG["analysis"]["group_descriptions"].get(
                          GROUPBY_FIELD,
                          f"groups defined by '{GROUPBY_FIELD}' in DonorsChoose data")
MIN_SHARED          = CFG["analysis"]["nmf_min_shared"]
MIN_COVERAGE        = CFG["analysis"]["min_coverage"]
N_COMPONENTS        = CFG["nmf"]["n_components"]
CAT_TFIDF_TOP_N     = CFG["analysis"]["cat_tfidf_top_n"]
N_REPRESENTATIVE    = CFG["llm"]["n_representative_snippets"]
TOP_TERMS_IN_PROMPT = CFG["llm"]["top_terms_in_prompt"]
REVIEW_GROUP        = CFG["analysis"]["review_group"]
EXCLUDE_GROUPS      = CFG["analysis"]["exclude_groups"]
MAX_WORKERS         = CFG["analysis"]["synthesis_max_workers"]
MODEL_LABELING      = CFG["models"]["labeling"]
MODEL_SYNTHESIS     = CFG["models"]["synthesis"]

bins       = CFG["analysis"].get("bins", [])
group_cols = [GROUPBY_FIELD, "bin"] if bins else [GROUPBY_FIELD]

print(f"GROUPBY_FIELD    = {GROUPBY_FIELD!r}")
print(f"EXCLUDE_GROUPS   = {EXCLUDE_GROUPS}")
print(f"MAX_WORKERS      = {MAX_WORKERS}")
# Out:
# GROUPBY_FIELD    = 'project_category'
# EXCLUDE_GROUPS   = []
# MAX_WORKERS      = 8

# %% [markdown]
# ---
# ## Step 1 — Build TF-IDF Matrices
#
# One vectorizer fit per n-gram range on the full corpus. Trigrams are persisted
# even if unused in Phase 1 analysis — Phase 2+ inherits them without re-extraction.

# %%
# Cache once — reused by Cells 10 and 13
docs  = df["tokens"].apply(tokens_to_str).tolist()
# N-grams are generated here by sklearn rather than in preprocessing.
# The vocab CSVs written below are the persisted n-gram vocabulary the
# spec calls for — just produced at feature time instead of as a
# separate preprocessing step, which avoids a redundant intermediate artifact.
specs = {"X_unigram": (1,1), "X_bigram": (2,2), "X_unigram_bigram": (1,2)}
if CFG["ngrams"]["max_n"] >= 3:
    specs["X_trigram"] = (3, 3)

matrices, vecs = {}, {}
for name, rng in specs.items():
    vec            = make_vec(ct["min_df"], ct["max_df"], rng)
    matrices[name] = vec.fit_transform(docs)
    vecs[name]     = vec
    sz, nnz        = matrices[name].shape, matrices[name].nnz
    print(f"  {name:20s}: shape={sz}  sparsity={1 - nnz/(sz[0]*sz[1]):.3f}")

# Vocab artifact: feature names + IDF weights per matrix
for name, vec in vecs.items():
    (pd.DataFrame({"feature": vec.get_feature_names_out(), "idf": vec.idf_})
       .sort_values("idf")
       .to_csv(OUT("vocab", f"vocab_{name}.csv"), index=False))

feat_dir = ROOT / "OUTPUTS/features"
feat_dir.mkdir(parents=True, exist_ok=True)
for name, X in matrices.items():
    sp.save_npz(feat_dir / f"{name}.npz", X.tocsr())

META_COLS = ["project_id", "project_category", "posted_date", "funded_date",
             "metro_type_at_time_of_posting", "grade_band", "theme_version"]
meta = df[META_COLS].reset_index(drop=True)
try:
    meta.to_parquet(feat_dir / "meta.parquet", index=False)
except ImportError:
    meta.to_csv(feat_dir / "meta.csv", index=False)

assert matrices["X_unigram"].shape[0] == len(df)
# Out:
#   X_unigram           : shape=(896277, 7296)  sparsity=0.992
#   X_bigram            : shape=(896277, 932870)  sparsity=1.000
#   X_unigram_bigram    : shape=(896277, 940166)  sparsity=1.000
#   X_trigram           : shape=(896277, 691995)  sparsity=1.000

# %% [markdown]
# ---
# ## Step 2 — Quality Report: Checkpoint 2

# %%
qr2 = quality_report(df, label="cp2", matrices=matrices,
                     save_path=OUT("quality", "quality_cp2.json"))
# Out:
# =======================================================  [cp2]
#   Projects : 896,277
#   Tok/proj : min=5  p50=62  max=89
#   Vocab    : 7,389 unique tokens
#   X_unigram           : shape=[896277, 7296]  sparsity=0.992
#   X_bigram            : shape=[896277, 932870]  sparsity=1.000
#   X_unigram_bigram    : shape=[896277, 940166]  sparsity=1.000
#   X_trigram           : shape=[896277, 691995]  sparsity=1.000
#   Stopwords: FAIL — ['project', 'grade', 'teacher', 'education']
# =======================================================

# %% [markdown]
# ---
# ## Step 3 — Category TF-IDF
#
# The vectorizer is fit **once** on the full corpus; category slices are scored
# by index. This avoids the string-comparison bug (identical token sets across
# projects would misclassify rows) and is much faster than refitting per slice.
#
# **Contrast** = token prevalence in this category minus prevalence outside it.
#
# Time bins: defined in `params.yaml` under `analysis.bins`; leave empty for
# the full date range.

# %%
top_n     = CAT_TFIDF_TOP_N
min_proj  = CFG["analysis"]["min_group_projects"]

df_work   = add_bin(df, bins) if bins else df.copy()
df_work   = df_work.reset_index(drop=True)
all_docs  = (df_work["tokens"].apply(tokens_to_str).tolist() if bins else docs)
vec_cat   = make_vec(ct["min_df"], ct["max_df"], tuple(ct["ngram_range"]))
X_full    = vec_cat.fit_transform(all_docs)
feat      = vec_cat.get_feature_names_out()
idf_vals  = vec_cat.idf_

def cat_tfidf_slice(idx):
    """Score category slice by index against the rest of the corpus."""
    rest_idx  = df_work.index.difference(idx)
    X_cat     = X_full[idx.tolist()]
    X_rest    = X_full[rest_idx.tolist()]
    cat_prev  = (X_cat  > 0).mean(axis=0).A1
    rest_prev = (X_rest > 0).mean(axis=0).A1 if len(rest_idx) else np.zeros(len(feat))
    tf        = X_cat.mean(axis=0).A1
    return (pd.DataFrame({
                "token":         feat,
                "tf":            tf,
                "idf":           idf_vals,
                "tfidf":         tf * idf_vals,
                "prevalence":    cat_prev,
                "contrast":      cat_prev - rest_prev,
                "project_count": (X_cat > 0).sum(axis=0).A1.astype(int),
            }).nlargest(top_n, "tfidf"))

rows = []
for keys, sub in df_work.groupby(group_cols, observed=True):
    if len(sub) < min_proj:
        continue
    kd  = group_key(keys, group_cols)
    top = cat_tfidf_slice(sub.index)
    for col, val in kd.items():
        top.insert(0, col, val)
    rows.append(top)

if not rows:
    raise RuntimeError(f"No groups met min_proj={min_proj} threshold — lower min_group_projects in params.yaml")
cat_tfidf_df = pd.concat(rows, ignore_index=True)
cat_tfidf_df.to_csv(OUT("analysis", "category_tfidf.csv"), index=False)
print(f"{len(cat_tfidf_df):,} rows  |  {cat_tfidf_df[group_cols[0]].nunique()} groups")
cat_tfidf_df.head(10)
# Out:
# 300 rows  |  15 groups
#   project_category       token        tf       idf     tfidf  prevalence  \
# 0     Art Supplies         art  0.021509  3.258761  0.070091    0.465726
# 1     Art Supplies       paint  0.014017  4.777631  0.066968    0.207513
# 2     Art Supplies      supply  0.016237  2.782164  0.045174    0.406386
# 3     Art Supplies       color  0.011566  3.724483  0.043077    0.218632
# 4     Art Supplies  creativity  0.010943  3.693527  0.040420    0.216783
# 5     Art Supplies      marker  0.009618  4.082559  0.039267    0.163811
# 6     Art Supplies     express  0.009308  4.126950  0.038412    0.162887
# 7     Art Supplies      cricut  0.005896  6.350626  0.037446    0.068568
# 8     Art Supplies    creative  0.011658  3.156758  0.036803    0.268303
# 9     Art Supplies      crayon  0.007216  5.072622  0.036602    0.098480
#
#    contrast  project_count
# 0  0.381497          22156
# 1  0.194987           9872
# 2  0.251460          19333
# 3  0.161633          10401
# 4  0.157502          10313
# 5  0.124583           7793
# 6  0.125709           7749
# 7  0.067402           3262
# 8  0.161159          12764
# 9  0.086014           4685

# %% [markdown]
# ---
# ## Step 4 — NMF Topic Discovery
#
# NMF is fit independently per category so the dominant axis in one category
# does not suppress signal in others. Topics are candidates for human review —
# not stable theme definitions (that is Phase 2).
#
# The weights DataFrame records which projects load most strongly on each topic;
# Step 5 uses it to select representative snippets by NMF weight rather than
# randomly.

# %%
cn    = CFG["nmf"]
n_rep = N_REPRESENTATIVE
min_proj = CFG["analysis"]["min_group_projects"]

def nmf_one(docs):
    """Fit NMF on one slice. Returns (topics_df, W) or (None, None)."""
    vec = make_vec(ct["min_df"], ct["max_df"], tuple(ct.get("ngram_range", [1, 1])))
    X   = vec.fit_transform(docs)
    if X.shape[1] < N_COMPONENTS:
        return None, None
    model = NMF(n_components=N_COMPONENTS, random_state=cn["random_seed"],
                init="nndsvd", max_iter=cn["max_iter"])
    W     = model.fit_transform(X)
    vocab = vec.get_feature_names_out()
    rows  = []
    for i, comp in enumerate(model.components_):
        idx = comp.argsort()[::-1][:cn["top_words"]]
        rows.append({"topic_id": i, "top_terms": vocab[idx].tolist(),
                     "top_weights": comp[idx].tolist()})
    return pd.DataFrame(rows), W

all_topics, all_weights = [], []
df_work = add_bin(df, bins) if bins else df.copy()
df_work = df_work.reset_index(drop=True)

for keys, sub in df_work.groupby(group_cols, observed=True):
    if len(sub) < min_proj:
        continue
    kd     = group_key(keys, group_cols)
    group_docs = sub["tokens"].apply(tokens_to_str).tolist()
    pids   = sub["project_id"].tolist()
    topics, W = nmf_one(group_docs)
    if topics is None:
        continue
    for col, val in kd.items():
        topics[col] = val
    all_topics.append(topics)
    for tid in range(W.shape[1]):
        order = W[:, tid].argsort()[::-1]
        for rank, idx in enumerate(order):
            all_weights.append({
                **kd,
                "topic_id": tid,
                "project_id": pids[idx],
                "weight": float(W[idx, tid]),
                "rank": rank,
            })

if not all_topics:
    raise RuntimeError(
        f"No groups produced NMF topics — check N_COMPONENTS={N_COMPONENTS} vs vocab size, "
        f"or lower min_group_projects"
    )

topics_df  = pd.concat(all_topics, ignore_index=True)
weights_df = pd.DataFrame(all_weights)
topics_df.to_csv(OUT("analysis", "nmf_topics.csv"),   index=False)
weights_df.to_csv(OUT("analysis", "nmf_weights.csv"), index=False)
print(f"{len(topics_df):,} topics across {topics_df[group_cols[0]].nunique()} groups")

# ── Build project-topic bridge ───────────────────────────────────────────
# weights_df must contain the FULL per-project topic-weight matrix for each
# retained group before any top-k or representative-project filtering. If the
# notebook currently reduces weights_df earlier, build the bridge from the raw
# NMF W matrix before that reduction step.
threshold = CFG["analysis"]["topic_assignment_threshold"]
project_topic_bridge_df = build_project_topic_bridge(
    weights_df, GROUPBY_FIELD, threshold
)
project_topic_bridge_df.to_csv(
    OUT("analysis", "project_topic_bridge.csv"), index=False
)
print(
    f"Bridge: {len(project_topic_bridge_df):,} project-topic assignments "
    f"(topic_share >= {threshold})"
)

topics_df.head(6)
# Out:
# 180 topics across 15 groups
# Bridge: 741,852 project-topic assignments (topic_share >= 0.3)
#    topic_id                                          top_terms  \
# 0         0  [hard, some, thing, one, work, love, kid, clas...
# 1         1  [problem, solve, problem solve, thinke, hand, ...
# 2         2  [paint, art, artist, medium, create, artwork, ...
# 3         3  [motor, fine, fine motor, motor skill, skill, ...
# 4         4  [language, english, learner, diverse, english ...
# 5         5  [pencil, marker, crayon, supply, glue, color, ...
#
#                                          top_weights project_category
# 0  [0.7794189762826691, 0.7597492401240165, 0.741...     Art Supplies
# 1  [0.761300615978416, 0.7311979164194524, 0.6363...     Art Supplies
# 2  [0.9450864449513288, 0.9218133804597908, 0.644...     Art Supplies
# 3  [1.3406051544110913, 1.2862956382237984, 1.257...     Art Supplies
# 4  [1.2126182261101017, 1.0916055085906375, 0.867...     Art Supplies
# 5  [1.182659150886908, 1.0838385523517313, 0.9053...     Art Supplies

# %%
# Cross-group universal themes — terms appearing in NMF topics across many groups
if REVIEW_GROUP is not None:
    _eligible = topics_df[group_cols[0]].unique().tolist()
    if REVIEW_GROUP not in _eligible:
        raise ValueError(
            f"REVIEW_GROUP={REVIEW_GROUP!r} not found. Eligible: {_eligible}"
        )
else:
    REVIEW_GROUP = df_work.groupby(GROUPBY_FIELD).size().idxmax()

records = [(r[group_cols[0]], frozenset(r.top_terms)) for _, r in topics_df.iterrows()]

theme_cats = defaultdict(set)
for i, (ci, si) in enumerate(records):
    for cj, sj in records[i+1:]:
        if ci == cj:
            continue
        shared = si & sj
        if len(shared) >= MIN_SHARED:
            key = frozenset(shared)
            theme_cats[key] |= {ci, cj}

# Sort by n_groups desc, then drop any theme whose terms are a subset of a prior theme
rows = sorted(theme_cats.items(), key=lambda x: -len(x[1]))
seen = []
deduped = []
for terms, cats in rows:
    if len(cats) < MIN_COVERAGE:
        continue
    if not any(terms <= prior for prior in seen):
        deduped.append({"theme": ", ".join(sorted(terms)[:5]),
                        "n_groups": len(cats),
                        "categories": sorted(cats)})
        seen.append(terms)

pd.DataFrame(deduped).reset_index(drop=True)
# Out:
#                                                 theme  n_groups  \
# 0                             income, low, low income        14
# 1                     family, income, low, low income        11
# 2               family, home, income, low, low income        10
# 3     free, free reduce, lunch, receive, receive free        10
# 4            free, free reduce, lunch, price, receive        10
# 5          breakfast, free, free reduce, lunch, price         9
# 6          breakfast, free, free reduce, lunch, price         8
# 7                challenge, face, family, income, low         7
# 8         english, english language, language learner         6
# 9                             emotional, self, social         6
# 10  breakfast, breakfast lunch, free, free reduce,...         6
# 11  absolutely, absolutely love, active engage, al...         6
#
#                                            categories
# 0   [Art Supplies, Books, Classroom Basics, Comput...
# 1   [Art Supplies, Books, Classroom Basics, Comput...
# 2   [Art Supplies, Books, Classroom Basics, Comput...
# 3   [Art Supplies, Classroom Basics, Computers & T...
# 4   [Art Supplies, Classroom Basics, Computers & T...
# 5   [Art Supplies, Books, Classroom Basics, Comput...
# 6   [Art Supplies, Classroom Basics, Computers & T...
# 7   [Art Supplies, Classroom Basics, Educational K...
# 8   [Art Supplies, Books, Computers & Tablets, Ins...
# 9   [Art Supplies, Books, Computers & Tablets, Fle...
# 10  [Art Supplies, Classroom Basics, Computers & T...
# 11  [Books, Classroom Basics, Educational Kits & G...

# %% [markdown]
# ---
# ## Step 5 — LLM Topic Labeling
#
# One API call per topic on compressed input only — never raw essay text at scale.
# Representative snippets are chosen by NMF weight (not random).
#
# Prompt field limits (`top_unigrams`, `top_bigrams`, `top_nmf_terms`) are applied
# as item counts. Parse failures are stored with enough metadata to debug later.
#
# **Requires:** `pip install anthropic` + `ANTHROPIC_API_KEY` env var.
# Without the package, stubs are written so downstream steps stay testable.

# %%
SYSTEM = (
    "You are an NLP analyst reviewing NMF topic clusters from DonorsChoose teacher "
    "essays. Respond ONLY with a JSON object, no preamble, no markdown fences.\n\n"
    "Token naming conventions you may see in topic terms:\n"
    "  __framing_[name]__ = a rhetorical framing signal injected during preprocessing "
    "(e.g. __framing_barrier_removal__ means essays removing obstacles to participation)\n"
    "  __cat_[name]__ = a subject matter category token (e.g. __cat_genetics__)\n"
    "  __sub_[name]__ = a subcategory token\n"
    "These are meaningful signals — incorporate them into your label and description.\n\n"
    "Labeling rules:\n"
    "- Prefer the most specific defensible label.\n"
    "- Preserve concrete signals such as named programs, vendors, pedagogies, student "
    "populations, classroom use cases, or rhetorical framing when present.\n"
    "- Do not collapse topics into broad umbrella labels like technology, literacy, "
    "engagement, classroom supplies, or social-emotional learning if the evidence "
    "supports a narrower interpretation.\n"
    "- When framing tokens are present, treat them as first-class evidence about how "
    "teachers are positioning the request, not just background metadata.\n"
    "- If a topic is mixed, say what subthemes are colliding rather than forcing an "
    "overly neat label."
)
PROMPT = (
    f"Group ({GROUPBY_FIELD}): {{group_value}}{{bin_line}}\n"
    "Topic {topic_id}\n"
    "Top unigrams : {unigrams}\n"
    "Top bigrams  : {bigrams}\n"
    "Top NMF terms: {nmf_terms}\n"
    "Representative project tokens:\n"
    "{snippets}\n\n"
    "Instructions:\n"
    "- proposed_label should be concrete and specific, ideally naming the request or "
    "intervention, the population or context, and the framing when supported.\n"
    "- description should explain what makes this topic distinct from nearby generic "
    "topics.\n"
    "- If the topic appears broad, identify the narrower mechanism, use case, or "
    "population if the evidence supports it.\n"
    "- If the evidence is genuinely mixed, preserve that ambiguity instead of inventing "
    "a falsely precise label.\n\n"
    f"Return a JSON object with exactly these keys:\n"
    f"  {GROUPBY_FIELD}, topic_id, proposed_label, description, coherence_flag, notes\n"
    'coherence_flag must be one of: "coherent", "mixed", "redundant"'
)

has_essay = "essay" in df.columns
pid_text  = (df.set_index("project_id")["essay"].str[:300] if has_essay
             else df.set_index("project_id")["tokens"].apply(lambda t: " ".join(t[:40])))

def build_input(t_row):
    terms = t_row["top_terms"]
    key_cols = [GROUPBY_FIELD] + (["bin"] if "bin" in t_row.index else [])
    mask = weights_df["topic_id"] == t_row["topic_id"]
    for col in key_cols:
        mask &= weights_df[col] == t_row[col]
    rep_pids = (weights_df[mask].sort_values("weight", ascending=False)
                    ["project_id"].tolist()[:N_REPRESENTATIVE])
    n_uni = TOP_TERMS_IN_PROMPT
    n_bi  = max(2, TOP_TERMS_IN_PROMPT // 2)
    n_nmf = TOP_TERMS_IN_PROMPT
    return {
        "group_value": t_row[GROUPBY_FIELD],
        "topic_id": int(t_row["topic_id"]),
        "bin_line": f"\nBin: {t_row['bin']}"
                    if "bin" in t_row.index and pd.notna(t_row.get("bin")) else "",
        "unigrams":  ", ".join([x for x in terms if " " not in x][:n_uni]),
        "bigrams":   ", ".join([x for x in terms if " " in  x][:n_bi]),
        "nmf_terms": ", ".join(terms[:n_nmf]),
        "snippets":  "\n".join(f"- {pid_text.get(p, '')}" for p in rep_pids),
    }

results = []
for _, t in topics_df.iterrows():
    inp  = build_input(t)
    resp = client.chat.completions.create(
        model=MODEL_LABELING,
        messages=[
            {"role": "system", "content": SYSTEM},
            {"role": "user",   "content": PROMPT.format(**inp)},
        ],
    )
    text = resp.choices[0].message.content.strip()
    try:
        obj = json.loads(text)
    except json.JSONDecodeError:
        obj = {"raw": text, "parse_error": True, "model": MODEL_LABELING,
               "timestamp": datetime.now().isoformat(),
               GROUPBY_FIELD: inp["group_value"], "topic_id": inp["topic_id"]}
    results.append(obj)
    print(f"  {inp['group_value']} / topic {inp['topic_id']} "
          f"→ {obj.get('proposed_label', '?')}")

parse_errors = [r for r in results if r.get("parse_error")]
if parse_errors:
    print(f"WARNING: {len(parse_errors)} topics failed JSON parse — excluded from synthesis:")
    for e in parse_errors:
        print(f"  {e.get(GROUPBY_FIELD,'?')} / topic {e.get('topic_id','?')}")

labels_df = pd.DataFrame([r for r in results if not r.get("parse_error")])

assert GROUPBY_FIELD in labels_df.columns, (
    f"labels_df missing '{GROUPBY_FIELD}' — re-run labeling for this groupby field"
)

with open(OUT("analysis", "llm_topic_labels.json"), "w") as f:
    json.dump(results, f, indent=2)
print(f"\n{len(results)} labels saved")
# Out:
#   Art Supplies / topic 0 → Creative Exploration in Second Grade Art Class
#   Art Supplies / topic 1 → STEM Lab Project Design for Critical Thinking in Rural Elementary Schools
#   Art Supplies / topic 2 → Art Medium Exploration and Technique Development in Visual Arts Education
#   Art Supplies / topic 3 → Sensory Play Materials for Fine Motor Skill Development in Early Childhood
#   Art Supplies / topic 4 → Art Supplies for Diverse English Language Learners in Low-Income Communities
#   Art Supplies / topic 5 → Basic Art Supplies for Diverse Classroom Needs
#   Art Supplies / topic 6 → Social Emotional Learning Tools for Mindfulness and Self-Regulation
#   Art Supplies / topic 7 → Cricut Machine Projects for Personalized Classroom Decor
#   Art Supplies / topic 8 → Literacy and Math Engagement through Fun Activities in Diverse Kindergarten Classes
#   Art Supplies / topic 9 → Creative Art Experiences for Low-Income Students Facing Challenges
#   Art Supplies / topic 10 → Art Supplies for Students Receiving Free or Reduced Price Lunch
#   Art Supplies / topic 11 → Creative Self-Expression in Low-Income Art Education
#   Awaiting Classification / topic 0 → RCA Professional Development for Enhancing Instructional Relationships
#   Awaiting Classification / topic 1 → Creative Art Supplies for Socioeconomically Disadvantaged Students
#   Awaiting Classification / topic 2 → First Grade Inquiry-Based Learning for Eager Students in Under-Resourced Communities
#   Awaiting Classification / topic 3 → Ron Clark Academy Professional Development for Engaging Diverse Student Populations
#   Awaiting Classification / topic 4 → Professional Development Workshops at Ron Clark Academy for Multilingual Learners
#   Awaiting Classification / topic 5 → Community Support for Safe Learning Environments
#   Awaiting Classification / topic 6 → Individualized Support for Diverse Learning Needs in Classroom Settings
#   Awaiting Classification / topic 7 → Implementation of Ron Clark Academy's House System in Elementary Music Education
#   Awaiting Classification / topic 8 → Literacy Support for Low Socioeconomic Urban Learners in Diverse Classrooms
#   Awaiting Classification / topic 9 → Support for Low-Income Students with Disabilities and Diverse Backgrounds
#   Awaiting Classification / topic 10 → Movement and Exploration in Science and Music for Diverse Learners
#   Awaiting Classification / topic 11 → Innovative Professional Development at Ron Clark Academy
#   Books / topic 0 → Engaging Diverse Learners through Storytelling in Elementary Education
#   Books / topic 1 → Enriching Independent Reading Experiences through Diverse Print Materials
#   Books / topic 2 → Access to Free and Reduced-Price Lunch Books for Diverse Students
#   Books / topic 3 → Graphic Novels and Series for Expanding Library Access
#   Books / topic 4 → Diverse Literary Texts for Culturally Responsive Teaching
#   Books / topic 5 → Scholastic News Subscription for Science and Social Studies in Second and Third Grades
#   Books / topic 6 → Decodable Readers for Literacy Development in Diverse First-Grade Classrooms
#   Books / topic 7 → Overcoming Challenges in Low-Income Districts to Foster a Love of Reading
#   Books / topic 8 → Bilingual Book Access for English Language Learners
#   Books / topic 9 → Social Emotional Learning (SEL) Tools for Early Childhood Self-Regulation
#   Books / topic 10 → Book Access and Literacy Support for Low-Income Families
#   Books / topic 11 → Engaging First Grade Projects to Think Outside the Box
#   Classroom Basics / topic 0 → Diverse Classroom Engagement for Underrepresented Students
#   Classroom Basics / topic 1 → Challenges Faced by Low-Income Families in Education
#   Classroom Basics / topic 2 → Math Practice with Dry Erase Boards and Markers for Whole Group Instruction
#   Classroom Basics / topic 3 → Basic Classroom Supplies for Resource-Constricted Students
#   Classroom Basics / topic 4 → Tools for Enhancing Collaborative Problem Solving in Mathematics
#   Classroom Basics / topic 5 → Creating Safe and Comfortable Learning Environments for Students with Emotional Needs
#   Classroom Basics / topic 6 → Kindergarten Writing Skill Development for English Language Learners
#   Classroom Basics / topic 7 → Organizational Tools for Math Classes
#   Classroom Basics / topic 8 → Support for Students Receiving Free or Reduced-Price Lunches
#   Classroom Basics / topic 9 → Active Engagement Strategies for Low-Income Elementary Students
#   Classroom Basics / topic 10 → Incentive-Based Motivation Strategies for Young Students
#   Classroom Basics / topic 11 → Improving Academic Achievement through Interactive Whiteboard Projects
#   Computers & Tablets / topic 0 → Access to Technology for Low-Income Families
#   Computers & Tablets / topic 1 → Accessing Technology for Low-Income Students with Free or Reduced Lunch
#   Computers & Tablets / topic 2 → Interactive iPad Tools for Enhancing Digital Literacy and Engagement
#   Computers & Tablets / topic 3 → Creative Problem-Solving in Rural Classrooms
#   Computers & Tablets / topic 4 → Interactive Literacy and Math Centers for Early Learners Using Tablets
#   Computers & Tablets / topic 5 → Creative Learning Experiences for Low-Income Students in Challenging Districts
#   Computers & Tablets / topic 6 → Assistive Technology for Students with Autism and Disabilities in Special Education
#   Computers & Tablets / topic 7 → Remote Learning Tools for Interactive Teaching during COVID-19
#   Computers & Tablets / topic 8 → Chromebook Charging Station Organization for Classroom Safety
#   Computers & Tablets / topic 9 → STEM Exploration and Problem Solving with Robotics and Renewable Energy
#   Computers & Tablets / topic 10 → Supporting English Language Learners with Translation Tools
#   Computers & Tablets / topic 11 → Enhancing Academic Achievement Through Collaborative Learning with Technology
#   Educational Kits & Games / topic 0 → Educational Support Kits for Low-Income Families
#   Educational Kits & Games / topic 1 → Critical Thinking and Problem-Solving Development Through Interactive Board Games
#   Educational Kits & Games / topic 2 → Calm Corner Sensory Tools for Emotional Regulation in Students
#   Educational Kits & Games / topic 3 → Phonics and Phonemic Awareness Resources for Kindergarten and First Grade
#   Educational Kits & Games / topic 4 → Fine Motor Skill Development Kits for Early Childhood Education
#   Educational Kits & Games / topic 5 → Free/Reduced Price Lunch Support for English Language Learners in Rural Areas
#   Educational Kits & Games / topic 6 → Creative Problem Solving through Active Engagement Activities
#   Educational Kits & Games / topic 7 → Social Emotional Skill Development Through Cooperative Play Activities
#   Educational Kits & Games / topic 8 → Special Education Language Support for Autism and Speech Impairments
#   Educational Kits & Games / topic 9 → Hands-On Math Manipulatives for Conceptual Understanding in Whole Group Instruction
#   Educational Kits & Games / topic 10 → PBIS Incentive Rewards for Student Behavior Support
#   Educational Kits & Games / topic 11 → STEM Exploration Kits for Elementary Students
#   Flexible Seating / topic 0 → Flexible Seating Options for Kinetic Learners
#   Flexible Seating / topic 1 → Flexible Seating for Student Autonomy and Comfort
#   Flexible Seating / topic 2 → Whole Group Instruction with Colorful Carpets for Kindergarten
#   Flexible Seating / topic 3 → Creating Inclusive and Engaging Learning Environments with Flexible Seating
#   Flexible Seating / topic 4 → Low-Income Students Needing Flexible Learning Environments
#   Flexible Seating / topic 5 → Calm Down Corners for Emotional Self-Regulation in Special Education
#   Flexible Seating / topic 6 → Bean Bag Chairs for Classroom Comfort and Regulation
#   Flexible Seating / topic 7 → Classroom Organization with Seat Sacks for Early Education
#   Flexible Seating / topic 8 → Creative Group Engagement through Active Learning Strategies
#   Flexible Seating / topic 9 → Flexible Seating for Enhanced Oxygen Flow and Academic Focus
#   Flexible Seating / topic 10 → Cozy Reading Spaces for Independent Learning
#   Flexible Seating / topic 11 → Flexible Seating Options for Student Autonomy and Engagement
#   Food, Clothing & Hygiene / topic 0 → Engaging First and Second Grade Learners Through Diverse Cultural Experiences
#   Food, Clothing & Hygiene / topic 1 → Supplies for Maintaining Cleanliness in Classrooms during Cold and Flu Season
#   Food, Clothing & Hygiene / topic 2 → Healthy Snacks for Focused Learning in Elementary Classrooms
#   Food, Clothing & Hygiene / topic 3 → Healthy Snack Support for Students' Academic Engagement
#   Food, Clothing & Hygiene / topic 4 → PBIS Incentive Programs for Diverse Student Engagement
#   Food, Clothing & Hygiene / topic 5 → Health and Hygiene Improvement for Early Learners through Sanitization Supplies
#   Food, Clothing & Hygiene / topic 6 → Access to Personal Hygiene Products for Students
#   Food, Clothing & Hygiene / topic 7 → Life Skills Development through Cooking in Special Education
#   Food, Clothing & Hygiene / topic 8 → Healthy Snack Provision for Student Concentration and Focus Enhancement
#   Food, Clothing & Hygiene / topic 9 → Winter Clothing Essentials for Alaska Students - A Humble Plea for Warmth
#   Food, Clothing & Hygiene / topic 10 → Humble Pleas for Community Support in Arts and Basic Needs Projects
#   Food, Clothing & Hygiene / topic 11 → Support for Low-Income Students Receiving Free or Reduced-Price Meals
#   Instructional Technology / topic 0 → Community Photography Project for Yearbook Creation
#   Instructional Technology / topic 1 → Teacher Pay Gift Card for Educational Resources
#   Instructional Technology / topic 2 → STEM Engineering Problem Solving with 3D Printing for Early Education
#   Instructional Technology / topic 3 → Visual Learning Aids Using Color Printers for Student Engagement
#   Instructional Technology / topic 4 → Noise-Canceling Headphones for Focused Learning in Elementary Classrooms
#   Instructional Technology / topic 5 → Supporting Low-Income Students with Digital Resources and Nutrition Support
#   Instructional Technology / topic 6 → Supporting Low-Income Families in Overcoming Educational Challenges
#   Instructional Technology / topic 7 → Support for English Language Learners' Literacy Skills through Bilingual Resources
#   Instructional Technology / topic 8 → Classroom Organizational Supplies for First Graders
#   Instructional Technology / topic 9 → Request for Gift Cards to Access Relevant Educational Resources
#   Instructional Technology / topic 10 → Creative Problem Solving through Engaging Activities for First Graders
#   Instructional Technology / topic 11 → Enhanced Learning Tools for Diverse Educational Needs
#   Lab Equipment / topic 0 → Lab Experiences for Low-Income English Language Learners
#   Lab Equipment / topic 1 → Curiosity-Driven Science Exploration for Fifth Graders
#   Lab Equipment / topic 2 → Urban Hydroponic Gardening for Sustainable Food Education
#   Lab Equipment / topic 3 → STEM Skills Development through Problem-Solving Engineering Projects for Elementary Students
#   Lab Equipment / topic 4 → Support for Free or Reduced Price Lunch Students Engaging in STEM Activities
#   Lab Equipment / topic 5 → Creating a Calming Learning Environment for Students with Sensory Sensitivity
#   Lab Equipment / topic 6 → Enhancing Critical Thinking through Interactive Science Tools
#   Lab Equipment / topic 7 → Teacher-Driven Support for Student Well-Being in Challenging Circumstances
#   Lab Equipment / topic 8 → Life Cycle Observation Kits for Elementary Students with Emphasis on Collaborative Learning
#   Lab Equipment / topic 9 → Hands-on Dissection Experience for Understanding Human Anatomy and Organ Systems
#   Lab Equipment / topic 10 → Chemistry Lab Equipment for Student-Centered Experiments
#   Lab Equipment / topic 11 → Creative Project Engagement with Hands-On Learning Strategies
#   Musical Instruments / topic 0 → Music Skill Development with Innovative Instruments for Diverse Learners
#   Musical Instruments / topic 1 → Support for Woodwind Instrument Supplies in Middle School Band Programs
#   Musical Instruments / topic 2 → Support for Free and Reduced Price Lunch Students to Access Music Instruments
#   Musical Instruments / topic 3 → Ukulele and Guitar Instruction for Elementary Music Classes
#   Musical Instruments / topic 4 → Music Education for Racial Minority Students in Urban Montessori Schools
#   Musical Instruments / topic 5 → Interactive Communication Tools for Fourth Grade and Preschool Students
#   Musical Instruments / topic 6 → Band Program Support for Middle Grades Performance Enhancement
#   Musical Instruments / topic 7 → Elementary Music Education Enhancement with Percussion Instruments
#   Musical Instruments / topic 8 → Support for High-Energy Orchestra and Choir Programs in Low-Income Schools
#   Musical Instruments / topic 9 → Support for English Language Learners in Arts Education Programs
#   Musical Instruments / topic 10 → Challenges Faced by Low-Income Families in Accessing Musical Instruments
#   Musical Instruments / topic 11 → Humble Plea for Musical Instrument Donations for Diverse Middle and Elementary School Programs
#   Reading Nooks, Desks & Storage / topic 0 → Collaborative Math Instruction with Dry Erase Boards for Group Learning
#   Reading Nooks, Desks & Storage / topic 1 → Classroom Material Organization for Preschool
#   Reading Nooks, Desks & Storage / topic 2 → Resources for English Language Learners from Low-Income Backgrounds to Support Breakfast and Lunch Programs
#   Reading Nooks, Desks & Storage / topic 3 → Flexible Seating Options for Student Comfort and Engagement
#   Reading Nooks, Desks & Storage / topic 4 → Kindergarten Reading Library Setup with Bookshelf Display
#   Reading Nooks, Desks & Storage / topic 5 → Collaborative Learning Environments for Diverse Students
#   Reading Nooks, Desks & Storage / topic 6 → Creative Engagement Projects for Diverse Student Groups
#   Reading Nooks, Desks & Storage / topic 7 → Creating Safe, Inclusive Classroom Spaces for Kindergarten Students
#   Reading Nooks, Desks & Storage / topic 8 → Flexible Seating for Student Choice and Autonomy
#   Reading Nooks, Desks & Storage / topic 9 → Social-Emotional Learning Supports for Students with Disabilities
#   Reading Nooks, Desks & Storage / topic 10 → Resource Requests for Low-Income Students Facing Multiple Challenges
#   Reading Nooks, Desks & Storage / topic 11 → STEM Exploration with Fine Motor Skill Development for Early Learners
#   Sports & Exercise Equipment / topic 0 → Literacy Development through Engaging Reading Practices in Diverse Elementary Classrooms
#   Sports & Exercise Equipment / topic 1 → Athletic Equipment Funding for Youth Team Sports
#   Sports & Exercise Equipment / topic 2 → Soccer and Volleyball Equipment for Building Teamwork and Confidence
#   Sports & Exercise Equipment / topic 3 → Health and Fitness Improvement through Physical Exercise Programs for Youth
#   Sports & Exercise Equipment / topic 4 → Support for Students Receiving Free and Reduced Price Lunch
#   Sports & Exercise Equipment / topic 5 → Reusable Water Bottle Project for Hydration in Physical Education
#   Sports & Exercise Equipment / topic 6 → Enhancement of Physical Education Equipment for Active Participation in Middle School Sports
#   Sports & Exercise Equipment / topic 7 → Sensory Tools for Emotional Regulation in Early Childhood Education
#   Sports & Exercise Equipment / topic 8 → Gross and Fine Motor Skill Development Equipment for Early Childhood Education
#   Sports & Exercise Equipment / topic 9 → Incentive-Based Behavior Reinforcement for Kindergarteners
#   Sports & Exercise Equipment / topic 10 → Support for Low-Income Families in Creative Educational Activities
#   Sports & Exercise Equipment / topic 11 → Recess Equipment for Active Play and Social Skills Development
#   Virtual Trips / topic 0 → Science Field Trips for Economically Disadvantaged Students
#   Virtual Trips / topic 1 → Professional Development Conferences for Educators
#   Virtual Trips / topic 2 → Social Emotional Learning through Yoga and Mindfulness Training for Educators
#   Virtual Trips / topic 3 → Free Lunch Assistance for English Language Learners
#   Virtual Trips / topic 4 → STEM Virtual Engagement for Talented Students
#   Virtual Trips / topic 5 → Funding for Competitive Athletic Travel Programs for Girls
#   Virtual Trips / topic 6 → Training in Orton-Gillingham Methodology for Literacy Instruction in Special Education
#   Virtual Trips / topic 7 → Empowering Rural First Graders through Dynamic Educational Strategies
#   Virtual Trips / topic 8 → Cultural Exposure Through Virtual Travel for Diverse Urban Students
#   Virtual Trips / topic 9 → Creative Learning Experiences for Low-Income Students Facing Challenges
#   Virtual Trips / topic 10 → Ron Clark Academy Training for Engaging Elementary Educators
#   Virtual Trips / topic 11 → Support for Emotionally Disturbed Students in Special Education
#   Virtual Visitors / topic 0 → Visual Art Education for Low-Income Students in Impoverished Communities
#   Virtual Visitors / topic 1 → Tuition-Free College Access Programs for Culturally Rich Communities
#   Virtual Visitors / topic 2 → Technology-Based Visual Aids for Students with Disabilities
#   Virtual Visitors / topic 3 → Support for Urban English Language Learners Receiving Free/Reduced Lunch for Arts Education
#   Virtual Visitors / topic 4 → Special Education Sensory and Motor Development Programs
#   Virtual Visitors / topic 5 → Virtual Music and Performing Arts Engagement for Diverse Student Populations
#   Virtual Visitors / topic 6 → Urban Preschool Engagement through Virtual Connections
#   Virtual Visitors / topic 7 → Virtual Author Visits to Encourage Reading in Rural Schools
#   Virtual Visitors / topic 8 → Holistic Community-Building through Virtual Experiences for Child Development
#   Virtual Visitors / topic 9 → Support Programs for Deaf and Hard of Hearing Preschool Language Learners in Inner City
#   Virtual Visitors / topic 10 → Virtual Field Trips to Explore Animal Adaptations for Fourth Graders
#   Virtual Visitors / topic 11 → Educational Support for Low-Income Minority Students
#
# 180 labels saved

# %%
labels_df = pd.DataFrame(results)
labels_df.groupby("coherence_flag").size().rename("count").to_frame()
labels_df[[GROUPBY_FIELD,"topic_id","proposed_label","coherence_flag","description"]]
# Out:
#      project_category topic_id  \
# 0        Art Supplies        0
# 1        Art Supplies        1
# 2        Art Supplies        2
# 3        Art Supplies        3
# 4        Art Supplies        4
# ..                ...      ...
# 175  Virtual Visitors        7
# 176  Virtual Visitors        8
# 177  Virtual Visitors        9
# 178  Virtual Visitors       10
# 179  Virtual Visitors       11
#
#                                         proposed_label coherence_flag  \
# 0       Creative Exploration in Second Grade Art Class       coherent
# 1    STEM Lab Project Design for Critical Thinking ...       coherent
# 2    Art Medium Exploration and Technique Developme...       coherent
# 3    Sensory Play Materials for Fine Motor Skill De...       coherent
# 4    Art Supplies for Diverse English Language Lear...       coherent
# ..                                                 ...            ...
# 175  Virtual Author Visits to Encourage Reading in ...       coherent
# 176  Holistic Community-Building through Virtual Ex...       coherent
# 177  Support Programs for Deaf and Hard of Hearing ...       coherent
# 178  Virtual Field Trips to Explore Animal Adaptati...       coherent
# 179  Educational Support for Low-Income Minority St...       coherent
#
#                                            description
# 0    This topic centers around second graders engag...
# 1    This topic centers on requests for STEM lab ma...
# 2    This topic focuses on enhancing art education ...
# 3    This topic focuses on the use of sensory play ...
# 4    This topic focuses on providing art supplies t...
# ..                                                 ...
# 175  This topic centers around virtual author visit...
# 176  This topic focuses on projects aimed at creati...
# 177  This topic focuses on initiatives aimed at sup...
# 178  This topic centers around requests for virtual...
# 179  This topic focuses on projects aimed at provid...
#
# [180 rows x 5 columns]

# %%
# ── SYNTHESIS — cross-group + per-group loops ─────────────────────────────

def clean_label(text):
    """Remove injected __token__ signals and replace with readable paraphrase."""
    return re.sub(r'__[a-z_]+__\s*', '', str(text)).strip()

def build_topic_lines(df, groupby_field, group=None):
    if group is not None:
        df = df[df[groupby_field] == group]
    return "\n".join(
        f"  {row[groupby_field]} | topic {row.topic_id} | "
        f"label: {clean_label(row.proposed_label)} | "
        f"coherence: {row.coherence_flag} | "
        f"description: {clean_label(row.description)}"
        for _, row in df.iterrows()
    )

SYNTHESIS_SYSTEM = (
    "You are a senior program analyst at an educational nonprofit. "
    "You write precise, insight-driven briefings for internal strategy audiences. "
    "You do not pad your answers or state the obvious.\n\n"
    "Some topic labels may reference rhetorical framing signals (e.g. 'barrier removal "
    "framing', 'chronic scarcity language') — these come from injected tokens that "
    "categorize how teachers write, not just what they request. Treat these as "
    "meaningful signals about teacher rhetorical strategy.\n\n"
    "Prioritize nuance over novelty. Prefer fine-grained distinctions, concrete "
    "mechanisms, specific populations, and framing differences over broad thematic "
    "summaries.\n\n"
    "Formatting: use plain numbered section headers (e.g. '1. SUBTHEME DISTINCTIONS'). "
    "Do not use markdown headers (##). Do not use bullet points.\n\n"
    "Grounding: when writing Framing Differences findings, the contrast must be "
    "traceable to explicit language in the topic label or description — not inferred "
    "from the topic's general subject matter or implied by category context. If you "
    "cannot quote or closely paraphrase specific label language to establish both sides "
    "of a contrast, do not make the finding."
)

topic_lines = build_topic_lines(labels_df, GROUPBY_FIELD)

SYNTHESIS_PROMPT_CROSS_GROUP = f"""
Below is a list of NMF topics discovered from teacher project request essays on DonorsChoose,
grouped by {GROUPBY_FIELD} ({GROUP_DESCRIPTION}).
Each topic represents a cluster of essays with similar language, framing, and request patterns.
{topic_lines}
Your task: identify the most specific, decision-useful patterns in this topic landscape.
Rules:
- Every finding must be grounded in specific topic labels, descriptions, or coherence flags
  from the list above.
- Do not introduce concepts, themes, or absences that cannot be traced to an actual topic.
- If you cannot name the specific group and topic, do not make the finding.
- Prefer fine-grained distinctions over broad summaries.
- Skip anything predictable given the group name.
- Skip the free/reduced lunch poverty framing — it appears everywhere and is already known.
- Skip generic engagement/motivation language unless the topic evidence makes it unusually specific.
- If fewer than two strong findings exist for a section, write one or write none. Do not pad.

Focus on:
1. RECURRING INTERNAL SPLITS — cases where the same subtheme distinction recurs independently
   inside multiple groups. Only flag a split if it appears in at least two groups with
   meaningfully similar internal logic. Name the groups and specific topics each time.

2. CROSS-GROUP SIGNATURES — a specific program, vendor, pedagogy, student need, or rhetorical
   frame that shows up as a recognizable topic in multiple groups. Name every group it appears
   in and explain why the pattern is meaningful.

3. FRAMING DIFFERENCES — cases where similar underlying needs are presented through meaningfully
   different rhetorical frames, populations, or classroom contexts. Explain what changes across
   groups and why that difference matters.

4. NOTABLE ABSENCES — a topic you would expect given the internal logic of a group's other
   topics, but that is missing. To qualify, name at least two specific topics already present
   in the same group that make the gap conspicuous from within. Do not reason from other groups.

5. REQUEST TRIGGERS AND PITCH STRATEGIES — patterns in why teachers say they are requesting and
   how they frame those reasons for a donor audience. Only use explicit topic evidence.

Format as five labeled sections. Under each, write 2-5 findings as short paragraphs.
Be specific — name the group and topic label every time. Do not use bullet points.
""".strip()

PER_GROUP_INSTRUCTIONS = """
Your task: identify the most specific, decision-useful patterns within this group.
Rules:
- Every finding must be grounded in specific topic labels, descriptions, or coherence flags
  from the list above.
- Do not introduce concepts, themes, or absences that cannot be traced to an actual topic.
- If you cannot name the specific topic, do not make the finding.
- Prefer fine-grained distinctions over broad summaries.
- Skip anything predictable given the group name.
- Skip the free/reduced lunch poverty framing — it appears everywhere and is already known.
- Skip generic engagement/motivation language unless the topic evidence makes it unusually specific.
- If fewer than two strong findings exist for a section, write one or write none. Do not pad.

Focus on:
1. SUBTHEME DISTINCTIONS — distinct needs, populations, pedagogies, use cases, or framing
   modes within this group.

2. INTERNAL FRAMING DIFFERENCES — cases within this group where similar underlying needs are
   presented through meaningfully different rhetorical frames, populations, or classroom
   contexts.

3. NOTABLE ABSENCES — a topic you would expect given the internal logic of this group's other
   topics, but that is missing.

4. REQUEST TRIGGERS AND PITCH STRATEGIES — patterns in why teachers say they are requesting
   within this group and how they frame that reason for a donor audience.

Format as four labeled sections. Under each, write 2-5 findings as short paragraphs.
Be specific — name the topic label every time. Do not use bullet points.
""".strip()

def build_per_group_prompt(group, topic_lines_text):
    return f"""
Below is a list of NMF topics discovered from teacher project request essays on DonorsChoose
for a single group: {group} ({GROUP_DESCRIPTION}).
Each topic represents a cluster of essays with similar language, framing, and request patterns.
{topic_lines_text}
{PER_GROUP_INSTRUCTIONS}
""".strip()

def _call_with_retry(prompt, max_retries=3):
    """Single synthesis call with exponential backoff on rate-limit/timeout."""
    for attempt in range(max_retries + 1):
        try:
            resp = client.chat.completions.create(
                model=MODEL_SYNTHESIS,
                messages=[
                    {"role": "system", "content": SYNTHESIS_SYSTEM},
                    {"role": "user",   "content": prompt},
                ],
            )
            return resp.choices[0].message.content.strip()
        except (_openai.RateLimitError, _openai.APITimeoutError):
            if attempt < max_retries:
                _time.sleep(2 ** attempt)
            else:
                raise
        except Exception as e:
            print(f"Non-retryable error: {e}")
            return None

synthesis_cross = _call_with_retry(SYNTHESIS_PROMPT_CROSS_GROUP)
with open(OUT("analysis", "llm_synthesis_cross_group.txt"), "w") as f:
    f.write(synthesis_cross or "")
print("── CROSS-GROUP ──────────────────────────────────────────")
print(synthesis_cross)

groups = [g for g in labels_df[GROUPBY_FIELD].unique() if g not in EXCLUDE_GROUPS]

def synthesize_one_group(group):
    topic_lines_text = build_topic_lines(labels_df, GROUPBY_FIELD, group=group)
    prompt = build_per_group_prompt(group, topic_lines_text)
    result = _call_with_retry(prompt)
    if result is None:
        print(f"WARNING: synthesis failed for group '{group}' — excluded")
        return group, None
    slug  = slugify_group_value(group)
    fpath = OUT("analysis", f"llm_synthesis_{slug}.txt")
    with open(fpath, "w") as f:
        f.write(result)
    return group, result

per_group_results = {}
with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    futures = {executor.submit(synthesize_one_group, g): g for g in groups}
    for future in as_completed(futures):
        group, result = future.result()
        if result is not None:
            per_group_results[group] = result
        print(f"Done: {group}")

per_group_results = {g: per_group_results[g] for g in groups if g in per_group_results}
# Out:
# ── CROSS-GROUP ──────────────────────────────────────────
# 1. RECURRING INTERNAL SPLITS
#
# One recurring internal split is the focus on English Language Learners (ELLs) and diverse cultural backgrounds within the "Art Supplies" and "Virtual Visitors" groups. In "Art Supplies," the topic "Art Supplies for Diverse English Language Learners in Low-Income Communities" highlights requests centered around celebrating students' identities through art to promote inclusivity. Similarly, in "Virtual Visitors," the topic "Support for Urban English Language Learners Receiving Free/Reduced Lunch for Arts Education" focuses on reducing barriers for ELLs' participation in arts programs. Both groups reveal a nuanced understanding of how art and cultural representation intersect with language learning.
#
# Another split is observed in the "Computers & Tablets" and "Instructional Technology" groups, where the use of technology to support English Language Learners appears. In "Computers & Tablets," the topic "Supporting English Language Learners with Translation Tools" highlights technology use for bridging language gaps. Similarly, in "Instructional Technology," the topic "Support for English Language Learners' Literacy Skills through Bilingual Resources" emphasizes technology's role in literacy development. This reflects a broader educational trend of utilizing digital tools to address language learning challenges.
#
# 2. CROSS-GROUP SIGNATURES
#
# The Ron Clark Academy appears as a cross-group signature within "Awaiting Classification" and "Virtual Trips." In "Awaiting Classification," topics like "Ron Clark Academy Professional Development for Engaging Diverse Student Populations" and "Innovative Professional Development at Ron Clark Academy" emphasize the institution's methodologies for enhancing classroom engagement and teacher energy. Similarly, in "Virtual Trips," "Ron Clark Academy Training for Engaging Elementary Educators" suggests a similar focus on transformative educational strategies. This repetition signals the Academy's significant impact and reputation as a provider of innovative professional development tailored to diverse educational contexts.
#
# Social-emotional learning (SEL) emerges as another cross-group signature in both "Art Supplies" and "Flexible Seating." In "Art Supplies," the topic "Social Emotional Learning Tools for Mindfulness and Self-Regulation" addresses the use of resources for emotional and social well-being. In "Flexible Seating," "Calm Down Corners for Emotional Self-Regulation in Special Education" emphasizes providing safe spaces for students to manage emotions. This indicates a unified commitment across groups to integrate SEL into education, underscoring its critical role in fostering an inclusive and supportive environment.
#
# 3. FRAMING DIFFERENCES
#
# In the "Books" group, there is a notable framing difference between "Bilingual Book Access for English Language Learners" and "Diverse Literary Texts for Culturally Responsive Teaching." The former emphasizes leveraging bilingual books to support language development among ELLs, highlighting gratitude for resources. The latter uses diverse texts to foster cultural empathy and understanding, focusing less on language acquisition and more on social education. This shift in emphasis underscores differing goals: language proficiency versus cultural literacy.
#
# In "Sports & Exercise Equipment," the topics "Incentive-Based Behavior Reinforcement for Kindergarteners" and "Recess Equipment for Active Play and Social Skills Development" present similar objectives through different lenses. The former focuses on structured behavior management using incentives, while the latter emphasizes unsupervised play to develop social skills. The framing difference reflects a strategic choice between direct intervention and a more laissez-faire, experiential approach to social development.
#
# 4. NOTABLE ABSENCES
#
# Within the "Musical Instruments" group, a notable absence is dedicated support for students with disabilities accessing music education. While topics like "Support for Free and Reduced Price Lunch Students to Access Music Instruments" and "Music Education for Racial Minority Students in Urban Montessori Schools" address socio-economic and racial disparities, there is no explicit focus on inclusive music education for students with disabilities, despite the specific needs these students might have.
#
# In "Lab Equipment," while multiple topics recognize the importance of engaging students in STEM (e.g., "STEM Skills Development through Problem-Solving Engineering Projects for Elementary Students"), there is no topic addressing the specific challenges or solutions for rural STEM education despite the known resource limitations in rural settings. Given the direct attention to urban hydroponics and technology-focused STEM, the absence is conspicuous.
#
# 5. REQUEST TRIGGERS AND PITCH STRATEGIES
#
# For the "Sports & Exercise Equipment" group, teachers frequently frame requests in terms of improving health and social outcomes, as seen in "Health and Fitness Improvement through Physical Exercise Programs for Youth" and "Recess Equipment for Active Play and Social Skills Development." The emphasis is often on holistic development—enhancing physical well-being along with academic and social skills—setting a broad, multi-faceted rationale for requests.
#
# In the "Virtual Trips" group, the pitch strategy for topics such as "Science Field Trips for Economically Disadvantaged Students" focuses on removing barriers to unique educational experiences. Teachers emphasize experiential learning opportunities that financially disadvantaged students could not access otherwise, thus appealing to donors’ sense of equity and broadening students' educational horizons as a compelling justification for funding.
# Done: Art Supplies
# Done: Awaiting Classification
# Done: Classroom Basics
# Done: Flexible Seating
# Done: Computers & Tablets
# Done: Books
# Done: Educational Kits & Games
# Done: Food, Clothing & Hygiene
# Done: Virtual Visitors
# Done: Instructional Technology
# Done: Virtual Trips
# Done: Reading Nooks, Desks & Storage
# Done: Lab Equipment
# Done: Sports & Exercise Equipment
# Done: Musical Instruments

# %%
# ── EXTERNAL-FACING INSIGHTS — structured JSON call ───────────────────────

synthesis_input = "\n\n".join([
    f"=== CROSS-GROUP ANALYSIS ===\n{synthesis_cross}",
    *[f"=== {group} ===\n{text}"
      for group, text in per_group_results.items()]
])

INSIGHTS_SYSTEM = (
    "You are a senior program analyst at an educational nonprofit. "
    "You write precise, decision-facing briefings for external audiences: "
    "foundations, corporate partners, policymakers, and major donors. "
    "You will return ONLY valid JSON. No preamble, no explanation, no markdown fences."
)

INSIGHTS_PROMPT = f"""
You are given a comprehensive structured analysis of classroom project request patterns including:
within-group subthemes, cross-group signatures, framing differences, notable absences,
and request triggers and pitch strategies.

{synthesis_input}

Your task: produce a decision-facing insights document for external stakeholders —
executives, foundation leaders, state legislators, and major donors — who are
intelligent but not close to classroom realities. These readers should finish each
insight thinking: "I never would have known that, and the fact that this organization
can see it means I should take their priorities seriously."

SELECTION CRITERIA:
- ~8-15 cross-category insights (use judgment)
- 2-4 per-category insights for each major category
- Each insight must: surface something genuinely non-obvious about what classrooms need,
  reframe how a thoughtful outsider should interpret teacher demand, and have a clear
  implication for where attention or resources should go
- Prioritize insights that reveal hidden scale, misallocated attention, or a shift in
  how teachers are operating that external stakeholders would not expect
- Avoid: methodological commentary, insights that only matter to data practitioners,
  observations that confirm what the category label already suggests

INSIGHT STRUCTURE — for every insight use exactly these fields:
- title: a crisp, declarative headline that makes the finding feel like a reveal —
  not a description. Should read like a finding, not a topic label.
- what_seeing: 2-4 sentences describing the observed pattern in plain, concrete language.
  Write about what teachers are actually doing or asking for — not about the data.
  Make it vivid enough that a reader who has never seen a classroom request can picture it.
- why_easy_to_miss: 1-2 sentences explaining why this pattern is invisible to someone
  looking at surface-level categories or conventional reporting. Keep it tight —
  this is the "aha" setup, not the payoff.
- what_it_means: the payoff. 2-4 sentences that translate the pattern into consequence.
  This should land like a strategic implication, not an analytical note. Avoid
  abstract hedging. Write toward: what this means for where money goes, what gets
  underfunded by accident, or what this organization is uniquely positioned to address.
  The reader should feel informed and compelled, not instructed.
- source_topics: list of objects, one per grounding topic.
  Format: [{{"group": "<exact group value>", "topic_id": <integer>}}, ...]
  Example: [{{"group": "Art Supplies", "topic_id": 3}},
            {{"group": "Books", "topic_id": 7}}]
  Use the exact group value as it appears in the topic list above.
- section: one of "key_insights", "appendix", or a category name matching the group exactly

STYLE:
- Direct, confident, and human — not academic, not corporate
- No mention of "topics", "model", "NMF", "pipeline", "cluster", or
  analytical machinery whatsoever
- No hedging phrases like "may suggest" or "could indicate" — write declaratively
- No filler. Every sentence should either reveal something or sharpen the implication.
- Do not repeat the same implication across insights

Return a JSON object with this structure:
{{
  "key_insights": [/* 8-15 insight objects */],
  "appendix": [/* secondary insight objects */],
  "by_category": {{
    "<category name>": [/* 2-4 insight objects */],
    ...
  }}
}}
""".strip()

resp = client.chat.completions.create(
    model=MODEL_SYNTHESIS,
    messages=[
        {"role": "system", "content": INSIGHTS_SYSTEM},
        {"role": "user",   "content": INSIGHTS_PROMPT},
    ],
    response_format={"type": "json_object"},
)

raw_json = resp.choices[0].message.content.strip()
insights_data = json.loads(raw_json)

with open(OUT("analysis", "insights_structured.json"), "w") as f:
    json.dump(insights_data, f, indent=2)

print(f"Key insights:  {len(insights_data.get('key_insights', []))}")
print(f"Appendix:      {len(insights_data.get('appendix', []))}")
print(f"Categories:    {list(insights_data.get('by_category', {}).keys())}")
# Out:
# Key insights:  8
# Appendix:      0
# Categories:    ['Art Supplies', 'Books', 'Virtual Trips']

# %%
VERIFY_SYSTEM = (
    "You are checking whether topic labels correctly support a given insight. "
    "Be strict. If the topic is only loosely related, drop it. "
    "Return only valid JSON."
)

def verify_source_topics(insight, labels_df, groupby_field):
    title         = insight.get("title", "")
    what_seeing   = insight.get("what_seeing", "")
    what_it_means = insight.get("what_it_means", "")
    source_topics = insight.get("source_topics", [])

    if not source_topics:
        return insight

    topic_lines = []
    for src in source_topics:
        if isinstance(src, dict):
            group = src.get("group", "")
            tid   = str(src.get("topic_id", ""))
        elif isinstance(src, str) and "|" in src:
            group, tid = src.rsplit("|", 1)
        else:
            continue

        match = labels_df[
            (labels_df[groupby_field] == group) &
            (labels_df["topic_id"]    == int(tid))
        ]
        if not match.empty:
            row = match.iloc[0]
            topic_lines.append(
                f"  {group}|{tid} | label: {row['proposed_label']} | "
                f"description: {row['description']}"
            )

    if not topic_lines:
        return insight

    prompt = f"""
Insight title: {title}

What we're seeing: {what_seeing}

What it means: {what_it_means}

Claimed source topics:
{chr(10).join(topic_lines)}

For each claimed source topic, decide: does this topic label and description
directly support the insight above, or is it only loosely related or irrelevant?

Rules:
- Keep a topic only if its label or description contains language that
  directly grounds a specific claim in the insight.
- Drop it if the connection requires inference, analogy, or category-level association.
- Do not add new topics.

Return JSON: {{"verified_topics": [{{"group": "...", "topic_id": <int>}}, ...]}}
""".strip()

    resp = client.chat.completions.create(
        model=MODEL_SYNTHESIS,
        messages=[
            {"role": "system", "content": VERIFY_SYSTEM},
            {"role": "user",   "content": prompt},
        ],
        response_format={"type": "json_object"},
    )
    result = json.loads(resp.choices[0].message.content)
    insight["source_topics"] = result.get("verified_topics", source_topics)
    return insight

for key in ["key_insights", "appendix"]:
    insights_data[key] = [
        verify_source_topics(i, labels_df, GROUPBY_FIELD)
        for i in insights_data.get(key, [])
    ]

for cat in insights_data.get("by_category", {}):
    insights_data["by_category"][cat] = [
        verify_source_topics(i, labels_df, GROUPBY_FIELD)
        for i in insights_data["by_category"][cat]
    ]

# NOTE: "by_category" is a temporary legacy key name retained in this refactor
# to avoid unnecessary downstream schema changes. Do not rename it in this pass.
for key in ["key_insights", "appendix"]:
    before = len(insights_data.get(key, []))
    insights_data[key] = [i for i in insights_data.get(key, []) if i.get("source_topics")]
    dropped = before - len(insights_data[key])
    if dropped:
        print(f"WARNING: {key}: dropped {dropped} insights with no verified source topics")

for cat in list(insights_data.get("by_category", {}).keys()):
    before = len(insights_data["by_category"][cat])
    insights_data["by_category"][cat] = [
        i for i in insights_data["by_category"][cat] if i.get("source_topics")
    ]
    dropped = before - len(insights_data["by_category"][cat])
    if dropped:
        print(f"WARNING: by_category[{cat}]: dropped {dropped} insights")

with open(OUT("analysis", "insights_structured.json"), "w") as f:
    json.dump(insights_data, f, indent=2)

print("Verification complete.")
# Out:
# WARNING: key_insights: dropped 8 insights with no verified source topics
# WARNING: by_category[Art Supplies]: dropped 1 insights
# WARNING: by_category[Books]: dropped 1 insights
# WARNING: by_category[Virtual Trips]: dropped 1 insights
# Verification complete.

# %%
print("After verification:")
print("  key_insights:", len(insights_data.get("key_insights", [])))
print("  appendix:", len(insights_data.get("appendix", [])))
print("  by_category:", {k: len(v) for k, v in insights_data.get("by_category", {}).items()})

# %%
# ── BUILD DOCX + TRACEABILITY ──────────────────────────────────────────────
assert "project_topic_bridge_df" in dir() and not project_topic_bridge_df.empty, (
    "project_topic_bridge_df missing — ensure Cell 13 ran successfully"
)

def get_project_ids(source_topics, bridge_df, max_ids=None):
    if not source_topics:
        return []
    records = []
    for src in source_topics:
        if isinstance(src, dict):
            group = src.get("group", "")
            tid   = str(src.get("topic_id", ""))
        elif isinstance(src, str) and "|" in src:
            group, tid = src.rsplit("|", 1)
        else:
            continue
        topic_key = f"{GROUPBY_FIELD}={group}|topic={tid}"
        matches   = bridge_df[bridge_df["topic_key"] == topic_key]["project_id"].tolist()
        records.extend(matches)
    seen = list(dict.fromkeys(records))
    return seen if max_ids is None else seen[:max_ids]

def source_topics_to_text(source_topics):
    parts = []
    for src in source_topics or []:
        if isinstance(src, dict):
            parts.append(f"{src.get('group','')}|{src.get('topic_id','')}")
        else:
            parts.append(str(src))
    return "; ".join(parts)

all_insights = (
    [("Key Insights", i) for i in insights_data.get("key_insights", [])]
    + [("Appendix",   i) for i in insights_data.get("appendix", [])]
    + [(cat, i)
       for cat, items in insights_data.get("by_category", {}).items()
       for i in items]
)

CSV_MAX_IDS_PER_INSIGHT = CFG["output"]["csv_max_ids_per_insight"]

traceability_rows = []
for section, insight in all_insights:
    pids = get_project_ids(
        insight.get("source_topics", []),
        project_topic_bridge_df,
        max_ids=CSV_MAX_IDS_PER_INSIGHT,
    )
    for pid in pids:
        traceability_rows.append({
            "section":       section,
            "insight_title": insight.get("title", ""),
            "source_topics": source_topics_to_text(insight.get("source_topics", [])),
            "project_id":    pid,
        })

traceability_df = pd.DataFrame(traceability_rows)
traceability_path = OUT("analysis", "insights_traceability.csv")
traceability_df.to_csv(traceability_path, index=False)
print(f"Traceability rows: {len(traceability_df):,}  →  {traceability_path}")

summary_rows = []
for section, insight in all_insights:
    title         = insight.get("title", "")
    source_topics = insight.get("source_topics", [])

    pids       = get_project_ids(source_topics, project_topic_bridge_df, max_ids=None)
    n_projects = len(pids)

    topic_details = []
    for src in source_topics:
        if isinstance(src, dict):
            group = src.get("group", "")
            tid   = str(src.get("topic_id", ""))
        elif isinstance(src, str) and "|" in src:
            group, tid = src.rsplit("|", 1)
        else:
            continue

        match = labels_df[
            (labels_df[GROUPBY_FIELD] == group) &
            (labels_df["topic_id"]    == int(tid))
        ]
        if not match.empty:
            row = match.iloc[0]
            topic_details.append({
                "group":     group,
                "topic_id":  tid,
                "label":     row["proposed_label"],
                "coherence": row["coherence_flag"],
            })
        else:
            topic_details.append({
                "group":     group,
                "topic_id":  tid,
                "label":     "[not found in labels_df]",
                "coherence": "unknown",
            })

    summary_rows.append({
        "section":       section,
        "insight_title": title,
        "n_projects":    n_projects,
        "n_topics":      len(source_topics),
        "topic_details": topic_details,
    })

for row in summary_rows:
    flag = "  ⚠" if any(t["coherence"] != "coherent" for t in row["topic_details"]) else ""
    print(f"{'─'*80}")
    print(f"[{row['section']}]  {row['insight_title']}{flag}")
    print(f"  Projects: {row['n_projects']:,}   |   Source topics: {row['n_topics']}")
    for t in row["topic_details"]:
        coherence_note = f"  ⚠ {t['coherence']}" if t["coherence"] != "coherent" else ""
        print(f"    • {t['group']} / topic {t['topic_id']}: {t['label']}{coherence_note}")
    print()

flat_rows = []
for row in summary_rows:
    insight_total = row["n_projects"]

    for t in row["topic_details"]:
        topic_pids = get_project_ids(
            [{"group": t["group"], "topic_id": t["topic_id"]}],
            project_topic_bridge_df,
            max_ids=None,
        )
        flat_rows.append({
            "section":        row["section"],
            "insight_title":  row["insight_title"],
            "n_projects_insight": insight_total,
            "n_projects_topic":   len(topic_pids),
            "n_topics":       row["n_topics"],
            "group":          t["group"],
            "topic_id":       t["topic_id"],
            "topic_label":    t["label"],
            "coherence":      t["coherence"],
        })

summary_df = pd.DataFrame(flat_rows)
summary_path = OUT("analysis", "insights_topic_summary.csv")
summary_df.to_csv(summary_path, index=False)
print(f"Summary rows: {len(summary_df):,}  →  {summary_path}")

def add_heading(doc, text, level):
    p = doc.add_heading(text, level=level)
    p.runs[0].font.color.rgb = RGBColor(0, 0, 0)
    return p

def add_insight(doc, insight):
    p = doc.add_paragraph()
    run = p.add_run(insight.get("title", ""))
    run.bold = True
    run.font.size = Pt(11)

    for label, key in [
        ("What we're seeing:",          "what_seeing"),
        ("Why this is easy to miss:",   "why_easy_to_miss"),
        ("What this means for funders:","what_it_means"),
    ]:
        p = doc.add_paragraph()
        label_run = p.add_run(label + "  ")
        label_run.bold = True
        label_run.font.size = Pt(10)
        body_run = p.add_run(insight.get(key, ""))
        body_run.font.size = Pt(10)
        p.paragraph_format.space_after = Pt(2)

    doc.add_paragraph()

doc = Document()

for section in doc.sections:
    section.top_margin    = Inches(1)
    section.bottom_margin = Inches(1)
    section.left_margin   = Inches(1)
    section.right_margin  = Inches(1)

style = doc.styles["Normal"]
style.font.name = "Arial"
style.font.size = Pt(10)

add_heading(doc, "Investigated Across Project Categories", level=1)
add_heading(doc, "Key Insights", level=2)

for insight in insights_data.get("key_insights", []):
    add_insight(doc, insight)

if insights_data.get("appendix"):
    add_heading(doc, "Appendix", level=2)
    for insight in insights_data["appendix"]:
        add_insight(doc, insight)

add_heading(doc, "By Category", level=1)

for category, items in insights_data.get("by_category", {}).items():
    add_heading(doc, category, level=2)
    for insight in items:
        add_insight(doc, insight)

docx_path = OUT("analysis", "R_I_Trends_generated.docx")
doc.save(docx_path)
print(f"Docx saved → {docx_path}")
print(f"Open and compare against R_I_Trends__Prototype_Checkpoint__1_.docx")
# Out:
# Traceability rows: 0  →  /Users/matt.fritz/Desktop/Research Insights/Essay Prototype/OUTPUTS/project_category/2026-03-27/analysis/insights_traceability.csv
# Summary rows: 0  →  /Users/matt.fritz/Desktop/Research Insights/Essay Prototype/OUTPUTS/project_category/2026-03-27/analysis/insights_topic_summary.csv
# Docx saved → /Users/matt.fritz/Desktop/Research Insights/Essay Prototype/OUTPUTS/project_category/2026-03-27/analysis/R_I_Trends_generated.docx
# Open and compare against R_I_Trends__Prototype_Checkpoint__1_.docx
