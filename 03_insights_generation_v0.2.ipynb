# %% [markdown]
# # Trend Tracker — Notebook 03: Insights Generation
#
# Builds feature matrices and runs all Phase 1 analytical work on the clean
# corpus from `01_preprocess.ipynb`. `make_vec`, `add_bin`, and `group_key` —
# all imported from `utils.py` — are shared across Steps 1, 3, and 4, which is
# the main reason those three live together.
#
# | Step | What | Key output |
# |------|------|------------|
# | 1 | Build TF-IDF matrices | `features/X_*.npz`, `vocab/vocab_*.csv` |
# | 2 | Quality CP2 | `quality/quality_cp2.json` |
# | 3 | Category TF-IDF | `analysis/category_tfidf.csv` |
# | 4 | NMF topic discovery | `analysis/nmf_topics.csv`, `nmf_weights.csv` |
# | 5 | LLM topic labeling | `analysis/llm_topic_labels.json` |

# %% [markdown]
# ## Setup

# %%
import sys, json, re, unicodedata
from copy import deepcopy
from pathlib import Path
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed
from collections import defaultdict
from statistics import mean
import time as _time
import openai as _openai

import pandas as pd
import numpy as np
import scipy.sparse as sp
from sklearn.decomposition import NMF
from docx import Document
from docx.shared import Pt, RGBColor, Inches
from docx.enum.text import WD_ALIGN_PARAGRAPH

ROOT = Path(".")
sys.path.insert(0, str(ROOT))
from utils import (
    load_cfg, tokens_to_str, make_vec, add_bin, group_key, quality_report,
    build_run_output_path, get_run_date, get_llm_client, build_project_topic_bridge,
    slugify_group_value, canonicalize_filter_spec, get_filter_fields_key, get_run_id,
    apply_filters, ensure_warning_file, append_warning, write_json, artifact_meta,
    start_stage_manifest, finalize_stage_manifest, build_pipeline_manifest,
    load_essay_snippet_lookup, get_warning_count
)

CFG = load_cfg()
ct = CFG["tfidf"]
client = get_llm_client()

raw_df = pd.read_parquet(ROOT / "OUTPUTS/prepared/05_enriched.parquet")
print(f"Loaded {len(raw_df):,} projects  |  {raw_df.shape[1]} columns")
# Out:
# Loaded 896,277 projects  |  45 columns

# %% [markdown]
# ---
# ## Parameters
#
# All tunable values live here. Edit this cell; do not edit parameter references in downstream cells.

# %%
# ── All parameters from params.yaml — edit there, not here ──────────────
GROUPBY_FIELD       = CFG["analysis"]["group_by"]
GROUP_DESCRIPTION   = CFG["analysis"]["group_descriptions"].get(
                          GROUPBY_FIELD,
                          f"groups defined by '{GROUPBY_FIELD}' in DonorsChoose data")
MIN_SHARED          = CFG["analysis"]["nmf_min_shared"]
MIN_COVERAGE        = CFG["analysis"]["min_coverage"]
N_COMPONENTS        = CFG["nmf"]["n_components"]
CAT_TFIDF_TOP_N     = CFG["analysis"]["cat_tfidf_top_n"]
N_REPRESENTATIVE    = CFG["llm"]["n_representative_snippets"]
TOP_TERMS_IN_PROMPT = CFG["llm"]["top_terms_in_prompt"]
REVIEW_GROUP        = CFG["analysis"]["review_group"]
EXCLUDE_GROUPS      = CFG["analysis"]["exclude_groups"]
MAX_WORKERS         = CFG["analysis"]["synthesis_max_workers"]
LABELING_MAX_WORKERS = CFG["analysis"].get("labeling_max_workers", MAX_WORKERS)
MODEL_LABELING      = CFG["models"]["labeling"]
MODEL_SYNTHESIS     = CFG["models"]["synthesis"]

FILTER_LOGIC = CFG["analysis"].get("filter_logic", "and")
FILTERS      = CFG["analysis"].get("filters", [])
FILTER_SPEC  = canonicalize_filter_spec(FILTER_LOGIC, FILTERS)
FILTER_FIELDS_KEY = get_filter_fields_key(FILTERS)

df, filter_summary = apply_filters(raw_df, FILTER_LOGIC, FILTERS)
if filter_summary["no_rows_after_filter"]:
    raise ValueError("No rows remain after applying analysis filters.")

RUN_DATE = get_run_date()
RUN_ID   = get_run_id(GROUPBY_FIELD, FILTER_SPEC)

def OUT(subdir, fname):
    return build_run_output_path(
        subdir=subdir,
        fname=fname,
        groupby_field=GROUPBY_FIELD,
        run_date=RUN_DATE,
        run_id=RUN_ID,
    )

WARNINGS_PATH = OUT("metadata", "warnings_03.jsonl")
ensure_warning_file(WARNINGS_PATH)

FILTER_SPEC_PATH = OUT("metadata", "filter_spec.json")
FILTER_SUMMARY_PATH = OUT("metadata", "filter_summary.json")
write_json(FILTER_SPEC_PATH, {
    "schema_version": "v1",
    "run_id": RUN_ID,
    "group_by_field": GROUPBY_FIELD,
    "filter_fields_key": FILTER_FIELDS_KEY,
    "filter_logic": FILTER_LOGIC,
    "filters": FILTERS,
})
write_json(FILTER_SUMMARY_PATH, {
    "schema_version": "v1",
    "run_id": RUN_ID,
    "group_by_field": GROUPBY_FIELD,
    **filter_summary,
})

STAGE_MANIFEST = start_stage_manifest(
    stage_name="03_insights_generation",
    notebook_file="03_insights_generation_v0.1.ipynb",
    run_id=RUN_ID,
    group_by_field=GROUPBY_FIELD,
    filter_fields_key=FILTER_FIELDS_KEY,
)

bins       = CFG["analysis"].get("bins", [])
group_cols = [GROUPBY_FIELD, "bin"] if bins else [GROUPBY_FIELD]

print(f"RUN_ID           = {RUN_ID}")
print(f"GROUPBY_FIELD    = {GROUPBY_FIELD!r}")
print(f"FILTER_FIELDS_KEY= {FILTER_FIELDS_KEY}")
print(f"Filtered rows    = {len(df):,} / {len(raw_df):,}")
print(f"Output path      = OUTPUTS/runs/{GROUPBY_FIELD}/{RUN_DATE}/{RUN_ID}/")
# Out:
# RUN_ID           = 20260331_101735_posted_year_quarter_a36f58b0
# GROUPBY_FIELD    = 'posted_year_quarter'
# FILTER_FIELDS_KEY= none
# Filtered rows    = 896,277 / 896,277
# Output path      = OUTPUTS/runs/posted_year_quarter/2026-03-31/20260331_101735_posted_year_quarter_a36f58b0/

# %% [markdown]
# ---
# ## Step 1 — Build TF-IDF Matrices
#
# One vectorizer fit per n-gram range on the full corpus. Trigrams are persisted
# even if unused in Phase 1 analysis — Phase 2+ inherits them without re-extraction.

# %%
# Cache once — reused by Cells 10 and 12
docs = df["tokens"].apply(tokens_to_str).tolist()
specs = {"X_unigram": (1,1), "X_bigram": (2,2), "X_unigram_bigram": (1,2)}
if CFG["ngrams"]["max_n"] >= 3:
    specs["X_trigram"] = (3, 3)

matrices, vecs = {}, {}
for name, rng in specs.items():
    vec            = make_vec(ct["min_df"], ct["max_df"], rng)
    matrices[name] = vec.fit_transform(docs)
    vecs[name]     = vec
    sz, nnz        = matrices[name].shape, matrices[name].nnz
    print(f"  {name:20s}: shape={sz}  sparsity={1 - nnz/(sz[0]*sz[1]):.3f}")

for name, vec in vecs.items():
    (pd.DataFrame({"feature": vec.get_feature_names_out(), "idf": vec.idf_})
       .sort_values("idf")
       .to_csv(OUT("vocab", f"vocab_{name}.csv"), index=False))

feat_dir = OUT("features", "_anchor").parent
feat_dir.mkdir(parents=True, exist_ok=True)
for name, X in matrices.items():
    sp.save_npz(feat_dir / f"{name}.npz", X.tocsr())

META_COLS = [c for c in [
    "project_id", "project_category", "posted_date", "funded_date",
    "metro_type_at_time_of_posting", "grade_band", "theme_version",
    "posted_year", "posted_year_quarter", "school_is_low_income"
] if c in df.columns]
meta = df[META_COLS].reset_index(drop=True)
try:
    meta.to_parquet(feat_dir / "meta.parquet", index=False)
except ImportError:
    meta.to_csv(feat_dir / "meta.csv", index=False)

assert matrices["X_unigram"].shape[0] == len(df)
# Out:
#   X_unigram           : shape=(896277, 7296)  sparsity=0.992
#   X_bigram            : shape=(896277, 932870)  sparsity=1.000
#   X_unigram_bigram    : shape=(896277, 940166)  sparsity=1.000
#   X_trigram           : shape=(896277, 691995)  sparsity=1.000

# %% [markdown]
# ---
# ## Step 2 — Quality Report: Checkpoint 2

# %%
qr2 = quality_report(df, label="cp2", matrices=matrices,
                     save_path=OUT("quality", "quality_cp2.json"))
# Out:
# =======================================================  [cp2]
#   Projects : 896,277
#   Tok/proj : min=5  p50=70  max=109
#   Vocab    : 7,447 unique tokens
#   X_unigram           : shape=[896277, 7296]  sparsity=0.992
#   X_bigram            : shape=[896277, 932870]  sparsity=1.000
#   X_unigram_bigram    : shape=[896277, 940166]  sparsity=1.000
#   X_trigram           : shape=[896277, 691995]  sparsity=1.000
#   Stopwords: FAIL — ['project', 'grade', 'teacher', 'education']
# =======================================================

# %% [markdown]
# ---
# ## Step 3 — Category TF-IDF
#
# The vectorizer is fit **once** on the full corpus; category slices are scored
# by index. This avoids the string-comparison bug (identical token sets across
# projects would misclassify rows) and is much faster than refitting per slice.
#
# **Contrast** = token prevalence in this category minus prevalence outside it.
#
# Time bins: defined in `params.yaml` under `analysis.bins`; leave empty for
# the full date range.

# %%
top_n     = CAT_TFIDF_TOP_N
min_proj  = CFG["analysis"]["min_group_projects"]

df_work   = add_bin(df, bins) if bins else df.copy()
df_work   = df_work.reset_index(drop=True)
all_docs  = (df_work["tokens"].apply(tokens_to_str).tolist() if bins else docs)
vec_cat   = make_vec(ct["min_df"], ct["max_df"], tuple(ct["ngram_range"]))
X_full    = vec_cat.fit_transform(all_docs)
feat      = vec_cat.get_feature_names_out()
idf_vals  = vec_cat.idf_

def cat_tfidf_slice(idx):
    """Score category slice by index against the rest of the corpus."""
    rest_idx  = df_work.index.difference(idx)
    X_cat     = X_full[idx.tolist()]
    X_rest    = X_full[rest_idx.tolist()]
    cat_prev  = (X_cat  > 0).mean(axis=0).A1
    rest_prev = (X_rest > 0).mean(axis=0).A1 if len(rest_idx) else np.zeros(len(feat))
    tf        = X_cat.mean(axis=0).A1
    return (pd.DataFrame({
                "token":         feat,
                "tf":            tf,
                "idf":           idf_vals,
                "tfidf":         tf * idf_vals,
                "prevalence":    cat_prev,
                "contrast":      cat_prev - rest_prev,
                "project_count": (X_cat > 0).sum(axis=0).A1.astype(int),
            }).nlargest(top_n, "tfidf"))

rows = []
for keys, sub in df_work.groupby(group_cols, observed=True):
    if len(sub) < min_proj:
        continue
    kd  = group_key(keys, group_cols)
    top = cat_tfidf_slice(sub.index)
    for col, val in kd.items():
        top.insert(0, col, val)
    rows.append(top)

if not rows:
    raise RuntimeError(f"No groups met min_proj={min_proj} threshold — lower min_group_projects in params.yaml")
cat_tfidf_df = pd.concat(rows, ignore_index=True)
cat_tfidf_df.to_csv(OUT("analysis", "category_tfidf.csv"), index=False)
print(f"{len(cat_tfidf_df):,} rows  |  {cat_tfidf_df[group_cols[0]].nunique()} groups")
cat_tfidf_df.head(10)
# Out:
# 960 rows  |  48 groups
#   posted_year_quarter         token        tf       idf     tfidf  prevalence  \
# 0         2014.0_Q3.0    technology  0.010660  2.934678  0.031283    0.302490
# 1         2014.0_Q3.0          ipad  0.007725  4.024065  0.031087    0.159948
# 2         2014.0_Q3.0      donation  0.007472  3.598766  0.026889    0.166758
# 3         2014.0_Q3.0  reduce lunch  0.006012  4.437528  0.026676    0.112686
# 4         2014.0_Q3.0   common core  0.004535  5.862824  0.026588    0.065561
# 5         2014.0_Q3.0          read  0.012458  2.128470  0.026517    0.482457
# 6         2014.0_Q3.0         level  0.009372  2.774475  0.026003    0.281439
# 7         2014.0_Q3.0         grade  0.011174  2.297307  0.025670    0.405201
# 8         2014.0_Q3.0          able  0.011943  2.125165  0.025382    0.461819
# 9         2014.0_Q3.0         there  0.008129  3.068653  0.024946    0.223101
#
#    contrast  project_count
# 0  0.160626           4397
# 1  0.113181           2325
# 2  0.093917           2424
# 3  0.081871           1638
# 4  0.058787            953
# 5  0.161550           7013
# 6  0.113712           4091
# 7  0.134110           5890
# 8  0.139483           6713
# 9  0.098341           3243

# %% [markdown]
# ---
# ## Step 4 — NMF Topic Discovery
#
# NMF is fit independently per category so the dominant axis in one category
# does not suppress signal in others. Topics are candidates for human review —
# not stable theme definitions (that is Phase 2).
#
# The weights DataFrame records which projects load most strongly on each topic;
# Step 5 uses it to select representative snippets by NMF weight rather than
# randomly.

# %%
cn    = CFG["nmf"]
n_rep = N_REPRESENTATIVE
min_proj = CFG["analysis"]["min_group_projects"]

def nmf_one(docs):
    """Fit NMF on one slice. Returns (topics_df, W) or (None, None)."""
    vec = make_vec(ct["min_df"], ct["max_df"], tuple(ct.get("ngram_range", [1, 1])))
    X   = vec.fit_transform(docs)
    if X.shape[1] < N_COMPONENTS:
        return None, None
    model = NMF(
        n_components=N_COMPONENTS,
        random_state=cn["random_seed"],
        init="nndsvd",
        max_iter=cn["max_iter"],
    )
    W     = model.fit_transform(X)
    vocab = vec.get_feature_names_out()
    rows  = []
    for i, comp in enumerate(model.components_):
        idx = comp.argsort()[::-1][:cn["top_words"]]
        rows.append({
            "topic_id": i,
            "top_terms": vocab[idx].tolist(),
            "top_weights": comp[idx].tolist(),
        })
    return pd.DataFrame(rows), W

all_topics, all_weights = [], []
df_work = add_bin(df, bins) if bins else df.copy()
df_work = df_work.reset_index(drop=True)

NMF_GROUPS_SKIPPED = []
NMF_GROUPS_FAILED = []

for keys, sub in df_work.groupby(group_cols, observed=True):
    kd = group_key(keys, group_cols)
    group_value = kd[GROUPBY_FIELD]

    if len(sub) < min_proj:
        NMF_GROUPS_SKIPPED.append(str(group_value))
        continue

    group_docs = sub["tokens"].apply(tokens_to_str).tolist()
    pids = sub["project_id"].tolist()

    try:
        topics, W = nmf_one(group_docs)
    except Exception as e:
        NMF_GROUPS_FAILED.append(str(group_value))
        append_warning(
            WARNINGS_PATH,
            "03_insights_generation",
            "NMF_GROUP_SKIPPED",
            f"NMF failed for group '{group_value}'",
            context={"group": group_value, "error": str(e)},
        )
        continue

    if topics is None or W is None:
        NMF_GROUPS_FAILED.append(str(group_value))
        append_warning(
            WARNINGS_PATH,
            "03_insights_generation",
            "NMF_GROUP_SKIPPED",
            f"NMF skipped group '{group_value}' because the slice could not produce topics",
            context={"group": group_value},
        )
        continue

    for col, val in kd.items():
        topics[col] = val
    all_topics.append(topics)

    for tid in range(W.shape[1]):
        order = W[:, tid].argsort()[::-1]
        for rank, idx in enumerate(order):
            all_weights.append({
                **kd,
                "topic_id": tid,
                "project_id": pids[idx],
                "weight": float(W[idx, tid]),
                "rank": rank,
            })

if not all_topics:
    raise RuntimeError(
        f"No groups produced NMF topics — check N_COMPONENTS={N_COMPONENTS} vs vocab size, "
        f"or lower min_group_projects"
    )

topics_df  = pd.concat(all_topics, ignore_index=True)
weights_df = pd.DataFrame(all_weights)
topics_df.to_csv(OUT("analysis", "nmf_topics.csv"), index=False)
weights_df.to_csv(OUT("analysis", "nmf_weights.csv"), index=False)
print(f"{len(topics_df):,} topics across {topics_df[group_cols[0]].nunique()} groups")

threshold = CFG["analysis"]["topic_assignment_threshold"]
project_topic_bridge_df = build_project_topic_bridge(weights_df, GROUPBY_FIELD, threshold)
project_topic_bridge_df.to_csv(OUT("analysis", "project_topic_bridge.csv"), index=False)
print(f"Bridge: {len(project_topic_bridge_df):,} project-topic assignments (topic_share >= {threshold})")

topics_df.head(6)
# Out:
# /opt/miniconda3/lib/python3.13/site-packages/sklearn/decomposition/_nmf.py:1728: ConvergenceWarning: Maximum number of iterations 400 reached. Increase it to improve convergence.
#   warnings.warn(
# /opt/miniconda3/lib/python3.13/site-packages/sklearn/decomposition/_nmf.py:1728: ConvergenceWarning: Maximum number of iterations 400 reached. Increase it to improve convergence.
#   warnings.warn(
# 576 topics across 48 groups
# Bridge: 886,403 project-topic assignments (topic_share >= 0.3)
#    topic_id                                          top_terms  \
# 0         0  [live, hard, college, community, life, family,...
# 1         1  [book, reader, read, library, interest, level,...
# 2         2  [lunch, free, reduce, free reduce, reduce lunc...
# 3         3  [technology, ipad, computer, access, app, rese...
# 4         4  [center, fun, math, kindergarten, letter, game...
# 5         5  [science, hand, explore, understand, world, pr...
#
#                                          top_weights posted_year_quarter
# 0  [0.566628625988524, 0.5513008485182201, 0.4691...         2014.0_Q3.0
# 1  [0.8931302411141219, 0.7836193474810513, 0.738...         2014.0_Q3.0
# 2  [1.0709461073622193, 1.0577817997334307, 1.040...         2014.0_Q3.0
# 3  [0.9758612076822559, 0.7488664377686635, 0.726...         2014.0_Q3.0
# 4  [0.5801316179521875, 0.48139062053130893, 0.47...         2014.0_Q3.0
# 5  [0.7553398432984694, 0.47618524115341276, 0.41...         2014.0_Q3.0

# %%
# Cross-group universal themes — terms appearing in NMF topics across many groups
if REVIEW_GROUP is not None:
    _eligible = topics_df[group_cols[0]].unique().tolist()
    if REVIEW_GROUP not in _eligible:
        raise ValueError(f"REVIEW_GROUP={REVIEW_GROUP!r} not found. Eligible: {_eligible}")
else:
    REVIEW_GROUP = df_work.groupby(GROUPBY_FIELD).size().idxmax()

records = [(r[group_cols[0]], frozenset(r.top_terms)) for _, r in topics_df.iterrows()]

theme_cats = defaultdict(set)
for i, (ci, si) in enumerate(records):
    for cj, sj in records[i+1:]:
        if ci == cj:
            continue
        shared = si & sj
        if len(shared) >= MIN_SHARED:
            key = frozenset(shared)
            theme_cats[key] |= {ci, cj}

rows = sorted(theme_cats.items(), key=lambda x: -len(x[1]))
seen = []
deduped = []
for terms, cats in rows:
    if len(cats) < MIN_COVERAGE:
        continue
    if not any(terms <= prior for prior in seen):
        deduped.append({
            "theme": ", ".join(sorted(terms)[:5]),
            "n_groups": len(cats),
            "categories": sorted(cats),
        })
        seen.append(terms)

cross_group_df = pd.DataFrame(deduped).reset_index(drop=True)
cross_group_df.to_csv(OUT("analysis", "cross_group_themes.csv"), index=False)
cross_group_df
# Out:
#                                                  theme  n_groups  \
# 0                              income, low, low income        40
# 1                    book, library, love, read, reader        38
# 2                                paper, pencil, supply        33
# 3                     book, level, library, love, read        33
# 4                                   grade, level, read        29
# ..                                                 ...       ...
# 249                activity, engage, resource, teacher         6
# 250  chair, comfortable, desk, flexible, flexible seat         6
# 251               fine, fine motor, hand, motor, skill         6
# 252                focus, food, healthy, hungry, snack         6
# 253     calm, emotion, emotional, regulate, regulation         6
#
#                                             categories
# 0    [2014.0_Q3.0, 2014.0_Q4.0, 2015.0_Q1.0, 2015.0...
# 1    [2014.0_Q3.0, 2014.0_Q4.0, 2015.0_Q1.0, 2015.0...
# 2    [2014.0_Q3.0, 2014.0_Q4.0, 2015.0_Q2.0, 2015.0...
# 3    [2015.0_Q2.0, 2015.0_Q3.0, 2016.0_Q1.0, 2016.0...
# 4    [2014.0_Q4.0, 2015.0_Q4.0, 2016.0_Q1.0, 2016.0...
# ..                                                 ...
# 249  [2020.0_Q3.0, 2020.0_Q4.0, 2022.0_Q2.0, 2022.0...
# 250  [2021.0_Q2.0, 2022.0_Q3.0, 2023.0_Q2.0, 2024.0...
# 251  [2021.0_Q4.0, 2022.0_Q4.0, 2023.0_Q4.0, 2024.0...
# 252  [2023.0_Q1.0, 2023.0_Q3.0, 2025.0_Q1.0, 2025.0...
# 253  [2023.0_Q4.0, 2024.0_Q2.0, 2025.0_Q1.0, 2025.0...
#
# [254 rows x 3 columns]

# %% [markdown]
# ---
# ## Step 5 — LLM Topic Labeling
#
# One API call per topic on compressed input only — never raw essay text at scale.
# Representative snippets are chosen by NMF weight (not random).
#
# Prompt field limits (`top_unigrams`, `top_bigrams`, `top_nmf_terms`) are applied
# as item counts. Parse failures are stored with enough metadata to debug later.

# %%
SYSTEM = (
    "You are an NLP analyst reviewing NMF topic clusters from DonorsChoose teacher "
    "essays. Respond ONLY with a JSON object, no preamble, no markdown fences.\n\n"
    "Token naming conventions you may see in topic terms:\n"
    "  __framing_[name]__ = a rhetorical framing signal injected during preprocessing "
    "(e.g. __framing_barrier_removal__ means essays removing obstacles to participation)\n"
    "  __cat_[name]__ = a subject matter category token (e.g. __cat_genetics__)\n"
    "  __sub_[name]__ = a subcategory token\n"
    "These are meaningful signals — incorporate them into your label and description.\n\n"
    "Labeling rules:\n"
    "- Prefer the most specific defensible label.\n"
    "- Preserve concrete signals such as named programs, vendors, pedagogies, student "
    "populations, classroom use cases, or rhetorical framing when present.\n"
    "- Do not collapse topics into broad umbrella labels like technology, literacy, "
    "engagement, classroom supplies, or social-emotional learning if the evidence "
    "supports a narrower interpretation.\n"
    "- When framing tokens are present, treat them as first-class evidence about how "
    "teachers are positioning the request, not just background metadata.\n"
    "- If a topic is mixed, say what subthemes are colliding rather than forcing an "
    "overly neat label.\n\n"
    "coherence_flag definitions:\n"
    "  coherent   — terms and representative snippets point clearly to one theme, "
    "population, or use case.\n"
    "  mixed      — two or more distinguishable subthemes are colliding in this topic; "
    "describe what they are in notes.\n"
    "  redundant  — this topic's terms and snippets substantially duplicate another "
    "topic in the same group, not merely overlap in subject area.\n"
    "  unclear    — terms are too scattered or generic to support a defensible label; "
    "the topic does not resolve to a coherent signal."
)
PROMPT = (
    f"Group ({GROUPBY_FIELD}): {{group_value}}{{bin_line}}\n"
    "Topic {topic_id}\n"
    "Top unigrams : {unigrams}\n"
    "Top bigrams  : {bigrams}\n"
    "Top NMF terms: {nmf_terms}\n"
    "Representative project tokens:\n"
    "{snippets}\n\n"
    "Instructions:\n"
    "- proposed_label should be concrete and specific, ideally naming the request or "
    "intervention, the population or context, and the framing when supported.\n"
    "- description should explain what makes this topic distinct from nearby generic topics.\n"
    "- If the topic appears broad, identify the narrower mechanism, use case, or population "
    "if the evidence supports it.\n"
    "- If the evidence is genuinely mixed, preserve that ambiguity instead of inventing a "
    "falsely precise label.\n\n"
    f"Return a JSON object with exactly these keys:\n"
    f"  {GROUPBY_FIELD}, topic_id, proposed_label, description, coherence_flag, notes\n"
    'coherence_flag must be one of: "coherent", "mixed", "redundant", "unclear" '
    "(definitions provided in system instructions)"
)

pid_text = df.set_index("project_id")["tokens"].apply(lambda t: " ".join(t[:40]))

def build_input(t_row):
    terms = t_row["top_terms"]
    key_cols = [GROUPBY_FIELD] + (["bin"] if "bin" in t_row.index else [])
    mask = weights_df["topic_id"] == t_row["topic_id"]
    for col in key_cols:
        mask &= weights_df[col] == t_row[col]
    rep_pids = (
        weights_df[mask]
        .sort_values("weight", ascending=False)["project_id"]
        .tolist()[:N_REPRESENTATIVE]
    )
    n_uni = TOP_TERMS_IN_PROMPT
    n_bi  = max(2, TOP_TERMS_IN_PROMPT // 2)
    n_nmf = TOP_TERMS_IN_PROMPT
    return {
        "group_value": t_row[GROUPBY_FIELD],
        "topic_id": int(t_row["topic_id"]),
        "bin_line": f"\nBin: {t_row['bin']}" if "bin" in t_row.index and pd.notna(t_row.get("bin")) else "",
        "unigrams":  ", ".join([x for x in terms if " " not in x][:n_uni]),
        "bigrams":   ", ".join([x for x in terms if " " in  x][:n_bi]),
        "nmf_terms": ", ".join(terms[:n_nmf]),
        "snippets":  "\n".join(f"- {pid_text.get(p, '')}" for p in rep_pids),
    }

def _make_label_error(inp, raw_text, code, error_text=None):
    return {
        "raw": raw_text,
        "parse_error": True,
        "error_code": code,
        "error": error_text,
        "model": MODEL_LABELING,
        "timestamp": datetime.now().isoformat(),
        GROUPBY_FIELD: inp["group_value"],
        "topic_id": inp["topic_id"],
    }

def _label_with_retry(inp, max_retries=3):
    text = ""
    for attempt in range(max_retries + 1):
        try:
            resp = client.chat.completions.create(
                model=MODEL_LABELING,
                messages=[
                    {"role": "system", "content": SYSTEM},
                    {"role": "user", "content": PROMPT.format(**inp)},
                ],
            )
            text = resp.choices[0].message.content.strip()
            obj = json.loads(text)
            obj["model"] = MODEL_LABELING
            obj["timestamp"] = datetime.now().isoformat()
            return obj
        except json.JSONDecodeError as e:
            if attempt < max_retries:
                _time.sleep(2 ** attempt)
                continue
            append_warning(
                WARNINGS_PATH,
                "03_insights_generation",
                "LABELING_PARSE_FAILURE",
                f"Topic labeling JSON parse failure for {inp['group_value']} / topic {inp['topic_id']}",
                context={"group": inp["group_value"], "topic_id": inp["topic_id"], "error": str(e)},
            )
            return _make_label_error(inp, text, "LABELING_PARSE_FAILURE", str(e))
        except (_openai.RateLimitError, _openai.APITimeoutError) as e:
            if attempt < max_retries:
                _time.sleep(2 ** attempt)
            else:
                append_warning(
                    WARNINGS_PATH,
                    "03_insights_generation",
                    "LABELING_API_FAILURE",
                    f"Topic labeling failed after retries for {inp['group_value']} / topic {inp['topic_id']}",
                    context={"group": inp["group_value"], "topic_id": inp["topic_id"], "error": str(e)},
                )
                return _make_label_error(inp, text or str(e), "LABELING_API_FAILURE", str(e))
        except Exception as e:
            append_warning(
                WARNINGS_PATH,
                "03_insights_generation",
                "LABELING_API_FAILURE",
                f"Topic labeling failed for {inp['group_value']} / topic {inp['topic_id']}",
                context={"group": inp["group_value"], "topic_id": inp["topic_id"], "error": str(e)},
            )
            return _make_label_error(inp, text or str(e), "LABELING_API_FAILURE", str(e))

topic_inputs = [build_input(t) for _, t in topics_df.iterrows()]

def _norm_group_value(value):
    return str(value or "").strip().casefold()

def _safe_topic_id(value):
    try:
        return int(float(value))
    except (TypeError, ValueError):
        return -1

topic_order = {
    (_norm_group_value(inp["group_value"]), int(inp["topic_id"])): i
    for i, inp in enumerate(topic_inputs)
}

results = []
with ThreadPoolExecutor(max_workers=LABELING_MAX_WORKERS) as executor:
    futures = {executor.submit(_label_with_retry, inp): inp for inp in topic_inputs}
    for future in as_completed(futures):
        inp = futures[future]
        obj = future.result()
        results.append(obj)
        print(f"  {inp['group_value']} / topic {inp['topic_id']} → {obj.get('proposed_label', '?')}")

for r in results:
    norm_key = (_norm_group_value(r.get(GROUPBY_FIELD, "")), _safe_topic_id(r.get("topic_id", -1)))
    if norm_key not in topic_order:
        append_warning(
            WARNINGS_PATH,
            "03_insights_generation",
            "LABELING_SORT_KEY_MISMATCH",
            f"Label result did not match deterministic sort key for {r.get(GROUPBY_FIELD, '')} / topic {r.get('topic_id', '')}",
            context={"group": r.get(GROUPBY_FIELD, ""), "topic_id": r.get("topic_id", "")},
        )

results = sorted(
    results,
    key=lambda r: topic_order.get(
        (_norm_group_value(r.get(GROUPBY_FIELD, "")), _safe_topic_id(r.get("topic_id", -1))),
        10**9
    )
)

with open(OUT("analysis", "llm_topic_labels.json"), "w", encoding="utf-8") as f:
    json.dump(results, f, indent=2, ensure_ascii=False, default=str)
print(f"\n{len(results)} labels saved")
# Out:
#   2014.0_Q3.0 / topic 0 → College-and-career aspiration framing for high-poverty students
#   2014.0_Q3.0 / topic 1 → Independent reading books for leveled, interest-based library access
#   2014.0_Q3.0 / topic 5 → Hands-on inquiry science for critical thinking and problem solving
#   2014.0_Q3.0 / topic 6 → Special education access for students with autism, speech-language, and severe disabilities
#   2014.0_Q3.0 / topic 7 → Low-income classroom basic supplies and consumables for hands-on work
#   2014.0_Q3.0 / topic 2 → Free/Reduced-Lunch Title I Students Needing Basic Learning Materials and Books
#   2014.0_Q3.0 / topic 3 → Rural access-to-technology requests for iPads/tablets and home computer/internet access
#   2014.0_Q3.0 / topic 4 → Kindergarten and early-grade literacy-math learning centers with manipulatives and games
#   2014.0_Q3.0 / topic 8 → Elementary band, chorus, and general music performance instruments
#   2014.0_Q3.0 / topic 10 → Flexible carpet-and-seating space for group work and reading in elementary classrooms
#   2014.0_Q3.0 / topic 9 → ESL/ELL literacy support for Spanish-speaking, newly arrived English learners
#   2014.0_Q4.0 / topic 0 → Barrier-removal support for high-poverty, family-disrupted students
#   2014.0_Q4.0 / topic 2 → Free/Reduced-Lunch Title I Support for Low-Income Early Elementary Classrooms
#   2014.0_Q4.0 / topic 1 → Take-Home Book Collections for Independent Reading and Comprehension Growth
#   2014.0_Q3.0 / topic 11 → Common Core nonfiction magazine subscriptions for informational text and current events
#   2014.0_Q4.0 / topic 3 → Student technology access for computer-based practice, research, and online assignment tools
#   2014.0_Q4.0 / topic 4 → Flexible seating and movement supports for kinesthetic/ADHD students
#   2014.0_Q4.0 / topic 5 → Kindergarten literacy-math centers for alphabet, number sense, and word practice
#   2014.0_Q4.0 / topic 6 → AAC and assistive communication support for special education students with autism, speech/language, and developmental disabilities
#   2014.0_Q4.0 / topic 9 → Low-income family literacy and math access via books, devices, and homework support
#   2014.0_Q4.0 / topic 10 → Hands-on STEM inquiry and science exploration materials for young elementary students
#   2014.0_Q4.0 / topic 7 → Middle-school music and band instrument sets for performance-based ensembles
#   2014.0_Q4.0 / topic 8 → Basic classroom art-and-writing supplies for creative projects and dry-erase instruction
#   2014.0_Q4.0 / topic 11 → ESL/ELL Spanish-speaking literacy and book access for newcomer multilingual learners
#   2015.0_Q1.0 / topic 0 → Hands-on inquiry science and engineering for problem solving and future STEM careers
#   2015.0_Q1.0 / topic 1 → Free/Reduced-Price Lunch Title I Classroom Access Requests
#   2015.0_Q1.0 / topic 4 → Flexible seating and movement supports for fidgety learners
#   2015.0_Q1.0 / topic 5 → iPad-enabled Common Core professional development for standards-based instruction
#   2015.0_Q1.0 / topic 2 → Hands-on kindergarten/early elementary math-and-literacy centers for ELL and Title I classrooms
#   2015.0_Q1.0 / topic 3 → Independent reading books and leveled-library access for emerging readers
#   2015.0_Q1.0 / topic 6 → Classroom tablets and laptops for app-based research and access in high-poverty schools
#   2015.0_Q1.0 / topic 7 → Special education supports for autism, developmental disabilities, and individualized classroom access
#   2015.0_Q1.0 / topic 8 → Creative writing and art supply kits for student expression
#   2015.0_Q1.0 / topic 9 → Music, band, choir, and percussion instrument access for student performance programs
#   2015.0_Q2.0 / topic 0 → Financial literacy, economics, and entrepreneurship framed as life-skills and college/career readiness
#   2015.0_Q1.0 / topic 11 → Low-income family and refugee student access to iPads for literacy, English learning, and immediate instructional support
#   2015.0_Q2.0 / topic 2 → Flexible seating and classroom movement options for young students
#   2015.0_Q1.0 / topic 10 → Financial literacy for elementary students through money-management play and classroom pretend stores
#   2015.0_Q2.0 / topic 3 → Early elementary leveled library books for beginning readers and guided fluency/comprehension practice
#   2015.0_Q2.0 / topic 4 → 1:1 classroom technology access for digital creation and online research
#   2015.0_Q2.0 / topic 5 → K-5 hands-on STEM engineering kits for problem solving and story-based design challenges
#   2015.0_Q2.0 / topic 6 → Basic classroom supply requests for organized writing and activity materials
#   2015.0_Q2.0 / topic 7 → Special education support for autism and developmental disabilities
#   2015.0_Q2.0 / topic 8 → School Music Performance and Instrument Access for General Music, Band, and Pep Band
#   2015.0_Q2.0 / topic 10 → Low-income family access and scarcity framing for home/library learning supports
#   2015.0_Q2.0 / topic 11 → Scholastic News/current-events magazines for social studies and nonfiction reading
#   2015.0_Q3.0 / topic 0 → Malala-inspired global citizenship and diversity awareness
#   2015.0_Q3.0 / topic 1 → Flexible seating for movement-friendly elementary classrooms
#   2015.0_Q3.0 / topic 2 → Free/reduced-price lunch rural low-income access to technology and hands-on learning
#   2015.0_Q3.0 / topic 3 → Class Library and Guided Reading Books for Elementary Literacy, Fluency, and Comprehension
#   2015.0_Q2.0 / topic 1 → Free/reduced-lunch poverty framing for rural/urban high-need student access
#   2015.0_Q3.0 / topic 4 → Limited-device classroom access for online research, apps, and assessments
#   2015.0_Q2.0 / topic 9 → English language learner literacy support for bilingual and second-language students
#   2015.0_Q3.0 / topic 5 → Basic classroom supply kits for low-income, high-needs classrooms
#   2015.0_Q3.0 / topic 7 → Special education supports for students with autism and moderate-to-severe disabilities
#   2015.0_Q3.0 / topic 6 → Hands-on STEM design challenges and maker-space inquiry for elementary students
#   2015.0_Q3.0 / topic 10 → Low-income family hardship framing for home-school learning access and barrier removal
#   2015.0_Q3.0 / topic 11 → Scholastic News and nonfiction magazine subscriptions for current events / informational text literacy
#   2015.0_Q3.0 / topic 9 → Inclusive early-elementary literacy and math supports for multilingual English learners
#   2015.0_Q3.0 / topic 8 → Elementary music class instruments, orchestra/band/chorus participation, and student-choice performance materials
#   2015.0_Q4.0 / topic 1 → Flexible seating and movement-friendly classroom furniture
#   2015.0_Q4.0 / topic 2 → Free/Reduced-Lunch Schools Framing Requests Around Chronic Scarcity and Student Needs
#   2015.0_Q4.0 / topic 3 → Inquiry-Based STEM Engineering Challenges for Gifted/Advanced Students
#   2015.0_Q4.0 / topic 6 → Special education sensory and behavior supports for autism, intellectual disability, and other disabilities
#   2015.0_Q4.0 / topic 7 → English Language Learner Support for Multilingual Immigrant Classrooms
#   2015.0_Q4.0 / topic 8 → Basic art and writing supplies for expressive classroom projects
#   2015.0_Q4.0 / topic 5 → Kindergarten literacy-math learning centers with sight-word, letter, and number games
#   2015.0_Q4.0 / topic 4 → Equitable access to Chromebooks, iPads, and online learning tools
#   2015.0_Q4.0 / topic 0 → Leveled books for independent reading and comprehension growth
#   2015.0_Q4.0 / topic 9 → Low-income family context: chronic-scarcity classroom support for reading, writing, organization, and basic supplies
#   2015.0_Q4.0 / topic 10 → School sports, music, and performance equipment for student participation and team programs
#   2016.0_Q1.0 / topic 1 → Flexible seating for movement-based focus and choice
#   2016.0_Q1.0 / topic 0 → World-expansion field trips and historical storytelling for rural students
#   2015.0_Q4.0 / topic 11 → Flexible seating and sensory-movement accommodations for active learners
#   2016.0_Q1.0 / topic 2 → Free/Reduced-Price Lunch High-Poverty Classroom Support Requests
#   2016.0_Q1.0 / topic 3 → Elementary guided reading and leveled-library books for fluency/comprehension growth
#   2016.0_Q1.0 / topic 4 → Chromebook/iPad access for low-income, ELL, and special-needs classrooms
#   2016.0_Q1.0 / topic 5 → Basic Writing-and-Art Classroom Consumables for Interactive Notebooks and Projects
#   2016.0_Q1.0 / topic 6 → Hands-on STEM makerspace and problem-solving engineering projects for low-income elementary and middle school students
#   2016.0_Q1.0 / topic 7 → Special education sensory-regulation and inclusive curriculum supports for autism and developmental disabilities
#   2016.0_Q1.0 / topic 9 → Flexible seating and movement supports for fidgety, ADHD, and special-needs learners
#   2016.0_Q1.0 / topic 8 → English language learner support for bilingual literacy, discussion, and classroom access
#   2016.0_Q2.0 / topic 0 → Levelled diverse reading libraries for elementary and middle grades
#   2016.0_Q2.0 / topic 1 → Flexible seating for active, fidgety elementary students
#   2016.0_Q1.0 / topic 11 → Low-income family classroom access and supply shortages
#   2016.0_Q2.0 / topic 2 → Free/Reduced Lunch Title I Equity: classroom resources for low-income and ESL students
#   2016.0_Q2.0 / topic 4 → Girls' team sports equipment and skill-development programs
#   2016.0_Q2.0 / topic 3 → Hands-on STEM engineering makerspace and problem-solving projects for K-5/middle grades
#   2016.0_Q2.0 / topic 5 → Low-income, high-poverty elementary classroom requests framed as overcoming student hardship
#   2016.0_Q2.0 / topic 6 → 1:1 student device access for research, apps, and online learning at home/school
#   2016.0_Q2.0 / topic 7 → Kindergarten math-literacy learning centers and manipulative games
#   2016.0_Q2.0 / topic 8 → Special education supports for students with autism and multiple disabilities
#   2016.0_Q2.0 / topic 9 → Basic classroom and art supply requests for organized, prepared classrooms
#   2016.0_Q2.0 / topic 10 → English Language Learner literacy and vocabulary support for multilingual immigrant students
#   2016.0_Q2.0 / topic 11 → Low-income family home-literacy and supply support under chronic scarcity
#   2016.0_Q3.0 / topic 0 → Basic classroom supply requests for high-poverty Title I students
#   2016.0_Q3.0 / topic 2 → Low-income, single-parent student support framed as overcoming daily barriers
#   2016.0_Q3.0 / topic 1 → Flexible seating and movement-friendly classroom seating for active students
#   2016.0_Q3.0 / topic 3 → Free/Reduced-Lunch, English Learner, and Low-Income Urban Classroom Resource Requests
#   2016.0_Q3.0 / topic 5 → Hands-on STEM problem-solving and engineering for diverse elementary learners
#   2016.0_Q3.0 / topic 4 → Leveled books and diverse texts for emergent multilingual and below-grade readers
#   2016.0_Q3.0 / topic 6 → Special education for neurodiverse, low-income students with autism and multiple disabilities
#   2016.0_Q1.0 / topic 10 → Band, sports, and club participation framed as access to performance equipment and team opportunities
#   2016.0_Q3.0 / topic 7 → Kindergarten literacy-and-math centers for active group practice
#   2016.0_Q3.0 / topic 8 → Physical activity and recess equipment for indoor/outdoor movement breaks
#   2016.0_Q3.0 / topic 10 → Low-income poverty-context barrier removal for classroom basics, books, and music materials
#   2016.0_Q3.0 / topic 11 → Free breakfast/lunch, weekend food, and pantry support for Title I students
#   2016.0_Q3.0 / topic 9 → 1:1 student devices for internet access, research, and blended instruction
#   2016.0_Q4.0 / topic 1 → Low-income classroom access and opportunity gap framing
#   2016.0_Q4.0 / topic 0 → Hands-on STEM inquiry and robotics/maker-space projects for elementary students
#   2016.0_Q4.0 / topic 2 → Flexible seating for active learners and movement-friendly classrooms
#   2016.0_Q4.0 / topic 3 → Title I / free-and-reduced-lunch students needing classroom supports
#   2016.0_Q4.0 / topic 4 → Reading workshop library books for leveled independent reading and book choice
#   2016.0_Q4.0 / topic 5 → Rural school band and sports program equipment for community performances and competitions
#   2016.0_Q4.0 / topic 6 → Chromebook/iPad classroom access for 21st-century digital research and instruction
#   2016.0_Q4.0 / topic 7 → Kindergarten hands-on learning centers for early literacy and math skills
#   2016.0_Q4.0 / topic 8 → Special education instruction for students with autism and other cognitive/emotional disabilities
#   2016.0_Q4.0 / topic 10 → Multilingual newcomer ELL support in diverse immigrant classrooms
#   2016.0_Q4.0 / topic 11 → Basic classroom consumables for organizing student work and hands-on projects
#   2017.0_Q1.0 / topic 1 → Low-income, single-parent students facing socioeconomic barriers and long commutes
#   2017.0_Q1.0 / topic 0 → Graphic-novel and leveled-reading books for reluctant/emerging readers
#   2016.0_Q4.0 / topic 9 → Low-income poverty-framed requests for student engagement resources and access supports
#   2017.0_Q1.0 / topic 2 → Flexible seating for active elementary classrooms
#   2017.0_Q1.0 / topic 4 → STEAM robotics and engineering design for problem-solving and invention
#   2017.0_Q1.0 / topic 3 → Free/Reduced-Price Lunch Majority-Title I Requests for Books, Media, and Enrichment Access
#   2017.0_Q1.0 / topic 7 → Special education supports for autism, emotional disturbance, and trauma-affected students
#   2017.0_Q1.0 / topic 6 → Rural, low-income extracurricular performance programs framed as opportunity access
#   2017.0_Q1.0 / topic 9 → ESL/ELL newcomer literacy and language-support technology
#   2017.0_Q1.0 / topic 8 → Kindergarten math-and-literacy center materials for low-income and English-learner classrooms
#   2017.0_Q1.0 / topic 11 → Chronic-scarcity, underfunding, catch-up remediation requests for low-income classrooms
#   2017.0_Q2.0 / topic 0 → Hands-on STEM problem-solving materials for elementary and preschool classrooms
#   2017.0_Q2.0 / topic 1 → Low-income, single-parent students facing home-barrier challenges; teacher framing of potential growth
#   2017.0_Q2.0 / topic 4 → Elementary classroom library book sets for reading interest and reader development
#   2017.0_Q1.0 / topic 5 → Chromebooks and Internet Access for College-Ready Digital Research and Assignment Completion
#   2017.0_Q2.0 / topic 3 → Free/Reduced Lunch and Title I Low-Income Student Resource Requests
#   2017.0_Q2.0 / topic 2 → Flexible seating for active kindergarten and elementary classrooms
#   2017.0_Q2.0 / topic 6 → Barrier-removal classroom basics for low-income and refugee students
#   2017.0_Q2.0 / topic 7 → Special education life-skills and sensory support for students with autism and multiple disabilities
#   2017.0_Q2.0 / topic 10 → ELL/second-language support for multilingual immigrant and Spanish-speaking students
#   2017.0_Q2.0 / topic 5 → Girls' sports and school team programs needing equipment and uniforms
#   2017.0_Q2.0 / topic 9 → Free Breakfast/Lunch, Weekend Food, and Backpack Pantry Support for Title I Students
#   2017.0_Q2.0 / topic 11 → Low-income, underfunded district requests framed as chronic scarcity barriers to learning and enrichment
#   2017.0_Q3.0 / topic 0 → English language learner / second-language literacy support for multilingual immigrant and low-income students
#   2017.0_Q3.0 / topic 1 → Poverty- and single-parent-context framing of student potential and mobility barriers
#   2017.0_Q3.0 / topic 2 → Flexible seating for movement-based classroom choice
#   2017.0_Q3.0 / topic 4 → STEM problem-solving and hands-on engineering design activities
#   2017.0_Q3.0 / topic 3 → Low-income / free-reduced-lunch student access and participation
#   2017.0_Q3.0 / topic 5 → Barrier-removal supplies for music, art, and basic classroom needs in under-resourced schools
#   2017.0_Q3.0 / topic 7 → Kindergarten hands-on math and literacy centers for play-based learning
#   2017.0_Q1.0 / topic 10 → Free breakfast/lunch and weekend food support for Title I students
#   2017.0_Q3.0 / topic 6 → Special education classrooms serving students with autism, developmental disabilities, and communication needs
#   2017.0_Q3.0 / topic 8 → Chromebook and online-learning access for technology-integrated classroom assignments
#   2017.0_Q3.0 / topic 9 → Low-income district barrier-removal requests for books, breakfast, technology, and PE materials
#   2017.0_Q3.0 / topic 11 → Free breakfast/lunch and weekend food support for high-poverty Title I students
#   2017.0_Q3.0 / topic 10 → Differentiated reading books and leveled texts to build interest and fluency
#   2017.0_Q4.0 / topic 0 → Hands-on STEM robotics and coding for problem-solving/career exploration
#   2017.0_Q4.0 / topic 2 → Free/reduced-lunch students needing core classroom and reading support
#   2017.0_Q4.0 / topic 3 → Flexible seating for movement-friendly elementary classrooms
#   2017.0_Q4.0 / topic 1 → Barrier-removal framing for low-income, high-poverty students facing multiple home and school challenges
#   2017.0_Q4.0 / topic 5 → Special education for diverse preschool–transition students with autism, sensory, and multiple disabilities
#   2017.0_Q4.0 / topic 4 → Reading intervention through leveled books, library access, and high-interest texts
#   2017.0_Q4.0 / topic 7 → Kindergarten hands-on literacy and math center materials
#   2017.0_Q4.0 / topic 6 → Hurricane-relief requests for sports, music, and PE equipment in economically disadvantaged communities
#   2017.0_Q4.0 / topic 8 → Barrier-removal for student device access to online math/research learning
#   2017.0_Q4.0 / topic 10 → Free breakfast/lunch and weekend food support for high-poverty Title I students
#   2017.0_Q4.0 / topic 9 → English language learner support for multilingual, high-diversity classrooms
#   2018.0_Q1.0 / topic 0 → Post-Hurricane Recovery Support for Music, Athletics, and Dance Programs
#   2018.0_Q1.0 / topic 2 → Flexible seating for active kindergarten/early-elementary classrooms
#   2018.0_Q1.0 / topic 1 → Barrier-removal framing for low-income students’ access to learning and growth
#   2017.0_Q4.0 / topic 11 → Low-income, high-need classroom basics and access supports
#   2018.0_Q1.0 / topic 3 → Free/Reduced-Lunch, Title I, and Low-Income Student Access Framing
#   2018.0_Q1.0 / topic 4 → Elementary STEM/robotics projects framed as problem-solving and critical thinking
#   2018.0_Q1.0 / topic 5 → Differentiated classroom and library book access for avid, reluctant, and below-grade readers
#   2018.0_Q1.0 / topic 6 → Special education classrooms for autism and mixed disabilities (self-contained, individualized instruction)
#   2018.0_Q1.0 / topic 7 → Kindergarten math-word work centers and manipulatives
#   2018.0_Q1.0 / topic 8 → Chromebooks/iPads for differentiated classroom access and digital literacy (math, research, ESL support)
#   2018.0_Q1.0 / topic 10 → Chronic-scarcity framing for basic classroom comfort, library books, and device access in low-income districts
#   2018.0_Q1.0 / topic 9 → Free breakfast/lunch + backpack-food support for Title I, high-poverty students
#   2018.0_Q1.0 / topic 11 → English Language Learners in Multilingual, Low-Income Classrooms
#   2018.0_Q2.0 / topic 1 → Flexible seating for student choice, movement, and focus in elementary classrooms
#   2018.0_Q2.0 / topic 0 → Classroom library and read-aloud books for fostering avid readers
#   2018.0_Q2.0 / topic 2 → Low-income, single-parent students framed around removing socioeconomic barriers to growth
#   2017.0_Q2.0 / topic 8 → Classroom Chromebooks/iPads for math, science, and research access
#   2018.0_Q2.0 / topic 3 → Free/reduced-lunch students framed as underserved learners needing equitable access to choice, seating, and instructional supports
#   2018.0_Q2.0 / topic 5 → Barrier-removal support for music, band, and team sports participation in low-income communities
#   2018.0_Q2.0 / topic 4 → Hands-on STEM problem-solving and coding kits for inquiry-based makerspaces
#   2018.0_Q2.0 / topic 6 → Special education and autism support for IEP-based social-emotional, communication, and sensory instruction
#   2018.0_Q2.0 / topic 8 → 1:1 Chromebooks/iPads for personalized digital practice and research access
#   2018.0_Q2.0 / topic 7 → Basic classroom writing and dry-erase supply replenishment
#   2018.0_Q3.0 / topic 0 → STEM maker kits and inquiry-based technology learning for elementary students
#   2018.0_Q2.0 / topic 11 → Free breakfast/lunch and weekend backpack food support for Title I students
#   2018.0_Q2.0 / topic 9 → Low-income, under-resourced classrooms seeking books, art materials, and flexible seating for differentiated engagement
#   2018.0_Q2.0 / topic 10 → Multilingual ELL/ESOL newcomer support for diverse immigrant and Title I classrooms
#   2018.0_Q3.0 / topic 1 → Flexible seating for active, choice-based elementary classrooms
#   2018.0_Q3.0 / topic 2 → Free/Reduced Lunch Students: Basic Supplies and Health/Readiness Supports
#   2018.0_Q3.0 / topic 3 → Low-income, free-lunch students facing multiple barriers to learning
#   2018.0_Q3.0 / topic 4 → Project-based choice and flexible seating for student-centered, “think outside the box” learning
#   2018.0_Q3.0 / topic 5 → Classroom library book-basket requests for leveled, diverse reading materials
#   2018.0_Q3.0 / topic 7 → Special education autism/disability support for self-contained elementary classrooms
#   2018.0_Q3.0 / topic 8 → Kindergarten kinesthetic play centers for early literacy and math
#   2018.0_Q3.0 / topic 6 → Low-income family hardship and basic-needs barrier removal
#   2018.0_Q3.0 / topic 9 → Community resilience and belonging through sports, arts, and school rebuilding
#   2018.0_Q3.0 / topic 10 → Multilingual newcomer ELL support with translation and language-acquisition technology
#   2018.0_Q3.0 / topic 11 → Basic classroom supply kits for special education, Title I, and AVID students
#   2018.0_Q4.0 / topic 0 → Chromebooks and iPads for student access to online research, math apps, and differentiated instruction
#   2018.0_Q4.0 / topic 4 → Hands-on project challenges for creative, outside-the-box student problem solving
#   2018.0_Q4.0 / topic 1 → Flexible seating and wobble chairs for student choice and inclusion
#   2018.0_Q4.0 / topic 3 → Low-income, single-parent students framed as facing barriers to learning and growth
#   2018.0_Q4.0 / topic 5 → Leveled classroom library books for independent reading and reading-circles
#   2018.0_Q4.0 / topic 7 → Special education supports for autism and multiple/severe disabilities
#   2018.0_Q4.0 / topic 6 → Barrier-Removal Requests for Low-Income Students’ Basic Needs, Breakfast/Lunch, and Home-Stability Supports
#   2018.0_Q4.0 / topic 8 → Hands-on STEAM makerspace and engineering design for problem solving
#   2018.0_Q4.0 / topic 9 → Kindergarten hands-on literacy and early math materials
#   2018.0_Q4.0 / topic 10 → Newcomer ELL literacy support for multilingual immigrant students
#   2018.0_Q4.0 / topic 11 → Barrier-Removal Support for School Sports, Music, and Team Programs
#   2019.0_Q1.0 / topic 0 → Elementary makerspace STEM/robotics for problem-solving and critical thinking
#   2019.0_Q1.0 / topic 1 → Flexible seating and movement-friendly classroom furniture for active learners
#   2019.0_Q1.0 / topic 3 → Creative, hands-on “think outside the box” learning with flexible grouping and alternative seating
#   2019.0_Q1.0 / topic 2 → Free/Reduced-Price Lunch and Breakfast Framing for High-Poverty Student Support
#   2019.0_Q1.0 / topic 4 → Barrier-removal requests for low-income students facing poverty-related challenges
#   2019.0_Q1.0 / topic 5 → Classroom book access for leveled independent reading and book clubs
#   2019.0_Q1.0 / topic 6 → Low-income household basic-needs and barrier-removal support
#   2019.0_Q1.0 / topic 7 → Self-contained special education for autism/disability: sensory regulation, social skills, and inclusion support
#   2019.0_Q1.0 / topic 8 → Kindergarten hands-on math and literacy centers for energetic, diverse learners
#   2019.0_Q1.0 / topic 9 → Chromebooks and tablets for low-income students’ access to online learning, research, and math work
#   2019.0_Q1.0 / topic 10 → English language learners in multilingual immigrant classrooms
#   2018.0_Q4.0 / topic 2 → Free/Reduced-Price Lunch Poverty Framing for Basic Classroom, Music, and School-Space Needs
#   2019.0_Q1.0 / topic 11 → Team-sport equipment requests for girls’ softball, volleyball, and soccer programs
#   2019.0_Q2.0 / topic 0 → __framing_barrier_removal__ for low-income youth sports teams and girls' athletics
#   2019.0_Q2.0 / topic 1 → Flexible seating for student choice and movement in elementary classrooms
#   2019.0_Q2.0 / topic 2 → Free/Reduced-Price Lunch and Breakfast: Title I Poverty-Barrier Framing
#   2019.0_Q2.0 / topic 3 → Low-income, high-poverty classroom support framed as overcoming barriers to student growth
#   2019.0_Q2.0 / topic 5 → Multilingual and ELL literature access for reading groups and book clubs
#   2019.0_Q2.0 / topic 4 → Hands-on, choice-based creative writing and thinking tasks for low-income elementary students
#   2019.0_Q2.0 / topic 7 → Special education supports for students with autism and severe disabilities
#   2019.0_Q2.0 / topic 6 → Hands-on STEM/engineering design projects framed as problem-solving and 21st-century skill building
#   2019.0_Q2.0 / topic 8 → Pre-K/Kindergarten play-based centers for early literacy and fine-motor skills
#   2019.0_Q2.0 / topic 9 → Rural/low-income access to classroom devices for math, research, and digital projects
#   2019.0_Q2.0 / topic 10 → Low-income, majority-poverty classrooms seeking home-to-school technology access and flexible seating
#   2019.0_Q3.0 / topic 1 → Flexible seating and movement-friendly classroom chairs
#   2019.0_Q3.0 / topic 2 → Hands-on, creative, think-outside-the-box project learning with flexible work/seat options
#   2019.0_Q3.0 / topic 0 → __framing_barrier_removal__ for impoverished, trauma-affected students needing basic supplies, arts/sports access, and instrument repairs
#   2019.0_Q3.0 / topic 3 → Free-and-Reduced Lunch Eligibility / Title I Low-Income School Framing
#   2019.0_Q3.0 / topic 4 → Low-income, high-poverty classroom support framed around simple creative learning
#   2019.0_Q3.0 / topic 6 → K-12 STEM makerspace and robotics/3D-printing problem-solving
#   2019.0_Q3.0 / topic 5 → Independent reading library books for early elementary readers
#   2019.0_Q3.0 / topic 7 → Special education supports for autism, disability, and sensory/behavioral needs
#   2019.0_Q3.0 / topic 8 → Kindergarten/Pre-K hands-on center play materials for school readiness
#   2019.0_Q3.0 / topic 9 → Low-income, title-eligible families seeking basic classroom and home-learning materials
#   2019.0_Q3.0 / topic 10 → Flexible seating and student choice in special education / differentiated classrooms
#   2019.0_Q3.0 / topic 11 → Bilingual ELL / English-language acquisition support for Spanish-speaking and other multilingual students
#   2019.0_Q4.0 / topic 0 → Safe, supportive classroom spaces for students facing poverty, homelessness, and trauma
#   2019.0_Q4.0 / topic 1 → Free/Reduced-Price Lunch Title I Students Needing Classroom Resources and Basic Supports
#   2019.0_Q4.0 / topic 2 → Flexible seating for choice-based independent and collaborative learning
#   2019.0_Q4.0 / topic 4 → Independent Reading Access for Elementary and Middle School Struggling Readers
#   2019.0_Q4.0 / topic 3 → Hands-on, choice-based classroom projects to help students think outside the box
#   2019.0_Q4.0 / topic 5 → Developmentally appropriate play-based kindergarten centers for letters, math, and movement
#   2019.0_Q2.0 / topic 11 → Basic classroom organization and writing-supply kits for elementary and special education students
#   2019.0_Q4.0 / topic 6 → Special education access and accommodation for autism, sensory, and emotional/behavioral disabilities
#   2019.0_Q4.0 / topic 7 → Basic classroom consumables for low-income elementary classrooms
#   2019.0_Q4.0 / topic 8 → STEAM/robotics inquiry projects for future-ready STEM problem solvers
#   2019.0_Q4.0 / topic 10 → English language learner literacy and transition supports for Spanish-dominant, multilingual elementary students
#   2019.0_Q4.0 / topic 11 → Music and athletics equipment for school performance and competitive teams
#   2019.0_Q4.0 / topic 9 → Low-income, free-lunch kindergarten classrooms framed by poverty barriers and family hardship
#   2020.0_Q1.0 / topic 0 → Basic classroom consumables for low-income elementary classrooms
#   2020.0_Q1.0 / topic 1 → Free/reduced-lunch low-income student support
#   2020.0_Q1.0 / topic 3 → Diverse classroom library books to build a love of reading
#   2020.0_Q1.0 / topic 2 → Creative, hands-on challenge-based learning for rural and resource-limited students
#   2020.0_Q1.0 / topic 4 → Flexible seating for movement-based focus and choice in elementary classrooms
#   2020.0_Q1.0 / topic 5 → Low-income, high-poverty district students framed as overcoming home and access barriers
#   2020.0_Q1.0 / topic 7 → Hands-on STEM problem-solving and exploration for curious, high-ability elementary learners
#   2020.0_Q1.0 / topic 6 → Special education for autism, developmental delays, and multiple disabilities in early childhood/self-contained classrooms
#   2020.0_Q1.0 / topic 10 → English language learner bilingual literacy support for Spanish-dominant and other multilingual students
#   2020.0_Q1.0 / topic 9 → Barrier-removal access to Chromebooks/iPads/headphones for low-income multilingual students
#   2020.0_Q1.0 / topic 8 → Community-based music and sports equipment for inclusive after-school team programs
#   2020.0_Q2.0 / topic 0 → Hands-on STEM project-based learning and makerspace exploration
#   2020.0_Q1.0 / topic 11 → Low-income family hardship and home-support access (__framing_chronic_scarcity__ / __framing_home_extension_family_colearning__)
#   2020.0_Q2.0 / topic 1 → Pandemic remote-learning access for home-based Chromebooks, internet, and Zoom instruction
#   2020.0_Q2.0 / topic 3 → Hardship-framed take-home packets and devices for low-income students in COVID distance learning
#   2020.0_Q2.0 / topic 2 → Free/reduced-price lunch and Title I high-need student populations
#   2020.0_Q2.0 / topic 5 → Flexible seating and alternative classroom furniture for student choice and movement
#   2020.0_Q2.0 / topic 4 → Remote support for newly established multilingual English-immersion classrooms during COVID-19
#   2020.0_Q2.0 / topic 6 → Diverse classroom books for representation, read-alouds, and independent reading
#   2020.0_Q2.0 / topic 7 → COVID-era distance learning participation via Zoom/Google Meet
#   2020.0_Q2.0 / topic 8 → Pandemic distance-learning basic school supply kits (pencils, paper, markers, folders)
#   2020.0_Q2.0 / topic 9 → Creative, hands-on classroom projects for students facing home-resource barriers
#   2020.0_Q2.0 / topic 11 → Special education support for autistic and developmentally disabled students in self-contained preschool–elementary classrooms
#   2020.0_Q3.0 / topic 1 → Hands-on project-based learning and flexible seating for creative problem solving
#   2020.0_Q2.0 / topic 10 → Low-income, single-parent and ESL student context with free-lunch access barriers
#   2020.0_Q3.0 / topic 0 → Diverse classroom library books as mirrors-and-windows for inclusive reading
#   2020.0_Q3.0 / topic 2 → Free/reduced-price lunch access framed as pandemic-era home learning support for low-income elementary students
#   2020.0_Q3.0 / topic 3 → COVID-era classroom air purification and germ-safety requests
#   2020.0_Q3.0 / topic 4 → Pandemic-era virtual instruction and home access to devices/connectivity
#   2020.0_Q3.0 / topic 6 → Early childhood special education for autism and multiple disabilities, with speech-language and sensory/functional skill support
#   2020.0_Q3.0 / topic 9 → Flexible seating and movement-friendly classroom furniture for wiggly students
#   2020.0_Q3.0 / topic 5 → Remote K–5 starter supply kits for writing, math, and dry-erase practice
#   2020.0_Q3.0 / topic 7 → Low-income and poverty-affected student households
#   2020.0_Q3.0 / topic 8 → Elementary STEM makerspace and hands-on design/problem-solving projects
#   2020.0_Q3.0 / topic 10 → Teacher Pay Gift Cards for At-Home / Virtual Math Engagement Materials
#   2020.0_Q3.0 / topic 11 → English language learners in multilingual, immigrant/refugee classrooms
#   2020.0_Q4.0 / topic 0 → Rural and low-income athletics/music program equipment support
#   2020.0_Q4.0 / topic 1 → Free/Reduced-Price Lunch Title I student access and barrier-removal requests
#   2020.0_Q4.0 / topic 4 → Kindergarten letter-writing and play-based readiness supplies
#   2020.0_Q4.0 / topic 2 → Creative, hands-on challenge projects for student choice and alternative learning setups
#   2020.0_Q4.0 / topic 3 → Diverse multicultural classroom library for emergent bilingual and low-income readers
#   2020.0_Q4.0 / topic 5 → Hybrid/remote instruction with student device access and virtual teaching tools
#   2020.0_Q4.0 / topic 7 → K-5 STEM/robotics design-challenge supplies for problem solving and coding
#   2020.0_Q4.0 / topic 6 → Low-income English learner / multilingual family needs with barrier-removal appeals
#   2020.0_Q4.0 / topic 8 → Special education and early intervention for preschool children with autism, developmental delays, and other disabilities
#   2020.0_Q4.0 / topic 9 → Barrier-removal appeals for low-income, high-poverty classrooms with multilingual and single-parent students
#   2020.0_Q4.0 / topic 10 → Teacher Pay Gift Card Requests for Digital Learning Resources and Activities
#   2020.0_Q4.0 / topic 11 → COVID-safe flexible seating and socially distanced classroom space for elementary students
#   2021.0_Q1.0 / topic 3 → Classroom library and diverse books to build reading interest and lifelong readers
#   2021.0_Q1.0 / topic 0 → COVID-era safe-return supplies and hygiene for in-person transition
#   2021.0_Q1.0 / topic 1 → Free- and reduced-price lunch students: equitable access / no-barrier participation framing for classroom, virtual, seasonal, and extracurricular supports
#   2021.0_Q1.0 / topic 2 → Hands-on, open-ended thinking activities for creative problem solving and student choice
#   2021.0_Q1.0 / topic 4 → Special education and autism support for social-emotional, adaptive, and academic goals
#   2021.0_Q1.0 / topic 5 → Virtual/hybrid classroom access tools for low-income multilingual students
#   2021.0_Q1.0 / topic 6 → Low-income, high-poverty classroom barrier-removal framing
#   2021.0_Q1.0 / topic 7 → Kindergarten hands-on play centers for early literacy, math, and fine-motor practice
#   2021.0_Q1.0 / topic 9 → English Learner / ESL literacy support for immigrant, refugee, and bilingual students
#   2021.0_Q1.0 / topic 11 → Flexible seating for student choice, comfort, and COVID-era distancing
#   2021.0_Q1.0 / topic 8 → STEM/STEAM makerspace and career-exploration projects for future scientists, engineers, and coders
#   2021.0_Q2.0 / topic 0 → Teacher Pay Gift Cards for Hybrid/Remote Math and Literacy Materials
#   2021.0_Q2.0 / topic 1 → Free/reduced-price lunch and breakfast access for low-income students
#   2021.0_Q2.0 / topic 3 → Flexible seating for movement-friendly, choice-based classroom participation
#   2021.0_Q2.0 / topic 2 → Creative, hands-on, outside-the-box learning activities and flexible classroom options
#   2021.0_Q2.0 / topic 4 → Special education support for autism, developmental disabilities, and sensory/behavioral needs
#   2021.0_Q2.0 / topic 5 → COVID-era return-to-classroom safety and belonging for elementary students
#   2021.0_Q2.0 / topic 8 → Low-income, high-poverty district classrooms framed around overcoming student hardship
#   2021.0_Q2.0 / topic 7 → Play-based kindergarten readiness centers for letter-sound and fine-motor practice
#   2021.0_Q2.0 / topic 6 → Diverse leveled book libraries for student choice, representation, and reading motivation
#   2021.0_Q2.0 / topic 9 → Hands-on STEM makerspace for future engineers and scientists
#   2021.0_Q2.0 / topic 10 → English Language Learner catch-up support for bilingual/Spanish-speaking students
#   2021.0_Q2.0 / topic 11 → Low-income household scarcity and chronic underfunding in family/community support requests
#   2021.0_Q1.0 / topic 10 → Free-and-reduced-lunch / Title I poverty framing for basic-needs, reading, and classroom-support requests
#   2021.0_Q3.0 / topic 1 → Hands-on creative challenge learning with flexible seating and group work
#   2021.0_Q3.0 / topic 0 → COVID-era safe return to in-person elementary classrooms
#   2021.0_Q3.0 / topic 3 → Flexible seating and alternative work-space seating for independent classroom choice
#   2021.0_Q3.0 / topic 2 → Free/reduced-price lunch Title I support for high-poverty multilingual and migrant classrooms
#   2021.0_Q3.0 / topic 4 → Print-rich leveled book access for early-grade reading growth
#   2021.0_Q3.0 / topic 7 → Special education supports for autism, social-emotional, and adaptive-skill instruction
#   2021.0_Q3.0 / topic 5 → Play-Based Kindergarten Readiness: Fine Motor, Early Literacy/Math, and Hands-On Centers
#   2021.0_Q3.0 / topic 8 → Low-income, free-lunch students facing poverty-related barriers to learning
#   2021.0_Q3.0 / topic 9 → STEAM makerspace and engineering problem-solving projects
#   2021.0_Q3.0 / topic 11 → Low-income household scarcity framing for basic school-home supplies and internet/access needs
#   2021.0_Q3.0 / topic 10 → English Language Learners and Multilingual Refugee/Newcomer Literacy Support
#   2021.0_Q3.0 / topic 6 → Basic classroom consumables for low-income elementary/urban classrooms
#   2021.0_Q4.0 / topic 1 → Creative, hands-on project learning framed as helping students think outside the box
#   2021.0_Q4.0 / topic 3 → Classroom library books for diverse, interest-driven independent reading
#   2021.0_Q4.0 / topic 2 → Free/Reduced-Price Lunch and Breakfast as a Poverty-Need Context for Student Supports
#   2021.0_Q4.0 / topic 4 → STEM design-build maker projects for problem solving and future careers
#   2021.0_Q4.0 / topic 6 → Flexible seating for student choice and movement in elementary/middle classrooms
#   2021.0_Q4.0 / topic 5 → Special education and autism/disability support for self-contained classrooms and speech-language needs
#   2021.0_Q4.0 / topic 7 → Kindergarten fine-motor and early literacy center materials
#   2021.0_Q4.0 / topic 8 → COVID-disrupted below-grade-level math and literacy intervention for diverse elementary students
#   2021.0_Q4.0 / topic 9 → Low-income and single-parent households, with free-lunch/ELL barriers to student support
#   2021.0_Q4.0 / topic 11 → COVID-era trauma-informed social-emotional and mental health support / calm-space requests
#   2022.0_Q1.0 / topic 0 → Barrier-removal support for low-income, foster-care, and inner-city students
#   2022.0_Q1.0 / topic 2 → Flexible seating options for choice-based classroom movement
#   2022.0_Q1.0 / topic 1 → Free/reduced-price lunch–qualified students needing books, reading support, and basic-needs relief
#   2022.0_Q1.0 / topic 3 → Classroom library book collections for independent reading and choice-based literacy
#   2022.0_Q1.0 / topic 5 → Early childhood fine-motor play materials for inclusive preschool/kindergarten exploration
#   2022.0_Q1.0 / topic 6 → Multisensory phonics and sight-word intervention for K–2 struggling readers
#   2022.0_Q1.0 / topic 7 → Special education access and IEP support for autism, disability, and communication needs
#   2022.0_Q1.0 / topic 4 → Hands-on, open-ended kindergarten/primary classroom materials for "think outside the box" inquiry learning
#   2022.0_Q1.0 / topic 8 → Hands-on STEM design-and-build materials for engineering problem-solving
#   2022.0_Q1.0 / topic 9 → Basic classroom writing and art supply replenishment for primary/special education, with triage repair framing
#   2022.0_Q1.0 / topic 10 → COVID-era SEL and self-regulation supports for student mental health, anxiety, and calming spaces
#   2021.0_Q4.0 / topic 10 → Multilingual English Learner literacy access (books, tablets, journals, and hydroponics/art integration)
#   2022.0_Q2.0 / topic 1 → Flexible seating for student choice, movement, and self-regulation
#   2022.0_Q1.0 / topic 11 → Low-income, multilingual and special-needs students facing chronic scarcity at home
#   2022.0_Q2.0 / topic 0 → Classroom storage and organization systems for keeping materials accessible and safe
#   2022.0_Q2.0 / topic 2 → Inclusive graphic novel and diverse book library expansion for struggling and interested readers
#   2022.0_Q2.0 / topic 3 → Hands-on STEAM build kits for creative science problem-solving
#   2022.0_Q2.0 / topic 4 → Teacher-pay gift card requests for classroom resource purchases and student engagement
#   2022.0_Q2.0 / topic 5 → Social-emotional regulation supports: calm corners, mindfulness, and sensory tools for self-regulation
#   2022.0_Q2.0 / topic 6 → Play-based early literacy and math center materials for preschool–kindergarten skill practice
#   2022.0_Q2.0 / topic 7 → End-of-year celebration and reward kits for student hard work
#   2022.0_Q2.0 / topic 9 → Print-rich classroom library for independent student reading
#   2022.0_Q2.0 / topic 8 → Chromebooks/iPads and headphones for online testing, research, and bilingual instruction
#   2022.0_Q2.0 / topic 10 → Dry-erase classroom basics and consumables replenishment
#   2022.0_Q2.0 / topic 11 → Low-income, free-lunch English learner / bilingual students framed through scarcity and home-extension caregiving
#   2022.0_Q3.0 / topic 0 → Classroom supply kits for in-person organization and dry-erase instruction
#   2022.0_Q3.0 / topic 1 → Flexible seating and classroom movement supports for student choice, comfort, and regulation
#   2022.0_Q3.0 / topic 2 → Graphic novels and leveled books for reluctant readers below grade level
#   2022.0_Q3.0 / topic 3 → Kindergarten hands-on math and fine-motor centers for play-based foundational skill practice
#   2022.0_Q3.0 / topic 4 → Calm-down corners and sensory regulation tools for students needing social-emotional self-regulation support
#   2022.0_Q3.0 / topic 5 → Teacher Pay Gift Cards for TPT/Digital Print Resources and Hands-On Activities
#   2022.0_Q3.0 / topic 9 → Elementary classroom library books and print-rich independent reading materials
#   2022.0_Q3.0 / topic 7 → Free breakfast/lunch spillover relief snacks for hungry, low-income students
#   2022.0_Q3.0 / topic 8 → Academic-attention support bundles: headphones, graphic novels, coding robots, and flexible seating framed as achievement boosters
#   2022.0_Q3.0 / topic 11 → Flexible seating for student choice and independent work
#   2022.0_Q3.0 / topic 10 → Low-income family needs framing: home–school support, basic supplies, and barrier removal
#   2022.0_Q3.0 / topic 6 → Hands-on STEAM makerspaces and engineering design for elementary students
#   2022.0_Q4.0 / topic 1 → Flexible seating and choice-based classroom furniture
#   2022.0_Q4.0 / topic 0 → Elementary–middle STEM problem-solving kits for robotics, building, and design thinking
#   2022.0_Q4.0 / topic 2 → Winter clothing and cold-weather gear requests framed as safety/comfort and access barriers
#   2022.0_Q4.0 / topic 4 → Basic classroom consumables for writing, art, and whiteboard instruction
#   2022.0_Q4.0 / topic 3 → Reader-choice library expansion for diverse, leveled books and graphic novels
#   2022.0_Q4.0 / topic 6 → Kindergarten/preschool fine-motor literacy centers with hands-on letter, number, and sorting play
#   2022.0_Q4.0 / topic 5 → Chromebooks and headphones for distraction-free digital work, reading fluency, and language practice
#   2022.0_Q4.0 / topic 9 → Print-rich classroom library for independent reading and choice
#   2022.0_Q4.0 / topic 8 → Teacher gift card requests framed as pay-gap workaround for buying TPT/resources and activity materials
#   2022.0_Q4.0 / topic 10 → Low-income hunger relief through classroom snacks, breakfast, and lunch
#   2022.0_Q4.0 / topic 11 → PBIS-style reward incentives: treasure boxes, prize stores, and snack treats for hard work and behavior
#   2021.0_Q4.0 / topic 0 → Student perseverance and safety/comfort support framed as keeping kids safe, healthy, and able to keep trying
#   2023.0_Q1.0 / topic 0 → Elementary STEAM makerspace kits for hands-on design, prototyping, and problem solving
#   2023.0_Q1.0 / topic 1 → Graphic novel and classroom library book expansion for reluctant readers
#   2023.0_Q1.0 / topic 2 → Flexible seating for student choice and independent work (wobble stools, beanbags, floor seating)
#   2023.0_Q1.0 / topic 3 → Calm corners and sensory self-regulation spaces for social-emotional coping
#   2023.0_Q1.0 / topic 5 → Breakfast/snack pantry supports for hungry students to sustain focus and participation
#   2023.0_Q1.0 / topic 4 → Print-rich classroom library and independent reading materials
#   2023.0_Q1.0 / topic 6 → Headphones and device access for ELL/special education language support and online practice
#   2023.0_Q1.0 / topic 7 → Basic classroom supply replenishment and dry-erase/organization materials
#   2023.0_Q1.0 / topic 8 → Kindergarten fine-motor literacy/math manipulatives for tracing, letters, and numbers
#   2023.0_Q1.0 / topic 9 → Teacher Pay Gift Cards for TPT/Online Resource Purchases
#   2023.0_Q1.0 / topic 10 → Classroom incentive rewards and treasure-box prizes for behavior and work ethic
#   2023.0_Q1.0 / topic 11 → Middle-school PE team-sport equipment requests for basketball, soccer, football, and flag football
#   2022.0_Q4.0 / topic 7 → Trauma-informed calm corner and sensory self-regulation supports for students (including preschoolers and students with developmental delays)
#   2023.0_Q2.0 / topic 0 → Kindergarten–early elementary fine-motor literacy/math manipulatives for readiness and remediation
#   2023.0_Q2.0 / topic 1 → Flexible seating and movement options for student choice, regulation, and inclusion
#   2023.0_Q2.0 / topic 2 → Classroom storage and organization systems for easy-access materials
#   2023.0_Q2.0 / topic 3 → Student-choice leveled classroom library books for independent reading and comprehension growth
#   2023.0_Q2.0 / topic 4 → Basic classroom consumables restock for dry-erase, paper, and art supplies
#   2023.0_Q2.0 / topic 6 → Self-regulation calm-down spaces and sensory supports for special education / social-emotional learning
#   2023.0_Q2.0 / topic 8 → Teacher Pay Gift Cards for TPT/Resource Purchases to Differentiate Grade-Level Materials
#   2023.0_Q2.0 / topic 11 → Flexible seating for student choice and independent work
#   2023.0_Q2.0 / topic 5 → Low-income, free-lunch bilingual/ELL classrooms framed by chronic scarcity and access needs
#   2023.0_Q2.0 / topic 9 → Hands-on STEM lab and maker-space materials for experiential science exploration
#   2023.0_Q2.0 / topic 10 → Barrier-removal and capacity-building requests framed as academic achievement boosts
#   2023.0_Q3.0 / topic 1 → Flexible seating and wobble stools for student choice and collaborative work
#   2023.0_Q3.0 / topic 0 → Underfunded music and classroom tech equipment for equitable participation
#   2023.0_Q3.0 / topic 2 → Healthy snack and breakfast/lunch food support for hungry students
#   2023.0_Q3.0 / topic 3 → Expanding classroom and library book collections for independent reading, graphic novels, and leveled/interest-based texts
#   2023.0_Q3.0 / topic 4 → Basic classroom consumables and dry-erase materials for early elementary workstations
#   2023.0_Q3.0 / topic 5 → Empowering inclusive special education and student recognition/support tools
#   2023.0_Q3.0 / topic 8 → Fine-motor manipulatives and sensory play for early childhood/kindergarten writing readiness
#   2023.0_Q2.0 / topic 7 → End-of-unit and end-of-year reward snacks, treats, and celebration incentives
#   2023.0_Q3.0 / topic 7 → Teacher-paid differentiated math/grade-level instructional resources for multilingual and dual-language classrooms
#   2023.0_Q3.0 / topic 9 → LEGO and hands-on STEM kits for problem-solving, teamwork, and critical thinking
#   2023.0_Q3.0 / topic 6 → COVID-era social-emotional regulation and calm-corner supports for students
#   2023.0_Q4.0 / topic 0 → Headphones for digital learning access, audiobooks, and iReady-style instruction
#   2023.0_Q3.0 / topic 10 → Low-income family scarcity framing for home-school supplies and consumables
#   2023.0_Q3.0 / topic 11 → Calming corner / safe-space seating for self-regulation and sensory reset
#   2023.0_Q4.0 / topic 2 → Calm-down corners and sensory regulation tools for special education / preschool classrooms
#   2023.0_Q4.0 / topic 3 → Flexible seating and fidget-friendly classroom chairs for student choice, movement, and focus
#   2023.0_Q4.0 / topic 1 → Inclusive sensory-and-collaborative classroom supports for diverse learners
#   2023.0_Q4.0 / topic 4 → Library books and series to spark reading interest, especially graphic novels and diverse fiction
#   2023.0_Q4.0 / topic 5 → Hands-on STEM maker kits and robotics for elementary problem-solving and critical thinking
#   2023.0_Q4.0 / topic 7 → Reusable classroom supply replenishment: dry-erase markers, paper, pencils, glue, and laminating materials
#   2023.0_Q4.0 / topic 6 → Kindergarten/early elementary fine-motor and alphabet readiness activities for hands-on literacy practice
#   2023.0_Q4.0 / topic 8 → Hungry students’ breakfast, lunch, and snack support to improve focus and readiness to learn
#   2023.0_Q4.0 / topic 10 → Classroom reward incentives for behavior, effort, and homework compliance
#   2023.0_Q4.0 / topic 9 → Winter warmth and coat/clothing requests framed as urgent household-needs support
#   2023.0_Q4.0 / topic 11 → Low-income family hardship framing for basic-needs, participation, and enrichment requests
#   2024.0_Q1.0 / topic 0 → Student-choice library books and graphic novels for reluctant readers
#   2024.0_Q1.0 / topic 2 → Classroom storage and hygiene organization for student materials
#   2024.0_Q1.0 / topic 1 → Barrier-removal classroom environment supports for inclusive, engaging instruction
#   2024.0_Q1.0 / topic 3 → Flexible seating for student choice, movement, and comfortable independent/group work
#   2024.0_Q1.0 / topic 5 → Social-emotional regulation supports for elementary students: calm corners, sensory tools, and mindfulness/SEL materials
#   2024.0_Q1.0 / topic 4 → Core classroom consumables restock: pencils, dry-erase markers, erasers, and paper/boards for day-to-day writing and math work
#   2024.0_Q1.0 / topic 6 → Student-led expressive art supplies for creative self-expression and artist identity
#   2024.0_Q1.0 / topic 7 → Sensory play and STEM manipulatives for fine-motor, problem-solving, and critical-thinking skill building
#   2024.0_Q1.0 / topic 8 → Food-insecurity snacks, breakfast/lunch, and weekend backpack food support
#   2024.0_Q1.0 / topic 9 → Teacher-Paid TPT printables and differentiated materials for multilingual/English learners
#   2024.0_Q2.0 / topic 1 → Barrier-Removal Classroom Basics for Inclusive Academic Access
#   2024.0_Q1.0 / topic 11 → PBIS-style rewards and incentive systems for student effort, behavior, and team perseverance
#   2024.0_Q2.0 / topic 0 → Elementary classroom book access for reluctant and beginning readers
#   2024.0_Q2.0 / topic 2 → Flexible seating for student choice, comfort, and fidget-friendly focus
#   2024.0_Q2.0 / topic 4 → Hands-on STEM problem-solving and critical-thinking materials
#   2024.0_Q1.0 / topic 10 → Gratitude-framed donation appeals for urgent classroom basics, test prep, and student enrichment
#   2024.0_Q2.0 / topic 3 → Organizational classroom supplies for executive-function support and ready-to-use writing/arts materials
#   2024.0_Q2.0 / topic 5 → Low-income student snack and hygiene supplies framed as hunger prevention and home extension
#   2024.0_Q2.0 / topic 8 → Low-income early childhood outdoor play and development request
#   2024.0_Q2.0 / topic 6 → Transitional kindergarten fine-motor alphabet and handwriting manipulatives for play-based literacy readiness
#   2024.0_Q2.0 / topic 9 → Reward/incentive prizes for student motivation and behavior incentives
#   2024.0_Q2.0 / topic 10 → TPT teacher-pay gift cards for subject-specific classroom resources and printable/digital materials
#   2024.0_Q3.0 / topic 0 → Identity-expression and access through music, PE, and project-based electives
#   2024.0_Q2.0 / topic 7 → Calm-down corners and sensory self-regulation supports for school counseling / SEL
#   2024.0_Q2.0 / topic 11 → Expressive art-making supplies for student creative production and display
#   2024.0_Q3.0 / topic 1 → Barrier-removal classroom environment and inclusion supports
#   2024.0_Q3.0 / topic 2 → School calm corner and self-regulation supports for social-emotional/mental health
#   2024.0_Q3.0 / topic 4 → Flexible seating and comfort-focused classroom furniture for student choice
#   2024.0_Q3.0 / topic 6 → Low-income student snack and breakfast requests framed as hunger relief and readiness to learn
#   2024.0_Q3.0 / topic 5 → Hands-on STEM building, coding, and fine-motor skill development
#   2024.0_Q3.0 / topic 3 → Print-rich classroom library books for student choice, independent reading, and reluctant readers
#   2024.0_Q3.0 / topic 8 → Gratitude-framed donation appeals for specific classroom materials and performance needs
#   2024.0_Q3.0 / topic 10 → Flexible seating for student choice, comfort, and readiness to learn
#   2024.0_Q3.0 / topic 9 → Classroom organization and dry-erase/consumable supply replenishment for writing, storage, and room setup
#   2024.0_Q3.0 / topic 11 → Behavior-reward incentive systems for work completion and classroom motivation
#   2024.0_Q4.0 / topic 2 → __framing_supportive_environment__ classroom organization and comfort tools for focused, engaged learning
#   2024.0_Q4.0 / topic 0 → STEM maker-space tools for robotics, coding, and prototyping
#   2024.0_Q4.0 / topic 1 → Free breakfast/lunch and healthy snack support for food-insecure students
#   2024.0_Q4.0 / topic 3 → Library book/series requests to build independent reading, choice, and vocabulary
#   2024.0_Q4.0 / topic 4 → Flexible seating and classroom choice furniture for independent work
#   2024.0_Q4.0 / topic 6 → Multilingual/ELL instructional resources via TPT, print materials, and headphones
#   2024.0_Q4.0 / topic 8 → Preschool/TK fine-motor sensory play materials for early learning and readiness-to-learn
#   2024.0_Q4.0 / topic 5 → Calm corners and sensory regulation tools for student mental health and emotional self-regulation
#   2024.0_Q4.0 / topic 7 → Core classroom supply replenishment for science/math with dry-erase and consumable materials
#   2024.0_Q4.0 / topic 9 → Behavior incentive rewards for classroom regulation and motivation
#   2024.0_Q4.0 / topic 10 → Barrier-Removal Requests for Team Sports, PE, and School Clubs
#   2024.0_Q4.0 / topic 11 → Barrier-removal requests for an inclusive, supportive classroom workspace
#   2024.0_Q3.0 / topic 7 → ELL newcomer literacy/math support materials and teacher-paid supplemental resources
#   2025.0_Q1.0 / topic 0 → Sensory regulation tools for autism/ADHD and neurodivergent students
#   2025.0_Q1.0 / topic 2 → Assistive and adaptive tech for special education and multilingual learners
#   2025.0_Q1.0 / topic 3 → Reading choice libraries for multilingual and early elementary readers
#   2025.0_Q1.0 / topic 1 → Chromebook/backup device access for multimedia, music-video, and classroom participation in preschool–grade settings
#   2025.0_Q1.0 / topic 4 → Flexible seating and movement-friendly classroom furniture for choice, comfort, and inclusion
#   2025.0_Q1.0 / topic 5 → Dry-erase boards and basic writing supplies for classroom practice, organization, and test prep
#   2025.0_Q1.0 / topic 6 → Expressive arts materials for student self-expression and cultural art projects
#   2025.0_Q1.0 / topic 7 → Hands-on STEM maker materials for problem-solving and critical thinking
#   2025.0_Q1.0 / topic 8 → Treasure box incentive rewards for behavior and work completion
#   2025.0_Q1.0 / topic 11 → Classroom hygiene and disinfecting supplies for safe, germ-free learning spaces
#   2025.0_Q1.0 / topic 10 → Gratitude-based donation appeals for classroom access needs, snacks, and career/beauty kits
#   2025.0_Q1.0 / topic 9 → Free breakfast/lunch and healthy snack requests framed as readiness-to-learn support
#   2025.0_Q2.0 / topic 0 → Hands-on STEM materials for elementary inquiry, engineering, and problem-solving
#   2025.0_Q2.0 / topic 1 → Classroom storage and organization for clutter-free, accessible learning spaces
#   2025.0_Q2.0 / topic 2 → Classroom library refresh for independent reading and student choice (graphic novels, series, culturally relevant texts)
#   2025.0_Q2.0 / topic 3 → Flexible seating for elementary choice, comfort, and movement-based independent work
#   2025.0_Q2.0 / topic 4 → Chronic scarcity framing for student food insecurity: snacks, breakfast, pantry bags, and school-grown produce
#   2025.0_Q2.0 / topic 5 → Calm-down corner and sensory self-regulation supports for social-emotional learning
#   2025.0_Q2.0 / topic 6 → Equitable access to digital instruction tools for ELL, math, and multimedia learning
#   2025.0_Q2.0 / topic 7 → Preschool–Kindergarten Fine Motor Development Through Hands-On Play Materials
#   2025.0_Q2.0 / topic 8 → Barrier-removal support for resilient, low-income and bilingual students
#   2025.0_Q2.0 / topic 10 → Behavior-and-effort incentive rewards for hard work, goal attainment, and positive behavior
#   2025.0_Q2.0 / topic 9 → Classroom consumables restock bundle for dry-erase, writing, and cleaning supplies
#   2025.0_Q2.0 / topic 11 → Teacher-pay gift card requests for TPT-backed classroom materials and activities
#   2025.0_Q3.0 / topic 0 → Inquiry-based STEM maker projects with printers, robotics, and hands-on design
#   2025.0_Q3.0 / topic 1 → Calm corners for self-regulation in special education and early grades
#   2025.0_Q3.0 / topic 3 → Diverse leveled classroom library for reluctant readers, multilingual learners, and graphic novels
#   2025.0_Q3.0 / topic 2 → Barrier-removal classroom support requests for high-poverty elementary classrooms (devices, snacks, materials, and music consumables)
#   2025.0_Q3.0 / topic 5 → PreK–Kindergarten fine-motor play kits for literacy/math readiness
#   2025.0_Q3.0 / topic 6 → Classroom rug as a warm, safe gathering space for morning meeting and read-aloud community
#   2025.0_Q3.0 / topic 4 → Basic consumables and dry-erase classroom organization supplies for primary/ELL learning
#   2025.0_Q3.0 / topic 7 → Classroom sanitation and germ-prevention supplies for early learners
#   2025.0_Q3.0 / topic 10 → PBIS reward incentives for behavior and effort recognition
#   2025.0_Q3.0 / topic 8 → Flexible seating for student choice, movement, and focus in classrooms
#   2025.0_Q4.0 / topic 0 → Student-made art display and holiday craft projects for self-expression and community pride
#   2025.0_Q3.0 / topic 11 → Inclusive special education & multilingual learning materials/access supports
#   2025.0_Q4.0 / topic 3 → Graphic novel and diverse book collections for reluctant elementary readers
#   2025.0_Q4.0 / topic 1 → Healthy snack support to prevent hunger-related distraction and improve readiness to learn
#   2025.0_Q4.0 / topic 2 → PE and music equipment replenishment for student choice and safe participation
#   2025.0_Q3.0 / topic 9 → Healthy snack requests to reduce hunger and sustain focus for low-income students
#   2025.0_Q4.0 / topic 4 → Dry-erase boards and marker supplies for primary classroom organization and student practice
#   2025.0_Q4.0 / topic 5 → __framing_regulation_safety_need__ sensory self-regulation calm corner and calming tools for emotional regulation
#   2025.0_Q4.0 / topic 6 → Early literacy manipulatives for fine-motor play in preschool–TK classrooms
#   2025.0_Q4.0 / topic 7 → Flexible seating for movement-friendly elementary classrooms (wobble stools, floor cushions, bean bags, lap desks)
#   2025.0_Q4.0 / topic 8 → Classroom sanitizing supplies for early learners (hand sanitizer, wipes, Lysol spray)
#   2025.0_Q4.0 / topic 10 → PBIS-style student reward and incentive systems for behavior, effort, and attendance
#   2025.0_Q4.0 / topic 9 → Elementary STEM makerspace kits for problem-solving and hands-on engineering
#   2025.0_Q4.0 / topic 11 → Adaptive digital-access tools for differentiated instruction in diverse and special-needs classrooms
#   2026.0_Q1.0 / topic 0 → Elementary art-making supplies for expressive creative self-expression
#   2026.0_Q1.0 / topic 1 → Food insecurity relief with basic hygiene, winter clothing, and snack support
#   2026.0_Q1.0 / topic 3 → Barrier-removal restock of basic classroom supplies for hands-on elementary workstations
#   2026.0_Q1.0 / topic 2 → Chronic scarcity relief for snacks and hands-on classroom materials
#   2026.0_Q1.0 / topic 4 → Elementary reading-motivation library collections for diverse leveled books, graphic novels, and culturally relevant texts
#   2026.0_Q1.0 / topic 5 → Calm-down corner and sensory self-regulation supports for students with autism, ADHD, and anxiety
#   2026.0_Q1.0 / topic 7 → PBIS-style reward incentives for behavior, effort, and attendance
#   2026.0_Q1.0 / topic 8 → Flexible seating for focus, comfort, and self-regulation in learner-centered reading/writing spaces
#   2026.0_Q1.0 / topic 6 → Differentiated iPad and digital-access instruction for literacy intervention, audio support, and special education/ELL learners
#   2026.0_Q1.0 / topic 9 → Hands-on STEM problem solving, engineering design, and critical thinking
#   2026.0_Q1.0 / topic 10 → Youth team sports equipment and safe-practice requests
#   2026.0_Q1.0 / topic 11 → Early childhood hands-on literacy/math materials for fine motor development
#   nan_Qnan / topic 1 → Spanish-language arts basics and personal/cultural reflection materials for kindergarten
#   nan_Qnan / topic 0 → Diverse literature for identity, empathy, and cross-cultural reflection
#   nan_Qnan / topic 2 → Library collection expansion for diverse, high-interest books and graphic novels to build lifelong reading
#   nan_Qnan / topic 3 → Special education and low-income multilingual learners needing literacy/technology access
#   nan_Qnan / topic 4 → Flexible seating for movement-friendly, inclusive classroom spaces
#   nan_Qnan / topic 7 → Basic classroom supply access for organization and participation
#   nan_Qnan / topic 5 → Early literacy access for beginning and emergent readers (phonics, decodables, sight words, vocabulary, comprehension)
#   nan_Qnan / topic 6 → Sensory supports for emotional self-regulation, especially for autism and overwhelm reduction
#   nan_Qnan / topic 8 → Reward-based motivation for effort, behavior, and perseverance (snacks, prizes, treasure boxes, classroom stores)
#   nan_Qnan / topic 9 → Low-income / Title I students framed through free-reduced lunch and access inequity
#   nan_Qnan / topic 10 → Hands-on maker and sensory play for early STEM problem solving
#   nan_Qnan / topic 11 → Unclear Spanish stopword-heavy topic with subgroup-specific/collaborative framing
#
# 576 labels saved

# %%
# Keep only successfully parsed labeling results in labels_df for downstream use
parse_errors = [r for r in results if r.get("parse_error")]
if parse_errors:
    print(f"WARNING: {len(parse_errors)} topics failed JSON parse — excluded from synthesis:")
    for e in parse_errors:
        print(f"  {e.get(GROUPBY_FIELD, '?')} / topic {e.get('topic_id', '?')}")

labels_df = pd.DataFrame([r for r in results if not r.get("parse_error")])

assert GROUPBY_FIELD in labels_df.columns, (
    f"labels_df missing '{GROUPBY_FIELD}' — re-run labeling for this groupby field"
)

all_groups = {str(r.get(GROUPBY_FIELD, "")) for r in results if str(r.get(GROUPBY_FIELD, "")).strip()}
labeled_groups = set(labels_df[GROUPBY_FIELD].astype(str).unique()) if not labels_df.empty else set()
LABELING_FAILED_GROUPS = sorted(all_groups - labeled_groups)

labels_df.groupby("coherence_flag").size().rename("count").to_frame()
labels_df[[GROUPBY_FIELD, "topic_id", "proposed_label", "coherence_flag", "description"]]
# Out:
#     posted_year_quarter  topic_id  \
# 0           2014.0_Q3.0         0
# 1           2014.0_Q3.0         1
# 2           2014.0_Q3.0         2
# 3           2014.0_Q3.0         3
# 4           2014.0_Q3.0         4
# ..                  ...       ...
# 571         2024.0_Q3.0  Topic 10
# 572         2024.0_Q4.0   Topic 7
# 573         2025.0_Q3.0   Topic 3
# 574         2025.0_Q4.0   Topic 4
# 575         2026.0_Q1.0   Topic 5
#
#                                         proposed_label coherence_flag  \
# 0    College-and-career aspiration framing for high...       coherent
# 1    Independent reading books for leveled, interes...       coherent
# 2    Free/Reduced-Lunch Title I Students Needing Ba...       coherent
# 3    Rural access-to-technology requests for iPads/...       coherent
# 4    Kindergarten and early-grade literacy-math lea...       coherent
# ..                                                 ...            ...
# 571  Flexible seating for student choice, comfort, ...       coherent
# 572  Core classroom supply replenishment for scienc...       coherent
# 573  Diverse leveled classroom library for reluctan...       coherent
# 574  Dry-erase boards and marker supplies for prima...       coherent
# 575  Calm-down corner and sensory self-regulation s...       coherent
#
#                                            description
# 0    This topic centers on essays that frame rigoro...
# 1    This topic centers on classroom and school-lib...
# 2    This topic centers on teachers in low-income, ...
# 3    This topic centers on teachers framing technol...
# 4    This topic centers on teacher requests for han...
# ..                                                 ...
# 571  This topic is centered on flexible seating and...
# 572  This topic is about teachers requesting basic ...
# 573  This topic centers on teachers requesting a di...
# 574  This topic centers on basic classroom organiza...
# 575  This topic centers on requests for calm spaces...
#
# [576 rows x 5 columns]

# %%
# ── SYNTHESIS — cross-group + per-group loops ─────────────────────────────

def clean_label(text):
    return re.sub(r'__[a-z_]+__\s*', '', str(text)).strip()

def build_topic_lines(df, groupby_field, group=None):
    if group is not None:
        df = df[df[groupby_field] == group]
    return "\n".join(
        f"  {row[groupby_field]} | topic {row.topic_id} | "
        f"label: {clean_label(row.proposed_label)} | "
        f"coherence: {row.coherence_flag} | "
        f"description: {clean_label(row.description)}"
        for _, row in df.iterrows()
    )

SYNTHESIS_SYSTEM = (
    "You are a senior program analyst at an educational nonprofit. "
    "You write precise, insight-driven briefings for internal strategy audiences. "
    "You do not pad your answers or state the obvious.\n\n"
    "Some topic labels may reference rhetorical framing signals (e.g. 'barrier removal "
    "framing', 'chronic scarcity language') — these come from injected tokens that "
    "categorize how teachers write, not just what they request. Treat these as "
    "meaningful signals about teacher rhetorical strategy.\n\n"
    "Prioritize nuance over novelty. Prefer fine-grained distinctions, concrete "
    "mechanisms, specific populations, and framing differences over broad thematic "
    "summaries.\n\n"
    "Grounding: when writing Framing Differences findings, the contrast must be "
    "traceable to explicit language in the topic label or description — not inferred "
    "from the topic's general subject matter or implied by category context. If you "
    "cannot quote or closely paraphrase specific label language to establish both sides "
    "of a contrast, do not make the finding."
)

topic_lines = build_topic_lines(labels_df, GROUPBY_FIELD)

SYNTHESIS_PROMPT_CROSS_GROUP = f"""
Below is a list of NMF topics discovered from teacher project request essays on DonorsChoose,
grouped by {GROUPBY_FIELD} ({GROUP_DESCRIPTION}).
Each topic represents a cluster of essays with similar language, framing, and request patterns.
{topic_lines}

Your task: identify the most specific, decision-useful patterns in this topic landscape.

Rules:
- Every finding must be grounded in specific topic labels, descriptions, or coherence flags
  from the list above.
- Do not introduce concepts, themes, or absences that cannot be traced to an actual topic.
- If you cannot name the specific group and topic, do not make the finding.
- Prefer fine-grained distinctions over broad summaries.
- Skip anything predictable given the group name.
- Skip the free/reduced lunch poverty framing — it appears everywhere and is already known.
- Skip generic engagement/motivation language unless the topic evidence makes it unusually specific.
- If fewer than two strong findings exist for a section, write one or write none. Do not pad.

Focus on:
1. RECURRING INTERNAL SPLITS — cases where the same subtheme distinction recurs independently
   inside multiple groups. Only flag a split if it appears in at least two groups with
   meaningfully similar internal logic. Name the groups and specific topics each time.

2. CROSS-GROUP SIGNATURES — a specific program, vendor, pedagogy, student need, or rhetorical
   frame that shows up as a recognizable topic in multiple groups. Name every group it appears
   in and explain why the pattern is meaningful.

3. FRAMING DIFFERENCES — cases where similar underlying needs are presented through meaningfully
   different rhetorical frames, populations, or classroom contexts. Explain what changes across
   groups and why that difference matters.

4. NOTABLE ABSENCES — a topic you would expect given the internal logic of a group's other
   topics, but that is missing. To qualify, name at least two specific topics already present
   in the same group that make the gap conspicuous from within. Do not reason from other groups.

5. REQUEST TRIGGERS AND PITCH STRATEGIES — patterns in why teachers say they are requesting and
   how they frame those reasons for a donor audience. Only use explicit topic evidence.

Formatting: use plain numbered section headers (e.g. '1. SUBTHEME DISTINCTIONS').
Do not use markdown headers (##). Do not use bullet points.

Format as five labeled sections. Under each, write 2-5 findings as short paragraphs.
Be specific — name the group and topic label every time. Do not use bullet points.
""".strip()

PER_GROUP_INSTRUCTIONS = """
Your task: identify the most specific, decision-useful patterns within this group.

Rules:
- Every finding must be grounded in specific topic labels, descriptions, or coherence flags
  from the list above.
- Do not introduce concepts, themes, or absences that cannot be traced to an actual topic.
- If you cannot name the specific topic, do not make the finding.
- Prefer fine-grained distinctions over broad summaries.
- Skip anything predictable given the group name.
- Skip the free/reduced lunch poverty framing — it appears everywhere and is already known.
- Skip generic engagement/motivation language unless the topic evidence makes it unusually specific.
- If fewer than two strong findings exist for a section, write one or write none. Do not pad.

Focus on:
1. SUBTHEME DISTINCTIONS — distinct needs, populations, pedagogies, use cases, or framing
   modes within this group.

2. INTERNAL FRAMING DIFFERENCES — cases within this group where similar underlying needs are
   presented through meaningfully different rhetorical frames, populations, or classroom
   contexts.

3. NOTABLE ABSENCES — a topic you would expect given the internal logic of this group's other
   topics, but that is missing.

4. REQUEST TRIGGERS AND PITCH STRATEGIES — patterns in why teachers say they are requesting
   within this group and how they frame that reason for a donor audience.

Formatting: use plain numbered section headers (e.g. '1. SUBTHEME DISTINCTIONS').
Do not use markdown headers (##). Do not use bullet points.

Format as four labeled sections. Under each, write 2-5 findings as short paragraphs.
Be specific — name the topic label every time. Do not use bullet points.
""".strip()

def build_per_group_prompt(group, topic_lines_text):
    return f"""
Below is a list of NMF topics discovered from teacher project request essays on DonorsChoose
for a single group: {group} ({GROUP_DESCRIPTION}).
Each topic represents a cluster of essays with similar language, framing, and request patterns.
{topic_lines_text}

{PER_GROUP_INSTRUCTIONS}
""".strip()

def _call_with_retry(prompt, max_retries=3):
    for attempt in range(max_retries + 1):
        try:
            resp = client.chat.completions.create(
                model=MODEL_SYNTHESIS,
                messages=[
                    {"role": "system", "content": SYNTHESIS_SYSTEM},
                    {"role": "user",   "content": prompt},
                ],
            )
            return resp.choices[0].message.content.strip()
        except (_openai.RateLimitError, _openai.APITimeoutError) as e:
            if attempt < max_retries:
                _time.sleep(2 ** attempt)
            else:
                raise
        except Exception as e:
            print(f"Non-retryable error: {e}")
            return None

synthesis_cross = _call_with_retry(SYNTHESIS_PROMPT_CROSS_GROUP)
if synthesis_cross is None:
    append_warning(
        WARNINGS_PATH,
        "03_insights_generation",
        "SYNTHESIS_CROSS_GROUP_FAILED",
        "Cross-group synthesis failed",
        context={},
    )
    raise RuntimeError("Cross-group synthesis failed; stopping before downstream cells.")

with open(OUT("analysis", "llm_synthesis_cross_group.txt"), "w", encoding="utf-8") as f:
    f.write(synthesis_cross)

groups = [
    g for g in labels_df[GROUPBY_FIELD].dropna().unique().tolist()
    if g not in EXCLUDE_GROUPS
]

def synthesize_one_group(group):
    topic_lines_text = build_topic_lines(labels_df, GROUPBY_FIELD, group=group)
    prompt = build_per_group_prompt(group, topic_lines_text)
    result = _call_with_retry(prompt)
    if result is None:
        append_warning(
            WARNINGS_PATH,
            "03_insights_generation",
            "SYNTHESIS_GROUP_FAILED",
            f"Synthesis failed for group '{group}'",
            context={"group": group},
        )
        return group, None
    slug = slugify_group_value(group)
    fpath = OUT("analysis", f"llm_synthesis_{slug}.txt")
    with open(fpath, "w", encoding="utf-8") as f:
        f.write(result)
    return group, result

per_group_results = {}
SYNTHESIS_FAILED_GROUPS = []

with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    futures = {executor.submit(synthesize_one_group, g): g for g in groups}
    for future in as_completed(futures):
        submitted_group = futures[future]
        try:
            group, result = future.result()
        except Exception as e:
            SYNTHESIS_FAILED_GROUPS.append(str(submitted_group))
            append_warning(
                WARNINGS_PATH,
                "03_insights_generation",
                "SYNTHESIS_GROUP_FAILED",
                f"Synthesis failed for group '{submitted_group}'",
                context={"group": submitted_group, "error": str(e)},
            )
            print(f"FAILED: {submitted_group} | error: {e}")
            continue

        if result is not None:
            per_group_results[group] = result
            print(f"Done: {group}")
        else:
            SYNTHESIS_FAILED_GROUPS.append(str(group))
            print(f"FAILED: {group}")

per_group_results = {g: per_group_results[g] for g in groups if g in per_group_results}

if not per_group_results:
    raise RuntimeError("No per-group synthesis results were produced; stopping before downstream cells.")
# Out:
# Done: 2015.0_Q2.0
# Done: 2014.0_Q3.0
# Done: 2015.0_Q3.0
# Done: 2016.0_Q2.0
# Done: 2015.0_Q1.0
# Done: 2014.0_Q4.0
# Done: 2016.0_Q1.0
# Done: 2015.0_Q4.0
# Done: 2016.0_Q3.0
# Done: 2016.0_Q4.0
# Done: 2017.0_Q3.0
# Done: 2017.0_Q2.0
# Done: 2017.0_Q1.0
# Done: 2017.0_Q4.0
# Done: 2018.0_Q1.0
# Done: 2018.0_Q2.0
# Done: 2018.0_Q3.0
# Done: 2018.0_Q4.0
# Done: 2019.0_Q1.0
# Done: 2019.0_Q2.0
# Done: 2019.0_Q3.0
# Done: 2020.0_Q1.0
# Done: 2019.0_Q4.0
# Done: 2020.0_Q2.0
# Done: 2020.0_Q3.0
# Done: 2021.0_Q1.0
# Done: 2021.0_Q2.0
# Done: 2021.0_Q4.0
# Done: 2020.0_Q4.0
# Done: 2021.0_Q3.0
# Done: 2022.0_Q1.0
# Done: 2022.0_Q2.0
# Done: 2022.0_Q3.0
# Done: 2023.0_Q4.0
# Done: 2022.0_Q4.0
# Done: 2023.0_Q1.0
# Done: 2023.0_Q3.0
# Done: 2023.0_Q2.0
# Done: 2024.0_Q2.0
# Done: 2024.0_Q1.0
# Done: 2024.0_Q3.0
# Done: 2025.0_Q1.0
# Done: 2024.0_Q4.0
# Done: 2025.0_Q3.0
# Done: 2025.0_Q2.0
# Done: 2019_Q4
# Done: 2025.0_Q4.0
# Done: 2026.0_Q1.0
# Done: nan_Qnan
# Done: 2021_Q3
# Done: 2023_Q4

# %%
# ── EXTERNAL-FACING INSIGHTS — structured JSON call ───────────────────────
OUTPUT_GROUP_KEY = "by_group"
REQUIRED_GROUP_VALUES = list(per_group_results.keys())

if not REQUIRED_GROUP_VALUES:
    raise RuntimeError("No synthesized group results are available; cannot build external-facing insights.")

def strip_json_fences(text):
    text = (text or "").strip()
    text = re.sub(r"^\s*```(?:json)?\s*", "", text, flags=re.IGNORECASE)
    text = re.sub(r"\s*```\s*$", "", text)
    return text.strip()

def normalize_source_topics(source_topics):
    """Normalize model output to [{'group': ..., 'topic_id': int}] with light recovery."""
    out = []

    for src in source_topics or []:
        group = None
        tid = None

        if isinstance(src, dict):
            group = src.get("group", src.get("group_value", ""))
            tid = src.get("topic_id", src.get("topic", src.get("id", "")))

        elif isinstance(src, str):
            s = src.strip()

            # Expected compact form: "<group>|<topic_id>"
            if "|" in s:
                left, right = s.rsplit("|", 1)
                group = left.strip()
                tid = right.strip()

            # Recovery form: "Topic 7"
            elif re.fullmatch(r"(?i)topic\s+\d+", s):
                tid = re.sub(r"(?i)topic\s+", "", s).strip()

        if group is not None:
            group = str(group).strip()
        if tid is not None:
            tid = str(tid).strip()

        if not tid:
            continue

        try:
            tid = int(float(tid))
        except Exception:
            continue

        # Only keep rows with an explicit group; skip ambiguous recovered topic-only rows
        if not group:
            continue

        out.append({"group": group, "topic_id": tid})

    deduped = []
    seen = set()
    for item in out:
        key = (item["group"], item["topic_id"])
        if key not in seen:
            seen.add(key)
            deduped.append(item)

    return deduped

def normalize_insight(insight):
    if not isinstance(insight, dict):
        raise ValueError(f"Insight must be a dict, got {type(insight)}")

    raw_source_topics = deepcopy(insight.get("source_topics", []))
    source_topics = normalize_source_topics(raw_source_topics)

    normalized = {
        "title": str(insight.get("title", "")).strip(),
        "what_seeing": str(insight.get("what_seeing", "")).strip(),
        "why_easy_to_miss": str(insight.get("why_easy_to_miss", "")).strip(),
        "what_it_means": str(insight.get("what_it_means", "")).strip(),
        "source_topics": source_topics,
        "source_topics_claimed": raw_source_topics,
    }
    if not normalized["title"]:
        raise ValueError(f"Insight missing title: {insight}")
    return normalized

synthesis_parts = []
if synthesis_cross:
    synthesis_parts.append(f"=== CROSS-GROUP ANALYSIS ===\n{synthesis_cross}")
for group_value, text in per_group_results.items():
    if text:
        synthesis_parts.append(f"=== {group_value} ===\n{text}")
synthesis_input = "\n\n".join(synthesis_parts)

INSIGHTS_SYSTEM = (
    "You are a senior program analyst at an educational nonprofit. "
    "You write precise, decision-facing briefings for external audiences: "
    "foundations, corporate partners, policymakers, and major donors. "
    "You return ONLY valid JSON. No preamble, no explanation, no markdown fences."
)

example_source_topics = []
example_rows = (
    labels_df[[GROUPBY_FIELD, "topic_id"]]
    .drop_duplicates()
    .head(3)
    .to_dict("records")
)

for row in example_rows:
    example_source_topics.append(f"{row[GROUPBY_FIELD]}|{int(row['topic_id'])}")

if not example_source_topics:
    for i, gv in enumerate(REQUIRED_GROUP_VALUES[:2], start=1):
        example_source_topics.append(f"{gv}|{i}")

example_source_topics_json = json.dumps(example_source_topics, ensure_ascii=False)

INSIGHTS_PROMPT = f"""
You are given a comprehensive structured analysis of classroom project request patterns including:
within-group subthemes, cross-group signatures, framing differences, notable absences,
and request triggers and pitch strategies.

The analysis is grouped by the field "{GROUPBY_FIELD}" ({GROUP_DESCRIPTION}).

{synthesis_input}

Your task: produce a decision-facing insights document for external stakeholders —
executives, foundation leaders, state legislators, and major donors — who are
intelligent but not close to classroom realities. These readers should finish each
insight thinking: "I never would have known that, and the fact that this organization
can see it means I should take their priorities seriously."

SELECTION CRITERIA:
- Each insight must surface something genuinely non-obvious about what classrooms need,
  reframe how a thoughtful outsider should interpret teacher demand, and have a clear
  implication for where attention or resources should go.
- Prioritize insights that reveal hidden scale, misallocated attention, or a shift in
  how teachers are operating that external stakeholders would not expect.
- Avoid methodological commentary, insights that only matter to data practitioners,
  and observations that merely restate what the group label already suggests.

COUNT + COVERAGE REQUIREMENTS:
- Return between 6 and 15 cross-group insights in "key_insights". Produce as many as
  the evidence strongly supports — do not pad to reach a target and do not stop early
  if strong findings remain.
- "{OUTPUT_GROUP_KEY}" must include every group value in this exact list:
  {json.dumps(REQUIRED_GROUP_VALUES, ensure_ascii=False)}
- Return exactly 1 strongest defensible insight for each group value above.
- Do not omit group values silently.
- Prefer slightly weaker but still defensible coverage over omission.

INSIGHT STRUCTURE — for every insight use exactly these fields:
- title: a crisp, declarative headline that makes the finding feel like a reveal,
  not a description.
- what_seeing: 2-4 sentences describing the observed pattern in plain, concrete language.
  Write about what teachers are actually doing or asking for — not about the analysis.
- why_easy_to_miss: 1-2 sentences explaining why this pattern is invisible to someone
  looking at surface-level groups or conventional reporting.
- what_it_means: 2-4 sentences translating the pattern into consequence.
  This should land like a strategic implication, not an analytical note.
- source_topics: a list of the strongest grounding topics for the insight.
  Use only topics that directly support the claim.
  Usually 2-4 topics is enough, but do not force a fixed count.
  Prefer fewer well-matched topics over padding with weak ones.
  Required format:
    - each item must be a string
    - each string must be exactly "<group_value>|<topic_id>"
    - group_value must exactly match one of the group values shown in the analysis
    - topic_id must be the integer topic number for that group
  Do not use labels, category names, prose, or invented group names in place of group_value.
  Example for this run: {example_source_topics_json}
- Do not include a "section" field inside each insight.
  Section is implied by where the insight appears in the JSON.

STYLE:
- Direct, confident, and human — not academic, not corporate.
- No mention of "topics", "model", "NMF", "pipeline", "cluster", or analytical machinery.
- No hedging phrases like "may suggest" or "could indicate".
- No filler.
- Do not repeat the same implication across insights.

VALIDITY RULES:
- Return valid JSON only.
- The response is incomplete if any required group value is missing from "{OUTPUT_GROUP_KEY}".
- Do not return markdown fences or explanatory text.

Return a JSON object with exactly this structure:
{{
  "key_insights": [/* 6-15 insight objects */],
  "{OUTPUT_GROUP_KEY}": {{
    "<group value>": [/* exactly 1 insight object */],
    ...
  }}
}}
""".strip()

resp = client.chat.completions.create(
    model=MODEL_SYNTHESIS,
    messages=[
        {"role": "system", "content": INSIGHTS_SYSTEM},
        {"role": "user",   "content": INSIGHTS_PROMPT},
    ],
    response_format={"type": "json_object"},
)

raw_json = strip_json_fences(resp.choices[0].message.content)
insights_data = json.loads(raw_json)

if not isinstance(insights_data, dict):
    raise ValueError("Top-level insights response is not a JSON object.")

raw_key = insights_data.get("key_insights", [])
raw_by_group = insights_data.get(OUTPUT_GROUP_KEY, {})

if not isinstance(raw_key, list):
    raise ValueError("key_insights is not a list.")
if not isinstance(raw_by_group, dict):
    raise ValueError(f"{OUTPUT_GROUP_KEY} is not an object.")

normalized = {
    "key_insights": [normalize_insight(i) for i in raw_key],
    OUTPUT_GROUP_KEY: {},
}

missing_group_values = [g for g in REQUIRED_GROUP_VALUES if g not in raw_by_group]
if missing_group_values:
    raise ValueError(f"Model omitted required group values: {missing_group_values}")

extra_group_values = [g for g in raw_by_group.keys() if g not in REQUIRED_GROUP_VALUES]
if extra_group_values:
    print(f"WARNING: extra group values returned and ignored: {extra_group_values}")

for group_value in REQUIRED_GROUP_VALUES:
    items = raw_by_group.get(group_value, [])
    if not isinstance(items, list):
        raise ValueError(f"{OUTPUT_GROUP_KEY}['{group_value}'] is not a list.")
    normalized[OUTPUT_GROUP_KEY][group_value] = [normalize_insight(i) for i in items]

insights_data = normalized

if not (6 <= len(insights_data["key_insights"]) <= 15):
    raise ValueError(f"Expected between 6 and 15 key insights, got {len(insights_data['key_insights'])}")

bad_group_counts = {
    group_value: len(items)
    for group_value, items in insights_data[OUTPUT_GROUP_KEY].items()
    if len(items) != 1
}
if bad_group_counts:
    raise ValueError(f"Expected exactly 1 insight per group value, got: {bad_group_counts}")

# Mid-cell write required by spec: post-normalize_insight(), pre-verification
write_json(OUT("insights", "insights_candidates.json"), insights_data)
# Out:
# PosixPath('/Users/matt.fritz/Desktop/Research Insights/Essay Prototype/OUTPUTS/runs/posted_year_quarter/2026-03-31/20260331_101735_posted_year_quarter_a36f58b0/insights/insights_candidates.json')

# %%
total_source_topics = (
    sum(len(i.get("source_topics", [])) for i in insights_data["key_insights"]) +
    sum(len(i.get("source_topics", [])) for items in insights_data[OUTPUT_GROUP_KEY].values() for i in items)
)

print(f"Key insights:  {len(insights_data.get('key_insights', []))}")
print(f"Group values:  {list(insights_data.get(OUTPUT_GROUP_KEY, {}).keys())}")
print(f"Total source_topics across all insights: {total_source_topics}")
# Out:
# Key insights:  8
# Group values:  ['2014.0_Q3.0', '2014.0_Q4.0', '2015.0_Q1.0', '2015.0_Q2.0', '2015.0_Q3.0', '2015.0_Q4.0', '2016.0_Q1.0', '2016.0_Q2.0', '2016.0_Q3.0', '2016.0_Q4.0', '2017.0_Q1.0', '2017.0_Q2.0', '2017.0_Q3.0', '2017.0_Q4.0', '2018.0_Q1.0', '2018.0_Q2.0', '2018.0_Q3.0', '2018.0_Q4.0', '2019.0_Q1.0', '2019.0_Q2.0', '2019.0_Q3.0', '2019.0_Q4.0', '2020.0_Q1.0', '2020.0_Q2.0', '2020.0_Q3.0', '2020.0_Q4.0', '2021.0_Q1.0', '2021.0_Q2.0', '2021.0_Q3.0', '2021.0_Q4.0', '2022.0_Q1.0', '2022.0_Q2.0', '2022.0_Q3.0', '2022.0_Q4.0', '2023.0_Q1.0', '2023.0_Q2.0', '2023.0_Q3.0', '2023.0_Q4.0', '2024.0_Q1.0', '2024.0_Q2.0', '2024.0_Q3.0', '2024.0_Q4.0', '2025.0_Q1.0', '2025.0_Q2.0', '2025.0_Q3.0', '2025.0_Q4.0', '2026.0_Q1.0', 'nan_Qnan', '2019_Q4', '2021_Q3', '2023_Q4']
# Total source_topics across all insights: 143

# %%
VERIFY_SYSTEM = (
    "You are checking whether topic labels correctly support a given insight. "
    "Be strict. If the topic is only loosely related, drop it. "
    "Return only valid JSON."
)

def verify_source_topics(insight, labels_df, groupby_field, max_retries=3):
    title = insight.get("title", "")
    what_seeing = insight.get("what_seeing", "")
    what_it_means = insight.get("what_it_means", "")
    source_topics = insight.get("source_topics", [])
    warning_identifier = title[:120] if str(title).strip() else str(what_seeing).strip()[:120]

    if not source_topics:
        return insight

    topic_lines = []
    for src in source_topics:
        if isinstance(src, dict):
            group = src.get("group", "")
            tid = str(src.get("topic_id", ""))
        elif isinstance(src, str) and "|" in src:
            group, tid = src.rsplit("|", 1)
        else:
            continue

        match = labels_df[
            (labels_df[groupby_field] == group) &
            (labels_df["topic_id"] == int(float(tid)))
        ]
        if not match.empty:
            row = match.iloc[0]
            topic_lines.append(
                f"  {group}|{tid} | label: {row['proposed_label']} | "
                f"description: {row['description']}"
            )

    if not topic_lines:
        return insight

    prompt = f"""
Insight title: {title}

What we're seeing: {what_seeing}

What it means: {what_it_means}

Claimed source topics:
{chr(10).join(topic_lines)}

Return JSON: {{"verified_topics": [{{"group": "...", "topic_id": <int>}}, ...]}}
""".strip()

    for attempt in range(max_retries + 1):
        try:
            resp = client.chat.completions.create(
                model=MODEL_SYNTHESIS,
                messages=[
                    {"role": "system", "content": VERIFY_SYSTEM},
                    {"role": "user", "content": prompt},
                ],
                response_format={"type": "json_object"},
            )
            result = json.loads(resp.choices[0].message.content)
            original_n = len(source_topics)
            insight["source_topics"] = normalize_source_topics(result.get("verified_topics", source_topics))
            verified_n = len(insight.get("source_topics", []))
            if verified_n != original_n:
                print(f"Adjusted source_topics: {title[:80]} | {original_n} -> {verified_n}")
            if verified_n == 0 and original_n > 0:
                print(f"WARNING: all source_topics removed: {title[:80]}")
            return insight
        except (_openai.RateLimitError, _openai.APITimeoutError) as e:
            if attempt < max_retries:
                _time.sleep(2 ** attempt)
            else:
                append_warning(
                    WARNINGS_PATH,
                    "03_insights_generation",
                    "VERIFY_API_FAILURE",
                    f"Verification failed for '{warning_identifier or '[untitled]'}'",
                    context={
                        "title": title or None,
                        "what_seeing_preview": str(what_seeing).strip()[:120] or None,
                        "error": str(e),
                    },
                )
                return insight
        except Exception as e:
            append_warning(
                WARNINGS_PATH,
                "03_insights_generation",
                "VERIFY_API_FAILURE",
                f"Verification failed for '{warning_identifier or '[untitled]'}'",
                context={
                    "title": title or None,
                    "what_seeing_preview": str(what_seeing).strip()[:120] or None,
                    "error": str(e),
                },
            )
            return insight

for key in ["key_insights"]:
    insights_data[key] = [verify_source_topics(i, labels_df, GROUPBY_FIELD) for i in insights_data.get(key, [])]

for cat in insights_data.get(OUTPUT_GROUP_KEY, {}):
    insights_data[OUTPUT_GROUP_KEY][cat] = [
        verify_source_topics(i, labels_df, GROUPBY_FIELD)
        for i in insights_data[OUTPUT_GROUP_KEY][cat]
    ]

print("Verification complete.")
# Out:
# Adjusted source_topics: Teachers are asking donors to fund the operating system of school, not just clas | 4 -> 3
# Adjusted source_topics: Technology demand has shifted from modernization to survival to accessibility. | 4 -> 3
# Adjusted source_topics: The rise of teacher-pay gift cards reveals a procurement failure, not just teach | 4 -> 3
# Adjusted source_topics: Food requests are no longer framed mainly as charity; teachers present them as i | 3 -> 2
# Adjusted source_topics: Not all device requests were for students—teachers were already using tech to bu | 3 -> 1
# Adjusted source_topics: Teachers were already treating home access as a different problem from classroom | 3 -> 2
# Adjusted source_topics: Current-events reading was stable enough to function like its own literacy infra | 2 -> 1
# Adjusted source_topics: Food support entered as a different kind of school request—not a classroom suppl | 2 -> 1
# Adjusted source_topics: Teachers were already using maker tools as elementary engineering infrastructure | 2 -> 1
# Adjusted source_topics: Graphic novels emerged as a deliberate bridge for students who would not enter r | 2 -> 1
# Adjusted source_topics: Weekend food support had become a school-delivered readiness intervention, not j | 2 -> 1
# Adjusted source_topics: After hurricanes, teachers asked to rebuild school belonging through extracurric | 2 -> 1
# Adjusted source_topics: Flexible seating had become a differentiated-workflow tool, not just a way to he | 2 -> 1
# Adjusted source_topics: Just before shutdowns, teachers were already treating the classroom as an extens | 2 -> 1
# Adjusted source_topics: Remote-learning demand broke into distinct failure points almost immediately. | 4 -> 3
# Adjusted source_topics: The rise of teacher-pay gift cards marked a shift from buying supplies to buying | 2 -> 1
# Adjusted source_topics: Calm spaces emerged as a post-crisis recovery tool, not just a special education | 2 -> 1
# Adjusted source_topics: Teacher purchasing power had become a classroom input in its own right. | 2 -> 1
# Adjusted source_topics: Teachers were increasingly using donor psychology itself as part of the ask. | 2 -> 1
# Adjusted source_topics: Teachers began recasting low-glamour supports as academic achievement tools. | 2 -> 1
# Adjusted source_topics: By 2023, calm corners had shifted from pandemic recovery tools to durable classr | 2 -> 1
# Adjusted source_topics: Teachers were turning ordinary supplies into executive-function supports. | 2 -> 1
# Adjusted source_topics: The classroom itself was increasingly being funded as an inclusion platform. | 3 -> 2
# Adjusted source_topics: Teachers increasingly framed support as preserving existing programs, not launch | 3 -> 2
# Adjusted source_topics: Teachers were drawing a clear line between regulation space and movement-friendl | 2 -> 1
# Adjusted source_topics: Teachers were bundling food, hygiene, and winter gear because bodily stability h | 2 -> 1
# Verification complete.

# %%
# ── EVIDENCE PACK + CONFIDENCE SCORING ─────────────────────────────────────
assert "project_topic_bridge_df" in dir() and not project_topic_bridge_df.empty, (
    "project_topic_bridge_df missing — ensure the bridge-build cell ran successfully"
)

BRIDGE_LOOKUP = {
    topic_key: grp[["project_id", "weight", "topic_share"]].copy()
    for topic_key, grp in project_topic_bridge_df.groupby("topic_key", observed=True)
}

def get_topic_key(group, topic_id):
    return f"{GROUPBY_FIELD}={group}|topic={int(float(topic_id))}"

def get_project_ids(source_topics, bridge_lookup, max_ids=None):
    if not source_topics:
        return [], {}
    topic_rows_cache = {}
    records = []
    for src in source_topics:
        if isinstance(src, dict):
            group = str(src.get("group", "")).strip()
            topic_id = int(float(src.get("topic_id", -1)))
        elif isinstance(src, str) and "|" in src:
            group, topic_id = src.rsplit("|", 1)
            group = str(group).strip()
            topic_id = int(float(topic_id))
        else:
            continue
        topic_key = get_topic_key(group, topic_id)
        if topic_key not in topic_rows_cache:
            topic_rows_cache[topic_key] = bridge_lookup.get(
                topic_key,
                pd.DataFrame(columns=["project_id", "weight", "topic_share"]),
            )
        records.extend(topic_rows_cache[topic_key]["project_id"].tolist())
    seen = list(dict.fromkeys(records))
    return (seen if max_ids is None else seen[:max_ids]), topic_rows_cache

def iter_candidate_insights(data):
    idx = 1
    for insight in data.get("key_insights", []):
        yield {
            "insight_id": f"KI_{idx:03d}",
            "section": "key_insights",
            "category_bucket": None,
            "insight": insight,
        }
        idx += 1

    group_idx = 1
    for group_value, items in data.get(OUTPUT_GROUP_KEY, {}).items():
        for insight in items:
            yield {
                "insight_id": f"BG_{group_idx:03d}",
                "section": OUTPUT_GROUP_KEY,
                "category_bucket": group_value,
                "insight": insight,
            }
            group_idx += 1

candidate_rows = list(iter_candidate_insights(insights_data))

topic_rows_cache_global = {}
all_needed_pids = []
for row in candidate_rows:
    _, topic_rows_cache = get_project_ids(row["insight"].get("source_topics", []), BRIDGE_LOOKUP, max_ids=None)
    for topic_key, topic_rows in topic_rows_cache.items():
        if topic_key not in topic_rows_cache_global:
            topic_rows_cache_global[topic_key] = topic_rows
        all_needed_pids.extend(topic_rows["project_id"].tolist())

all_needed_pids = list(dict.fromkeys(all_needed_pids))

ESSAY_LOOKUP_PATH = ROOT / "OUTPUTS/prepared/02_project_essay_lookup.parquet"
if not ESSAY_LOOKUP_PATH.exists():
    raise FileNotFoundError(
        f"Essay lookup parquet not found: {ESSAY_LOOKUP_PATH}. Run Notebook 01 first."
    )

essay_lookup_df = pd.read_parquet(ESSAY_LOOKUP_PATH, columns=["project_id", "essay_text"])
essay_lookup = (
    essay_lookup_df[essay_lookup_df["project_id"].isin(all_needed_pids)]
    .drop_duplicates(subset=["project_id"], keep="first")
    .set_index("project_id")["essay_text"]
    .to_dict()
)

token_lookup = df.set_index("project_id")["tokens"].to_dict()

def _parse_topic_id(val):
    """Handle both plain ints and 'Topic N' strings from model output."""
    s = str(val).strip()
    if s.lower().startswith("topic"):
        s = s.split()[-1]
    return int(s)

label_index = {}
for _, row in labels_df.iterrows():
    try:
        tid = _parse_topic_id(row["topic_id"])
        label_index[(str(row[GROUPBY_FIELD]), tid)] = row
    except (ValueError, IndexError):
        append_warning(
            WARNINGS_PATH,
            "03_insights_generation",
            "LABEL_INDEX_PARSE_FAILURE",
            f"Could not parse topic_id '{row['topic_id']}' for group '{row[GROUPBY_FIELD]}'",
            context={"group": str(row[GROUPBY_FIELD]), "topic_id": str(row["topic_id"])},
        )

def build_full_essay_text(project_id):
    if project_id in essay_lookup and str(essay_lookup[project_id]).strip():
        return re.sub(r"\s+", " ", str(essay_lookup[project_id])).strip()
    return ""

def build_injected_tokens(project_id):
    tokens = token_lookup.get(project_id, [])
    injected = [
        str(t).strip()
        for t in tokens
        if re.fullmatch(r"__[^_]+(?:_[^_]+)*__", str(t).strip())
    ]
    injected = list(dict.fromkeys(injected))
    return " | ".join(injected)

def build_evidence_obj(candidate):
    insight = candidate["insight"]
    source_topics = insight.get("source_topics", [])
    claimed_topic_count = len(insight.get("source_topics_claimed", []))
    supporting_project_ids, topic_rows_cache = get_project_ids(source_topics, topic_rows_cache_global, max_ids=None)

    topic_support = []
    for src in source_topics:
        if not isinstance(src, dict):
            continue
        group = str(src.get("group", ""))
        topic_id = int(float(src.get("topic_id", -1)))
        topic_key = get_topic_key(group, topic_id)
        topic_rows = topic_rows_cache.get(topic_key, pd.DataFrame(columns=["project_id", "weight", "topic_share"]))
        label_row = label_index.get((group, topic_id))
        topic_support.append({
            "group": group,
            "topic_id": topic_id,
            "topic_label": label_row["proposed_label"] if label_row is not None else "[not found in labels_df]",
            "topic_description": label_row["description"] if label_row is not None else "[not found in labels_df]",
            "coherence_flag": label_row["coherence_flag"] if label_row is not None else "unknown",
            "supporting_project_count": int(topic_rows["project_id"].nunique()) if not topic_rows.empty else 0,
            "mean_topic_share": float(topic_rows["topic_share"].mean()) if not topic_rows.empty else 0.0,
            "median_topic_share": float(topic_rows["topic_share"].median()) if not topic_rows.empty else 0.0,
        })

    sample_projects = []
    for pid in supporting_project_ids[:N_REPRESENTATIVE]:
        matches = []
        for src in source_topics:
            if not isinstance(src, dict):
                continue
            topic_key = get_topic_key(src.get("group", ""), src.get("topic_id", -1))
            topic_rows = topic_rows_cache.get(topic_key, pd.DataFrame(columns=["project_id", "topic_share"]))
            hit = topic_rows[topic_rows["project_id"] == pid]
            if not hit.empty:
                matches.append((src["group"], int(float(src["topic_id"])), float(hit["topic_share"].iloc[0])))
        if matches:
            best = sorted(matches, key=lambda x: x[2], reverse=True)[0]
            sample_projects.append({
                "project_id": pid,
                "group": best[0],
                "topic_id": best[1],
                "topic_share": best[2],
            })

    return {
        "schema_version": "v1",
        "run_id": RUN_ID,
        "insight_id": candidate["insight_id"],
        "section": candidate["section"],
        "category_bucket": candidate["category_bucket"],
        "group_by_field": GROUPBY_FIELD,
        "title": insight.get("title", ""),
        "what_seeing": insight.get("what_seeing", ""),
        "why_easy_to_miss": insight.get("why_easy_to_miss", ""),
        "what_it_means": insight.get("what_it_means", ""),
        "source_topics_claimed": insight.get("source_topics_claimed", []),
        "source_topics_verified": source_topics,
        "verification_drop_count": int(max(claimed_topic_count - len(source_topics), 0)),
        "supporting_project_count": int(len(supporting_project_ids)),
        "topic_support": topic_support,
        "sample_projects": sample_projects,
        "claimed_topic_count": int(claimed_topic_count),
    }

candidate_evidence_rows = [build_evidence_obj(row) for row in candidate_rows]

CONFIDENCE_CFG = CFG["analysis"]["confidence"]
TOPIC_QUALITY_MAP = {"coherent": 1.0, "mixed": 0.5, "redundant": 0.0, "unclear": 0.0, "unknown": 0.0}

CONFIDENCE_RATIONALE_SYSTEM = (
    "You explain confidence scores for analytical insights. Return only one short sentence."
)

def build_confidence_rationale(conf_row):
    prompt = (
        f"Insight: {conf_row['title']}\n"
        f"Support volume score: {conf_row['support_volume_score']:.1f}\n"
        f"Support breadth score: {conf_row['support_breadth_score']:.1f}\n"
        f"Topic quality score: {conf_row['topic_quality_score']:.1f}\n"
        f"Bridge strength score: {conf_row['bridge_strength_score']:.1f}\n"
        f"Verification cleanliness score: {conf_row['verification_cleanliness_score']:.1f}\n"
        f"Penalty score: {conf_row['penalty_score']:.1f}\n"
        f"Final confidence: {conf_row['confidence_score']:.1f} ({conf_row['confidence_band']})\n"
        "Explain the main drivers in one short sentence."
    )
    try:
        resp = client.chat.completions.create(
            model=MODEL_LABELING,
            messages=[
                {"role": "system", "content": CONFIDENCE_RATIONALE_SYSTEM},
                {"role": "user", "content": prompt},
            ],
        )
        return resp.choices[0].message.content.strip()
    except Exception:
        return (
            f"Confidence is {conf_row['confidence_band']} because support volume, topic cleanliness, "
            f"and bridge strength combine to {conf_row['confidence_score']:.1f} after penalties."
        )

def score_insight_confidence(evidence_obj, cfg):
    verified_topic_coherence_flags = [ts["coherence_flag"] for ts in evidence_obj["topic_support"]]
    supporting_project_count = int(evidence_obj["supporting_project_count"])
    verified_topic_count = int(len(evidence_obj["source_topics_verified"]))
    claimed_topic_count = int(evidence_obj["claimed_topic_count"])

    support_volume_score = min(
        100.0,
        100.0 * supporting_project_count / cfg["support_volume_scale_projects"],
    )
    support_breadth_score = min(
        100.0,
        100.0 * verified_topic_count / cfg["support_breadth_scale_topics"],
    )
    topic_quality_score = (
        0.0 if not verified_topic_coherence_flags
        else 100.0 * mean(TOPIC_QUALITY_MAP.get(flag, 0.0) for flag in verified_topic_coherence_flags)
    )
    mean_topic_share_all_verified_topics = (
        0.0 if not evidence_obj["topic_support"]
        else float(mean(ts["mean_topic_share"] for ts in evidence_obj["topic_support"]))
    )
    bridge_strength_score = (
        0.0 if not evidence_obj["topic_support"]
        else min(100.0, 100.0 * mean_topic_share_all_verified_topics / cfg["bridge_strength_scale_topic_share"])
    )
    verification_cleanliness_score = (
        100.0 if claimed_topic_count == 0
        else 100.0 * verified_topic_count / claimed_topic_count
    )

    penalty_score = 0.0
    if supporting_project_count < 10:
        penalty_score -= cfg["penalties"]["low_support_penalty"]
    if any(flag == "unclear" for flag in verified_topic_coherence_flags):
        penalty_score -= cfg["penalties"]["unclear_topic_penalty"]
    if verification_cleanliness_score < 50:
        penalty_score -= cfg["penalties"]["low_verification_cleanliness_penalty"]
    if bridge_strength_score < 50:
        penalty_score -= cfg["penalties"]["low_bridge_strength_penalty"]

    confidence_score = (
        0.30 * support_volume_score +
        0.15 * support_breadth_score +
        0.20 * topic_quality_score +
        0.20 * bridge_strength_score +
        0.15 * verification_cleanliness_score +
        penalty_score
    )
    confidence_score = round(max(0.0, min(100.0, confidence_score)), 1)

    if confidence_score >= cfg["band_thresholds"]["high"]:
        confidence_band = "high"
    elif confidence_score >= cfg["band_thresholds"]["medium"]:
        confidence_band = "medium"
    else:
        confidence_band = "low"

    # ── confidence_rationale is intentionally excluded here.
    # It is built separately in parallel below and merged back into conf_rows.
    return {
        "support_volume_score": round(support_volume_score, 1),
        "support_breadth_score": round(support_breadth_score, 1),
        "topic_quality_score": round(topic_quality_score, 1),
        "bridge_strength_score": round(bridge_strength_score, 1),
        "verification_cleanliness_score": round(verification_cleanliness_score, 1),
        "penalty_score": round(penalty_score, 1),
        "confidence_score": confidence_score,
        "confidence_band": confidence_band,
        "confidence_rationale": None,  # placeholder — filled by parallel block below
        "supporting_project_count": supporting_project_count,
        "verified_topic_count": verified_topic_count,
        "claimed_topic_count": claimed_topic_count,
        "mean_topic_share_all_verified_topics": round(mean_topic_share_all_verified_topics, 4),
        "verified_topic_coherence_flags": verified_topic_coherence_flags,
    }

conf_rows = []
for ev in candidate_evidence_rows:
    conf = score_insight_confidence(ev, CONFIDENCE_CFG)
    conf["insight_id"] = ev["insight_id"]
    conf["title"] = ev["title"]
    conf["confidence_version"] = "v1"
    conf_rows.append(conf)

# ── parallel rationale generation ─────────────────────────────────────────────
def _build_rationale_for_row(conf_row):
    rationale = build_confidence_rationale(conf_row)
    return conf_row["insight_id"], rationale

rationale_map = {}
with ThreadPoolExecutor(max_workers=LABELING_MAX_WORKERS) as executor:
    futures = {executor.submit(_build_rationale_for_row, row): row["insight_id"]
               for row in conf_rows}
    for future in as_completed(futures):
        try:
            insight_id, rationale = future.result()
            rationale_map[insight_id] = rationale
        except Exception as e:
            insight_id = futures[future]
            append_warning(
                WARNINGS_PATH,
                "03_insights_generation",
                "RATIONALE_API_FAILURE",
                f"Confidence rationale failed for '{insight_id}'",
                context={"insight_id": insight_id, "error": str(e)},
            )
            rationale_map[insight_id] = None

for row in conf_rows:
    row["confidence_rationale"] = rationale_map.get(row["insight_id"])

conf_df = pd.DataFrame(conf_rows)
conf_df.to_csv(OUT("insights", "insights_confidence.csv"), index=False)
print(f"Scored {len(conf_df):,} candidate insights")

# ── STRICT CHANGE VERIFICATION ────────────────────────────────────────────────
# Confirms that the only structural change from the original is the parallelization
# of build_confidence_rationale. All other logic, keys, values, and outputs must
# be identical. Raises AssertionError immediately on any violation.

_expected_conf_df_columns = {
    "support_volume_score", "support_breadth_score", "topic_quality_score",
    "bridge_strength_score", "verification_cleanliness_score", "penalty_score",
    "confidence_score", "confidence_band", "confidence_rationale",
    "supporting_project_count", "verified_topic_count", "claimed_topic_count",
    "mean_topic_share_all_verified_topics", "verified_topic_coherence_flags",
    "insight_id", "title", "confidence_version",
}
_actual_cols = set(conf_df.columns)
_missing = _expected_conf_df_columns - _actual_cols
_extra   = _actual_cols - _expected_conf_df_columns
assert not _missing, f"CHANGE VERIFICATION FAILED — columns missing from conf_df: {_missing}"
assert not _extra,   f"CHANGE VERIFICATION FAILED — unexpected new columns in conf_df: {_extra}"

assert len(conf_df) == len(candidate_evidence_rows), (
    f"CHANGE VERIFICATION FAILED — conf_df row count {len(conf_df)} "
    f"does not match candidate_evidence_rows count {len(candidate_evidence_rows)}"
)

assert conf_df["confidence_version"].eq("v1").all(), (
    "CHANGE VERIFICATION FAILED — confidence_version is not 'v1' for all rows"
)

assert conf_df["confidence_rationale"].notna().all() or rationale_map, (
    "CHANGE VERIFICATION FAILED — confidence_rationale column is entirely null "
    "and rationale_map is empty; parallel block may not have executed"
)

_rationale_none_count = conf_df["confidence_rationale"].isna().sum()
if _rationale_none_count > 0:
    print(f"WARNING: {_rationale_none_count} insight(s) have null confidence_rationale "
          f"due to API failures — check warnings_03.jsonl for RATIONALE_API_FAILURE entries")

assert set(conf_df["insight_id"]) == {row["insight_id"] for row in candidate_evidence_rows}, (
    "CHANGE VERIFICATION FAILED — insight_id set in conf_df does not match candidate_evidence_rows"
)

_score_cols = [
    "support_volume_score", "support_breadth_score", "topic_quality_score",
    "bridge_strength_score", "verification_cleanliness_score",
]
for col in _score_cols:
    assert conf_df[col].between(0.0, 100.0).all(), (
        f"CHANGE VERIFICATION FAILED — {col} contains values outside [0, 100]"
    )

assert conf_df["confidence_score"].between(0.0, 100.0).all(), (
    "CHANGE VERIFICATION FAILED — confidence_score contains values outside [0, 100]"
)

assert conf_df["confidence_band"].isin({"high", "medium", "low"}).all(), (
    "CHANGE VERIFICATION FAILED — confidence_band contains unexpected values: "
    f"{conf_df['confidence_band'].unique().tolist()}"
)

_conf_output_path = OUT("insights", "insights_confidence.csv")
assert _conf_output_path.exists(), (
    f"CHANGE VERIFICATION FAILED — insights_confidence.csv was not written to {_conf_output_path}"
)

print("Change verification passed — conf_df structure, row count, score ranges, "
      "bands, insight_id alignment, and output file all confirmed.")
# Out:
# Scored 59 candidate insights
# Change verification passed — conf_df structure, row count, score ranges, bands, insight_id alignment, and output file all confirmed.

# %% [markdown]
# ---

# %%
# ── CONFIDENCE CALIBRATION DIAGNOSTIC ──────────────────────────────────────
# NEW CELL — insert after confidence scoring cell, before tiering cell.
# Read-only. No side effects. Purpose: surface whether formula scale params
# and tiering thresholds will discriminate meaningfully on this corpus.
# Adjust params.yaml [analysis][confidence] and [analysis][tiering] based
# on the output, then re-run from the confidence scoring cell if needed.

conf_cfg = CFG["analysis"]["confidence"]
tier_cfg = CFG["analysis"]["tiering"]

# ── Join supporting_project_count and verified_topic_count from evidence pack
# (these are inputs to the confidence formula, not stored in conf_df itself)
evidence_index = {
    row["insight_id"]: row
    for row in candidate_evidence_rows
}

diag = conf_df.copy()

diag["supporting_project_count"] = diag["insight_id"].map(
    lambda iid: evidence_index[iid]["supporting_project_count"]
    if iid in evidence_index else 0
)
diag["verified_topic_count"] = diag["insight_id"].map(
    lambda iid: len(evidence_index[iid].get("source_topics_verified", []))
    if iid in evidence_index else 0
)

# Collect all per-topic mean_topic_share values for bridge strength calibration
all_mean_shares = [
    ts["mean_topic_share"]
    for row in candidate_evidence_rows
    for ts in row.get("topic_support", [])
    if "mean_topic_share" in ts
]

component_cols = [
    "support_volume_score",
    "support_breadth_score",
    "topic_quality_score",
    "bridge_strength_score",
    "verification_cleanliness_score",
]

# ── 1. Header ──────────────────────────────────────────────────────────────
n = len(diag)
print("=" * 65)
print("  CONFIDENCE CALIBRATION DIAGNOSTIC")
print(f"  insights scored: {n}  |  groupby: {GROUPBY_FIELD}")
print("=" * 65)

# ── 2. Component distributions ─────────────────────────────────────────────
print("\n── Component score distributions (0–100 scale) ──")
print(
    diag[component_cols + ["penalty_score", "confidence_score"]]
    .describe(percentiles=[.1, .25, .5, .75, .9])
    .round(1)
    .to_string()
)

# ── 3. Ceiling hits — components that aren't discriminating ────────────────
print("\n── Ceiling hits (score >= 99.9) — components maxed for too many insights ──")
any_ceiling_problem = False
for col in component_cols:
    maxed = (diag[col] >= 99.9).sum()
    pct   = 100 * maxed / n if n else 0
    flag  = "  ⚠  not discriminating" if pct > 70 else ""
    print(f"  {col:<42s}: {maxed:>3}/{n}  ({pct:5.1f}%){flag}")
    if pct > 70:
        any_ceiling_problem = True

if any_ceiling_problem:
    print("\n  Current scale params (from params.yaml):")
    print(f"    support_volume_scale_projects     = {conf_cfg['support_volume_scale_projects']}")
    print(f"    support_breadth_scale_topics      = {conf_cfg['support_breadth_scale_topics']}")
    print(f"    bridge_strength_scale_topic_share = {conf_cfg['bridge_strength_scale_topic_share']}")
    print("\n  Suggested recalibration targets (p75 of this corpus):")
    p75_spc   = int(diag['supporting_project_count'].quantile(0.75))
    p75_vtc   = float(round(diag['verified_topic_count'].quantile(0.75), 1))
    p75_share = float(round(pd.Series(all_mean_shares).quantile(0.75), 3)) if all_mean_shares else 'n/a'
    print(f"    support_volume_scale_projects     → {p75_spc}")
    print(f"    support_breadth_scale_topics      → {p75_vtc}")
    print(f"    bridge_strength_scale_topic_share → {p75_share}")

# ── 4. Actual support count distribution — key for scale calibration ───────
print("\n── supporting_project_count distribution (raw corpus values) ──")
print(
    diag["supporting_project_count"]
    .describe(percentiles=[.1, .25, .5, .75, .9])
    .round(0)
    .to_string()
)
print(f"\n  scale param currently set to: {conf_cfg['support_volume_scale_projects']}")
print(f"  (anything at or above this scores 100 on support_volume_score)")
frac_maxed = (diag["supporting_project_count"] >= conf_cfg["support_volume_scale_projects"]).mean()
print(f"  fraction of insights at or above that threshold: {frac_maxed:.0%}")

# ── 5. Final confidence_score band breakdown ───────────────────────────────
print("\n── confidence_score band distribution ──")
for band in ["high", "medium", "low"]:
    cnt = (diag["confidence_band"] == band).sum()
    pct = 100 * cnt / n if n else 0
    print(f"  {band:<8s}: {cnt:>3}  ({pct:5.1f}%)")

# ── 6. Simulate tiering under current thresholds ──────────────────────────
print("\n── Simulated tier distribution (what the tiering cell will produce) ──")

def _simulate_tier(row):
    cs  = row["confidence_score"]
    spc = row["supporting_project_count"]
    vtc = row["verified_topic_count"]
    tqs = row["topic_quality_score"]
    bss = row["bridge_strength_score"]
    top = tier_cfg["top"]
    sec = tier_cfg["secondary"]
    ter = tier_cfg["tertiary"]
    if (cs  >= top["min_confidence_score"] and
        spc >= top["min_supporting_project_count"] and
        vtc >= top["min_verified_topic_count"]):
        return "top"
    if (cs  >= sec["min_confidence_score"] and
        spc >= sec["min_supporting_project_count"]):
        return "secondary"
    if (cs  >= ter["min_confidence_score"] and
        spc >= ter["min_supporting_project_count"] and
        tqs >= ter["min_topic_quality_score"] and
        bss >= ter["min_bridge_strength_score"]):
        return "tertiary"
    return "rejected"

diag["_sim_tier"] = diag.apply(_simulate_tier, axis=1)

for tier in ["top", "secondary", "tertiary", "rejected"]:
    cnt = (diag["_sim_tier"] == tier).sum()
    pct = 100 * cnt / n if n else 0
    print(f"  {tier:<12s}: {cnt:>3}  ({pct:5.1f}%)")

# ── 7. Dead zone: rejected but not obviously weak ─────────────────────────
dead_zone = diag[
    (diag["_sim_tier"] == "rejected") &
    (diag["confidence_score"]         >= 40) &
    (diag["supporting_project_count"] >= 10)
].copy()

if not dead_zone.empty:
    print(f"\n── Dead zone: {len(dead_zone)} insight(s) rejected despite moderate support ──")
    print("   These fall through tier gaps. Review tertiary thresholds.")
    show_cols = [
        "insight_id", "confidence_score", "confidence_band",
        "supporting_project_count", "verified_topic_count",
        "topic_quality_score", "bridge_strength_score",
    ]
    print(dead_zone[show_cols].to_string(index=False))
else:
    print("\n  No dead-zone insights. Tier thresholds look clean.")

# ── 8. Penalty breakdown ───────────────────────────────────────────────────
print("\n── Penalty score breakdown ──")
penalized = diag[diag["penalty_score"] < 0]
print(f"  Insights with any penalty : {len(penalized)} / {n}")
if not penalized.empty:
    print(f"  Range                     : {penalized['penalty_score'].min():.0f}  to  {penalized['penalty_score'].max():.0f}")
    print(f"  Mean penalty (when hit)   : {penalized['penalty_score'].mean():.1f}")

print("\n" + "=" * 65)
print("  If ceiling hits > 70% or tier distribution looks off,")
print("  adjust params.yaml and re-run from the confidence scoring cell.")
print("=" * 65)
# Out:
# =================================================================
#   CONFIDENCE CALIBRATION DIAGNOSTIC
#   insights scored: 59  |  groupby: posted_year_quarter
# =================================================================
#
# ── Component score distributions (0–100 scale) ──
#        support_volume_score  support_breadth_score  topic_quality_score  bridge_strength_score  verification_cleanliness_score  penalty_score  confidence_score
# count                  59.0                   59.0                 59.0                   59.0                            59.0           59.0              59.0
# mean                   14.1                   49.2                 92.5                   69.4                            80.5           -2.7              53.9
# std                    11.8                   22.2                 23.2                   25.2                            23.3            7.7              18.0
# min                     0.0                   25.0                  0.0                    0.0                            33.3          -25.0               0.0
# 10%                     0.6                   25.0                 75.0                   48.4                            50.0          -13.0              32.2
# 25%                     4.4                   25.0                100.0                   69.0                            50.0            0.0              47.7
# 50%                    12.6                   50.0                100.0                   75.0                           100.0            0.0              59.1
# 75%                    20.2                   75.0                100.0                   80.8                           100.0            0.0              64.7
# 90%                    31.2                   75.0                100.0                   88.0                           100.0            0.0              68.4
# max                    44.2                  100.0                100.0                  100.0                           100.0            0.0              79.1
#
# ── Ceiling hits (score >= 99.9) — components maxed for too many insights ──
#   support_volume_score                      :   0/59  (  0.0%)
#   support_breadth_score                     :   3/59  (  5.1%)
#   topic_quality_score                       :  51/59  ( 86.4%)  ⚠  not discriminating
#   bridge_strength_score                     :   3/59  (  5.1%)
#   verification_cleanliness_score            :  33/59  ( 55.9%)
#
#   Current scale params (from params.yaml):
#     support_volume_scale_projects     = 20000
#     support_breadth_scale_topics      = 4
#     bridge_strength_scale_topic_share = 0.6
#
#   Suggested recalibration targets (p75 of this corpus):
#     support_volume_scale_projects     → 4042
#     support_breadth_scale_topics      → 3.0
#     bridge_strength_scale_topic_share → 0.484
#
# ── supporting_project_count distribution (raw corpus values) ──
# count      59.0
# mean     2813.0
# std      2364.0
# min         0.0
# 10%       124.0
# 25%       896.0
# 50%      2512.0
# 75%      4042.0
# 90%      6227.0
# max      8849.0
#
#   scale param currently set to: 20000
#   (anything at or above this scores 100 on support_volume_score)
#   fraction of insights at or above that threshold: 0%
#
# ── confidence_score band distribution ──
#   high    :   0  (  0.0%)
#   medium  :  34  ( 57.6%)
#   low     :  25  ( 42.4%)
#
# ── Simulated tier distribution (what the tiering cell will produce) ──
#   top         :   0  (  0.0%)
#   secondary   :  34  ( 57.6%)
#   tertiary    :   0  (  0.0%)
#   rejected    :  25  ( 42.4%)
#
# ── Dead zone: 18 insight(s) rejected despite moderate support ──
#    These fall through tier gaps. Review tertiary thresholds.
# insight_id  confidence_score confidence_band  supporting_project_count  verified_topic_count  topic_quality_score  bridge_strength_score
#     BG_004              47.5             low                      1081                     2                 75.0                   66.7
#     BG_005              47.3             low                       688                     1                100.0                   75.1
#     BG_009              47.2             low                      1172                     1                100.0                   70.7
#     BG_010              46.8             low                       948                     1                100.0                   70.7
#     BG_012              46.5             low                       669                     1                100.0                   71.5
#     BG_014              51.0             low                      3135                     1                100.0                   75.0
#     BG_015              46.4             low                      1902                     1                 50.0                   74.0
#     BG_020              54.2             low                      2512                     2                 75.0                   64.9
#     BG_021              51.6             low                       288                     1                100.0                   99.3
#     BG_023              45.4             low                      1351                     1                100.0                   60.5
#     BG_026              48.9             low                       844                     1                100.0                   81.9
#     BG_030              47.5             low                      1491                     1                100.0                   70.1
#     BG_033              51.4             low                      1507                     1                100.0                   89.4
#     BG_034              51.5             low                       155                     1                100.0                  100.0
#     BG_036              47.9             low                       461                     1                100.0                   79.9
#     BG_037              50.9             low                      3452                     1                100.0                   72.2
#     BG_040              50.6             low                      2566                     1                100.0                   77.3
#     BG_047              51.0             low                      1666                     1                100.0                   86.2
#
# ── Penalty score breakdown ──
#   Insights with any penalty : 7 / 59
#   Range                     : -25  to  -10
#   Mean penalty (when hit)   : -22.9
#
# =================================================================
#   If ceiling hits > 70% or tier distribution looks off,
#   adjust params.yaml and re-run from the confidence scoring cell.
# =================================================================

# %% [markdown]
# ---

# %%
# ── TIERING + FINAL OUTPUTS + REPORTING ─────────────────────────────────────
TIER_CFG = CFG["analysis"]["tiering"]

def assign_insight_tier(confidence_obj, cfg):
    supporting_project_count = confidence_obj["supporting_project_count"]
    verified_topic_count = confidence_obj["verified_topic_count"]
    claimed_topic_count = confidence_obj["claimed_topic_count"]
    confidence_score = confidence_obj["confidence_score"]
    topic_quality_score = confidence_obj["topic_quality_score"]
    bridge_strength_score = confidence_obj["bridge_strength_score"]

    if claimed_topic_count == 0:
        return "rejected", "zero_source_topics"
    if claimed_topic_count > 0 and verified_topic_count == 0:
        return "rejected", "verification_failed"

    top = cfg["top"]
    sec = cfg["secondary"]
    ter = cfg["tertiary"]

    if (
        confidence_score >= top["min_confidence_score"] and
        supporting_project_count >= top["min_supporting_project_count"] and
        verified_topic_count >= top["min_verified_topic_count"]
    ):
        return "top", None

    if (
        confidence_score >= sec["min_confidence_score"] and
        supporting_project_count >= sec["min_supporting_project_count"]
    ):
        return "secondary", None

    if (
        confidence_score >= ter["min_confidence_score"] and
        supporting_project_count >= ter["min_supporting_project_count"] and
        topic_quality_score >= ter["min_topic_quality_score"] and
        bridge_strength_score >= ter["min_bridge_strength_score"]
    ):
        return "tertiary", None

    if supporting_project_count < ter["min_supporting_project_count"]:
        return "rejected", "low_support"
    if topic_quality_score < ter["min_topic_quality_score"]:
        return "rejected", "low_topic_quality"
    if bridge_strength_score < ter["min_bridge_strength_score"]:
        return "rejected", "low_bridge_strength"
    return "rejected", "below_thresholds"

tier_rows = []
for _, row in conf_df.iterrows():
    tier, rejected_reason_code = assign_insight_tier(row.to_dict(), TIER_CFG)
    tier_rows.append({
        "insight_id": row["insight_id"],
        "tier": tier,
        "rejected_reason_code": rejected_reason_code,
        "tier_version": "v1",
    })
tier_df = pd.DataFrame(tier_rows)

run_warnings_count = get_warning_count(WARNINGS_PATH)

flat_rows = []
for ev in candidate_evidence_rows:
    conf = conf_df[conf_df["insight_id"] == ev["insight_id"]].iloc[0].to_dict()
    tier = tier_df[tier_df["insight_id"] == ev["insight_id"]].iloc[0].to_dict()
    flat_rows.append({
        "run_id": RUN_ID,
        "insight_id": ev["insight_id"],
        "section": ev["section"],
        "category_bucket": ev["category_bucket"],
        "title": ev["title"],
        "what_seeing": ev["what_seeing"],
        "why_easy_to_miss": ev["why_easy_to_miss"],
        "what_it_means": ev["what_it_means"],
        "confidence_score": conf["confidence_score"],
        "confidence_band": conf["confidence_band"],
        "confidence_version": conf["confidence_version"],
        "confidence_rationale": conf["confidence_rationale"],
        "tier": tier["tier"],
        "tier_version": tier["tier_version"],
        "rejected_reason_code": tier["rejected_reason_code"],
        "supporting_project_count": conf["supporting_project_count"],
        "verified_topic_count": conf["verified_topic_count"],
        "source_topic_count_claimed": conf["claimed_topic_count"],
        "source_topic_count_verified": conf["verified_topic_count"],
        "group_by_field": GROUPBY_FIELD,
        "filter_logic": FILTER_LOGIC,
        "warnings_count": run_warnings_count,
    })

insights_flat_df = pd.DataFrame(flat_rows)
insights_flat_df.to_csv(OUT("insights", "insights_flat.csv"), index=False)

accepted_ids = set(insights_flat_df[insights_flat_df["tier"] != "rejected"]["insight_id"])
rejected_ids = set(insights_flat_df[insights_flat_df["tier"] == "rejected"]["insight_id"])

accepted_evidence_rows = [row for row in candidate_evidence_rows if row["insight_id"] in accepted_ids]
rejected_evidence_rows = [row for row in candidate_evidence_rows if row["insight_id"] in rejected_ids]

write_json(OUT("insights", "rejected_insights.json"), [
    {
        **row,
        "confidence": conf_df[conf_df["insight_id"] == row["insight_id"]].iloc[0].to_dict(),
        "tiering": tier_df[tier_df["insight_id"] == row["insight_id"]].iloc[0].to_dict(),
    }
    for row in rejected_evidence_rows
])

structured = {"key_insights": [], OUTPUT_GROUP_KEY: {}}
for candidate in candidate_rows:
    ev = next((r for r in candidate_evidence_rows if r["insight_id"] == candidate["insight_id"]), None)
    if candidate["insight_id"] not in accepted_ids or ev is None:
        continue
    insight_clean = {
        "insight_id": candidate["insight_id"],
        "title": ev["title"],
        "what_seeing": ev["what_seeing"],
        "why_easy_to_miss": ev["why_easy_to_miss"],
        "what_it_means": ev["what_it_means"],
        "source_topics": ev["source_topics_verified"],
        "confidence_score": float(conf_df.loc[conf_df["insight_id"] == candidate["insight_id"], "confidence_score"].iloc[0]),
        "confidence_band": conf_df.loc[conf_df["insight_id"] == candidate["insight_id"], "confidence_band"].iloc[0],
        "confidence_version": "v1",
        "tier": tier_df.loc[tier_df["insight_id"] == candidate["insight_id"], "tier"].iloc[0],
        "tier_version": "v1",
        "supporting_project_count": int(ev["supporting_project_count"]),
        "verified_topic_count": int(len(ev["source_topics_verified"])),
        "warnings": [],
    }
    if candidate["section"] == "key_insights":
        structured["key_insights"].append(insight_clean)
    else:
        structured[OUTPUT_GROUP_KEY].setdefault(candidate["category_bucket"], []).append(insight_clean)

write_json(OUT("insights", "insights_structured.json"), structured)

# Accepted-only evidence artifacts
with open(OUT("evidence", "evidence_pack.jsonl"), "w", encoding="utf-8") as f:
    for row in accepted_evidence_rows:
        f.write(json.dumps(row, ensure_ascii=False, default=str) + "\n")

evidence_topic_support_rows = []
evidence_snippet_rows = []
evidence_project_rows = []
for row in accepted_evidence_rows:
    topic_rows_cache = {get_topic_key(ts["group"], ts["topic_id"]): BRIDGE_LOOKUP.get(get_topic_key(ts["group"], ts["topic_id"]), pd.DataFrame(columns=["project_id", "weight", "topic_share"])) for ts in row["topic_support"]}
    for ts in row["topic_support"]:
        evidence_topic_support_rows.append({
            "run_id": RUN_ID,
            "insight_id": row["insight_id"],
            "section": row["section"],
            "category_bucket": row["category_bucket"],
            "group_by_field": GROUPBY_FIELD,
            "group_value": ts["group"],
            "topic_id": ts["topic_id"],
            "topic_label": ts["topic_label"],
            "topic_description": ts["topic_description"],
            "coherence_flag": ts["coherence_flag"],
            "supporting_project_count": ts["supporting_project_count"],
            "mean_topic_share": ts["mean_topic_share"],
            "median_topic_share": ts["median_topic_share"],
        })
        topic_key = get_topic_key(ts["group"], ts["topic_id"])
        bridge_rows = topic_rows_cache.get(topic_key, pd.DataFrame(columns=["project_id", "weight", "topic_share"]))
        for _, br in bridge_rows.iterrows():
            evidence_project_rows.append({
                "run_id": RUN_ID,
                "insight_id": row["insight_id"],
                "group_by_field": GROUPBY_FIELD,
                "group_value": ts["group"],
                "topic_id": ts["topic_id"],
                "project_id": br["project_id"],
                "topic_key": topic_key,
                "weight": br["weight"],
                "topic_share": br["topic_share"],
            })
    for sp in row["sample_projects"]:
        evidence_snippet_rows.append({
            "run_id": RUN_ID,
            "insight_id": row["insight_id"],
            "group_by_field": GROUPBY_FIELD,
            "group_value": sp["group"],
            "topic_id": sp["topic_id"],
            "project_id": sp["project_id"],
            "topic_share": sp["topic_share"],
            "essay_text": build_full_essay_text(sp["project_id"]),
            "injected_tokens": build_injected_tokens(sp["project_id"]),
        })

pd.DataFrame(evidence_topic_support_rows).to_csv(OUT("evidence", "evidence_topic_support.csv"), index=False)
pd.DataFrame(evidence_snippet_rows).to_csv(OUT("evidence", "evidence_snippets.csv"), index=False)
pd.DataFrame(evidence_project_rows).to_csv(OUT("evidence", "evidence_projects.csv"), index=False)

# Chart-ready accepted-only data
chart_rows = []
group_support_rows = []
for row in accepted_evidence_rows:
    flat = insights_flat_df[insights_flat_df["insight_id"] == row["insight_id"]].iloc[0]
    chart_rows.append({
        "run_id": RUN_ID,
        "insight_id": row["insight_id"],
        "theme": row["title"],
        "section": row["section"],
        "category_bucket": row["category_bucket"],
        "tier": flat["tier"],
        "confidence_band": flat["confidence_band"],
        "confidence_score": flat["confidence_score"],
        "group_by_field": GROUPBY_FIELD,
        "supporting_project_count": row["supporting_project_count"],
        "verified_topic_count": len(row["source_topics_verified"]),
        "magnitude": row["supporting_project_count"],
        "magnitude_unit": "projects",
        "delta": None,
        "delta_unit": None,
        "period": None,
    })
    for ts in row["topic_support"]:
        group_support_rows.append({
            "run_id": RUN_ID,
            "insight_id": row["insight_id"],
            "theme": row["title"],
            "group_by_field": GROUPBY_FIELD,
            "group_value": ts["group"],
            "topic_id": ts["topic_id"],
            "supporting_project_count": ts["supporting_project_count"],
            "mean_topic_share": ts["mean_topic_share"],
            "confidence_score": flat["confidence_score"],
            "confidence_band": flat["confidence_band"],
            "tier": flat["tier"],
        })

pd.DataFrame(chart_rows).to_csv(OUT("chart_data", "chart_ready_insights.csv"), index=False)
pd.DataFrame(group_support_rows).to_csv(OUT("chart_data", "chart_ready_group_support.csv"), index=False)

# DOCX report accepted-only
def add_heading(doc, text, level):
    p = doc.add_heading(text, level=level)
    p.runs[0].font.color.rgb = RGBColor(0, 0, 0)
    return p

def add_insight(doc, insight):
    p = doc.add_paragraph()
    run = p.add_run(insight.get("title", ""))
    run.bold = True
    run.font.size = Pt(11)

    for label, key in [
        ("What we're seeing:", "what_seeing"),
        ("Why this is easy to miss:", "why_easy_to_miss"),
        ("What this means for funders:", "what_it_means"),
    ]:
        p = doc.add_paragraph()
        label_run = p.add_run(label + "  ")
        label_run.bold = True
        label_run.font.size = Pt(10)
        body_run = p.add_run(insight.get(key, ""))
        body_run.font.size = Pt(10)
        p.paragraph_format.space_after = Pt(2)
    doc.add_paragraph()

doc = Document()
for section in doc.sections:
    section.top_margin = Inches(1)
    section.bottom_margin = Inches(1)
    section.left_margin = Inches(1)
    section.right_margin = Inches(1)

style = doc.styles["Normal"]
style.font.name = "Arial"
style.font.size = Pt(10)

add_heading(doc, f"Investigated Across {GROUPBY_FIELD}", level=1)
add_heading(doc, "Key Insights", level=2)
for insight in structured.get("key_insights", []):
    add_insight(doc, insight)

add_heading(doc, "By Group", level=1)
for category, items in structured.get(OUTPUT_GROUP_KEY, {}).items():
    add_heading(doc, category, level=2)
    for insight in items:
        add_insight(doc, insight)

docx_path = OUT("reports", "trend_tracker_report.docx")
doc.save(docx_path)

# Metadata / manifests
write_json(OUT("metadata", "confidence_model_meta.json"), {
    "schema_version": "v1",
    "run_id": RUN_ID,
    "group_by_field": GROUPBY_FIELD,
    "filter_fields_key": FILTER_FIELDS_KEY,
    "confidence_config": CONFIDENCE_CFG,
})
write_json(OUT("metadata", "tiering_model_meta.json"), {
    "schema_version": "v1",
    "run_id": RUN_ID,
    "group_by_field": GROUPBY_FIELD,
    "filter_fields_key": FILTER_FIELDS_KEY,
    "tiering_config": TIER_CFG,
})

groups_failed = sorted(set(NMF_GROUPS_FAILED) | set(LABELING_FAILED_GROUPS) | set(SYNTHESIS_FAILED_GROUPS))
eligible_groups = list(per_group_results.keys())

stage_manifest_path = OUT("metadata", "stage_manifest_03_insights_generation.json")
finalize_stage_manifest(
    STAGE_MANIFEST,
    output_path=stage_manifest_path,
    status="success",
    input_artifacts=[
        artifact_meta(ROOT / "OUTPUTS/prepared/05_enriched.parquet", "enriched_parquet"),
        artifact_meta(ROOT / "OUTPUTS/prepared/metadata/stage_manifest_01_preprocess.json", "stage_manifest_01"),
        artifact_meta(ROOT / "OUTPUTS/enrichment/metadata/stage_manifest_02_semantic_enrichment.json", "stage_manifest_02"),
    ],
    output_artifacts=[
        artifact_meta(OUT("analysis", "category_tfidf.csv"), "category_tfidf_csv"),
        artifact_meta(OUT("analysis", "nmf_topics.csv"), "nmf_topics_csv"),
        artifact_meta(OUT("analysis", "nmf_weights.csv"), "nmf_weights_csv"),
        artifact_meta(OUT("analysis", "project_topic_bridge.csv"), "project_topic_bridge_csv"),
        artifact_meta(OUT("analysis", "llm_topic_labels.json"), "llm_topic_labels_json"),
        artifact_meta(OUT("insights", "insights_candidates.json"), "insights_candidates_json"),
        artifact_meta(OUT("insights", "insights_structured.json"), "insights_structured_json"),
        artifact_meta(OUT("insights", "rejected_insights.json"), "rejected_insights_json"),
        artifact_meta(OUT("insights", "insights_flat.csv"), "insights_flat_csv"),
        artifact_meta(OUT("insights", "insights_confidence.csv"), "insights_confidence_csv"),
        artifact_meta(OUT("chart_data", "chart_ready_insights.csv"), "chart_ready_insights_csv"),
        artifact_meta(OUT("reports", "trend_tracker_report.docx"), "trend_tracker_report_docx"),
    ],
    row_counts={
        "input_projects": int(len(raw_df)),
        "filtered_projects": int(len(df)),
        "eligible_groups": int(len(eligible_groups)),
        "groups_skipped": int(len(NMF_GROUPS_SKIPPED)),
        "groups_failed": int(len(groups_failed)),
        "topics_generated": int(len(topics_df)),
        "insights_generated": int(len(candidate_evidence_rows)),
        "insights_accepted": int(len(accepted_ids)),
        "insights_rejected": int(len(rejected_ids)),
    },
    key_params={
        "group_by": GROUPBY_FIELD,
        "filter_fields_key": FILTER_FIELDS_KEY,
        "min_group_projects": CFG["analysis"]["min_group_projects"],
        "topic_assignment_threshold": CFG["analysis"]["topic_assignment_threshold"],
        "model_labeling": MODEL_LABELING,
        "model_synthesis": MODEL_SYNTHESIS,
        "confidence_config": CONFIDENCE_CFG,
        "tiering_config": TIER_CFG,
    },
    warnings_path=WARNINGS_PATH,
)

pipeline_manifest_path = OUT("metadata", "pipeline_manifest.json")
build_pipeline_manifest(
    output_path=pipeline_manifest_path,
    run_id=RUN_ID,
    run_date=RUN_DATE,
    group_by_field=GROUPBY_FIELD,
    filter_fields_key=FILTER_FIELDS_KEY,
    filter_spec_path=FILTER_SPEC_PATH,
    filter_summary_path=FILTER_SUMMARY_PATH,
    stage_manifest_paths=[
        ROOT / "OUTPUTS/prepared/metadata/stage_manifest_01_preprocess.json",
        ROOT / "OUTPUTS/enrichment/metadata/stage_manifest_02_semantic_enrichment.json",
        stage_manifest_path,
    ],
    warnings_01_path=ROOT / "OUTPUTS/prepared/warnings_01.jsonl",
    warnings_02_path=ROOT / "OUTPUTS/enrichment/warnings_02.jsonl",
    warnings_03_path=WARNINGS_PATH,
    final_outputs={
        "insights_structured_json": str(OUT("insights", "insights_structured.json")),
        "insights_flat_csv": str(OUT("insights", "insights_flat.csv")),
        "evidence_pack_jsonl": str(OUT("evidence", "evidence_pack.jsonl")),
        "insights_confidence_csv": str(OUT("insights", "insights_confidence.csv")),
        "chart_ready_insights_csv": str(OUT("chart_data", "chart_ready_insights.csv")),
        "trend_tracker_report_docx": str(OUT("reports", "trend_tracker_report.docx")),
    },
)

print(f"Accepted insights: {len(accepted_ids):,}")
print(f"Rejected insights: {len(rejected_ids):,}")
print(f"Docx saved → {docx_path}")
print(f"Stage manifest written → {stage_manifest_path}")
print(f"Pipeline manifest written → {pipeline_manifest_path}")
# Out:
# Accepted insights: 34
# Rejected insights: 25
# Docx saved → /Users/matt.fritz/Desktop/Research Insights/Essay Prototype/OUTPUTS/runs/posted_year_quarter/2026-03-31/20260331_101735_posted_year_quarter_a36f58b0/reports/trend_tracker_report.docx
# Stage manifest written → /Users/matt.fritz/Desktop/Research Insights/Essay Prototype/OUTPUTS/runs/posted_year_quarter/2026-03-31/20260331_101735_posted_year_quarter_a36f58b0/metadata/stage_manifest_03_insights_generation.json
# Pipeline manifest written → /Users/matt.fritz/Desktop/Research Insights/Essay Prototype/OUTPUTS/runs/posted_year_quarter/2026-03-31/20260331_101735_posted_year_quarter_a36f58b0/metadata/pipeline_manifest.json
